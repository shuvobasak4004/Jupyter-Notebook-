# %%
import os
import numpy as np
import matplotlib.pyplot as plt
from matplotlib import cm
from PIL import Image
import cv2

# Define input and output directories
input_directory = r'F:\MLpractrice\ct\data2'
output_directory = r'F:\MLpractrice\ct\output'

# Create the output directory if it doesn't exist
if not os.path.exists(output_directory):
    os.makedirs(output_directory)

# Method 1: Basic Color Map Application
def apply_color_map(ct_image, cmap='jet'):
    ct_image_normalized = (ct_image - np.min(ct_image)) / (np.max(ct_image) - np.min(ct_image))
    colored_image = cm.get_cmap(cmap)(ct_image_normalized)
    return (colored_image[:, :, :3] * 255).astype(np.uint8)

# Method 2: Adaptive Histogram Equalization with Color Map
def apply_adaptive_hist_eq(ct_image):
    clahe = cv2.createCLAHE(clipLimit=2.0, tileGridSize=(8, 8))
    enhanced_image = clahe.apply(ct_image)
    return apply_color_map(enhanced_image)

# Method 3: Contrast Stretching with Color Map
def apply_contrast_stretching(ct_image):
    min_val, max_val = np.min(ct_image), np.max(ct_image)
    stretched_image = (ct_image - min_val) / (max_val - min_val)
    return apply_color_map(stretched_image)

# Method 4: Gaussian Blur with Color Map
def apply_gaussian_blur(ct_image):
    blurred_image = cv2.GaussianBlur(ct_image, (5, 5), 0)
    return apply_color_map(blurred_image)

# Method 5: Edge Detection with Canny and Color Map
def apply_edge_detection(ct_image):
    edges = cv2.Canny(ct_image, 100, 200)
    return apply_color_map(edges)

# Method 6: Random Color Palettes (Color Overlay)
def apply_random_color_palette(ct_image):
    random_colored = np.random.rand(*ct_image.shape, 3)
    colored_image = ct_image[:, :, None] * random_colored
    return (colored_image * 255).astype(np.uint8)

# Method 7: Non-Linear Color Stretching (Gamma Correction)
def apply_gamma_correction(ct_image, gamma=1.2):
    gamma_corrected = np.power(ct_image / float(np.max(ct_image)), gamma) * 255
    return apply_color_map(gamma_corrected)

# Method 8: LUT (Lookup Table) Color Mapping (Use predefined LUT)
def apply_lut_color_map(ct_image):
    colored_image = cm.plasma((ct_image - np.min(ct_image)) / (np.max(ct_image) - np.min(ct_image)))
    return (colored_image[:, :, :3] * 255).astype(np.uint8)

# Method 9: Alpha Blending (Threshold-based)
def apply_alpha_blending(ct_image):
    thresholded_image = ct_image > 100
    colored_image = apply_color_map(ct_image)
    thresholded_image_rgb = np.stack([thresholded_image] * 3, axis=-1)
    alpha = 0.5
    final_image = alpha * colored_image + (1 - alpha) * thresholded_image_rgb * 255
    return final_image.astype(np.uint8)

# Method 10: 3D Rendering (Placeholder for 2D images)
def apply_3d_rendering(ct_image):
    return apply_color_map(ct_image)

# Method 11: Heatmap Visualization for Anomaly Detection
def apply_heatmap(ct_image):
    heatmap_image = cm.hot((ct_image - np.min(ct_image)) / (np.max(ct_image) - np.min(ct_image)))
    return (heatmap_image[:, :, :3] * 255).astype(np.uint8)

# Method 12: 3D Volume Rendering (Placeholder for 3D visualization)
def apply_3d_volume_rendering(ct_image):
    return apply_color_map(ct_image)

# Method 13: Interactive Visualization with Segmented Regions
def apply_interactive_visualization(ct_image):
    segmented_image = ct_image > 100
    segmented_colored = cm.plasma(segmented_image.astype(np.float32))
    return (segmented_colored[:, :, :3] * 255).astype(np.uint8)

# Traverse the input directory and process each image in the subfolders
for root, dirs, files in os.walk(input_directory):
    # For each image file in the directory
    for image_file in files:
        if image_file.endswith('.jpg') or image_file.endswith('.png'):
            try:
                # Construct the full input path for the image
                image_path = os.path.join(root, image_file)
                
                # Load the image using PIL
                image = Image.open(image_path)
                
                # Convert image to grayscale
                ct_image = np.array(image.convert('L'))  # Convert to grayscale
                
                # Create the same folder structure in the output directory
                relative_path = os.path.relpath(root, input_directory)  # Get relative folder structure
                output_folder = os.path.join(output_directory, relative_path)
                if not os.path.exists(output_folder):
                    os.makedirs(output_folder)
                
                # Apply all methods and save the output images
                methods = [
                    ("Basic Color Map", apply_color_map(ct_image, cmap='jet')),
                    ("Adaptive Histogram Equalization", apply_adaptive_hist_eq(ct_image)),
                    ("Contrast Stretching", apply_contrast_stretching(ct_image)),
                    ("Gaussian Blur", apply_gaussian_blur(ct_image)),
                    ("Edge Detection", apply_edge_detection(ct_image)),
                    ("Random Color Palette", apply_random_color_palette(ct_image)),
                    ("Gamma Correction", apply_gamma_correction(ct_image, gamma=1.5)),
                    ("LUT Color Map", apply_lut_color_map(ct_image)),
                    ("Alpha Blending", apply_alpha_blending(ct_image)),
                    ("3D Rendering", apply_3d_rendering(ct_image)),
                    ("Heatmap Visualization", apply_heatmap(ct_image)),
                    ("3D Volume Rendering", apply_3d_volume_rendering(ct_image)),
                    ("Interactive Segmentation", apply_interactive_visualization(ct_image))
                ]
                
                # Save the images as .jpg in the output folder, starting from 1.jpg
                for idx, (method_name, result_image) in enumerate(methods):
                    output_image_path = os.path.join(output_folder, f"{idx+1}.jpg")
                    Image.fromarray(result_image).save(output_image_path, format='JPEG')
                    print(f"Processed and saved {image_file} with method '{method_name}' as {output_image_path}")
            
            except Exception as e:
                print(f"Error processing {image_file} in {root}: {e}")

print("Processing complete.")
# Out:
# C:\Users\AIC\AppData\Local\Temp\ipykernel_14264\1168260378.py:19: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap(obj)`` instead.
#   colored_image = cm.get_cmap(cmap)(ct_image_normalized)
# Processed and saved 00000(6).png with method 'Basic Color Map' as F:\MLpractrice\ct\output\a\1.jpg
# Processed and saved 00000(6).png with method 'Adaptive Histogram Equalization' as F:\MLpractrice\ct\output\a\2.jpg
# Processed and saved 00000(6).png with method 'Contrast Stretching' as F:\MLpractrice\ct\output\a\3.jpg
# Processed and saved 00000(6).png with method 'Gaussian Blur' as F:\MLpractrice\ct\output\a\4.jpg
# Processed and saved 00000(6).png with method 'Edge Detection' as F:\MLpractrice\ct\output\a\5.jpg
# Processed and saved 00000(6).png with method 'Random Color Palette' as F:\MLpractrice\ct\output\a\6.jpg
# Processed and saved 00000(6).png with method 'Gamma Correction' as F:\MLpractrice\ct\output\a\7.jpg
# Processed and saved 00000(6).png with method 'LUT Color Map' as F:\MLpractrice\ct\output\a\8.jpg
# Processed and saved 00000(6).png with method 'Alpha Blending' as F:\MLpractrice\ct\output\a\9.jpg
# Processed and saved 00000(6).png with method '3D Rendering' as F:\MLpractrice\ct\output\a\10.jpg
# Processed and saved 00000(6).png with method 'Heatmap Visualization' as F:\MLpractrice\ct\output\a\11.jpg
# Processed and saved 00000(6).png with method '3D Volume Rendering' as F:\MLpractrice\ct\output\a\12.jpg
# Processed and saved 00000(6).png with method 'Interactive Segmentation' as F:\MLpractrice\ct\output\a\13.jpg
# Processed and saved 000000 (6).png with method 'Basic Color Map' as F:\MLpractrice\ct\output\a\1.jpg
# Processed and saved 000000 (6).png with method 'Adaptive Histogram Equalization' as F:\MLpractrice\ct\output\a\2.jpg
# Processed and saved 000000 (6).png with method 'Contrast Stretching' as F:\MLpractrice\ct\output\a\3.jpg
# Processed and saved 000000 (6).png with method 'Gaussian Blur' as F:\MLpractrice\ct\output\a\4.jpg
# Processed and saved 000000 (6).png with method 'Edge Detection' as F:\MLpractrice\ct\output\a\5.jpg
# Processed and saved 000000 (6).png with method 'Random Color Palette' as F:\MLpractrice\ct\output\a\6.jpg
# Processed and saved 000000 (6).png with method 'Gamma Correction' as F:\MLpractrice\ct\output\a\7.jpg
# Processed and saved 000000 (6).png with method 'LUT Color Map' as F:\MLpractrice\ct\output\a\8.jpg
# Processed and saved 000000 (6).png with method 'Alpha Blending' as F:\MLpractrice\ct\output\a\9.jpg
# Processed and saved 000000 (6).png with method '3D Rendering' as F:\MLpractrice\ct\output\a\10.jpg
# Processed and saved 000000 (6).png with method 'Heatmap Visualization' as F:\MLpractrice\ct\output\a\11.jpg
# Processed and saved 000000 (6).png with method '3D Volume Rendering' as F:\MLpractrice\ct\output\a\12.jpg
# Processed and saved 000000 (6).png with method 'Interactive Segmentation' as F:\MLpractrice\ct\output\a\13.jpg
# Processed and saved 00000(6).png with method 'Basic Color Map' as F:\MLpractrice\ct\output\b\1.jpg
# Processed and saved 00000(6).png with method 'Adaptive Histogram Equalization' as F:\MLpractrice\ct\output\b\2.jpg
# Processed and saved 00000(6).png with method 'Contrast Stretching' as F:\MLpractrice\ct\output\b\3.jpg
# Processed and saved 00000(6).png with method 'Gaussian Blur' as F:\MLpractrice\ct\output\b\4.jpg
# Processed and saved 00000(6).png with method 'Edge Detection' as F:\MLpractrice\ct\output\b\5.jpg
# Processed and saved 00000(6).png with method 'Random Color Palette' as F:\MLpractrice\ct\output\b\6.jpg
# Processed and saved 00000(6).png with method 'Gamma Correction' as F:\MLpractrice\ct\output\b\7.jpg
# Processed and saved 00000(6).png with method 'LUT Color Map' as F:\MLpractrice\ct\output\b\8.jpg
# Processed and saved 00000(6).png with method 'Alpha Blending' as F:\MLpractrice\ct\output\b\9.jpg
# Processed and saved 00000(6).png with method '3D Rendering' as F:\MLpractrice\ct\output\b\10.jpg
# Processed and saved 00000(6).png with method 'Heatmap Visualization' as F:\MLpractrice\ct\output\b\11.jpg
# Processed and saved 00000(6).png with method '3D Volume Rendering' as F:\MLpractrice\ct\output\b\12.jpg
# Processed and saved 00000(6).png with method 'Interactive Segmentation' as F:\MLpractrice\ct\output\b\13.jpg
# Processed and saved 000000 (6).png with method 'Basic Color Map' as F:\MLpractrice\ct\output\b\1.jpg
# Processed and saved 000000 (6).png with method 'Adaptive Histogram Equalization' as F:\MLpractrice\ct\output\b\2.jpg
# Processed and saved 000000 (6).png with method 'Contrast Stretching' as F:\MLpractrice\ct\output\b\3.jpg
# Processed and saved 000000 (6).png with method 'Gaussian Blur' as F:\MLpractrice\ct\output\b\4.jpg
# Processed and saved 000000 (6).png with method 'Edge Detection' as F:\MLpractrice\ct\output\b\5.jpg
# Processed and saved 000000 (6).png with method 'Random Color Palette' as F:\MLpractrice\ct\output\b\6.jpg
# Processed and saved 000000 (6).png with method 'Gamma Correction' as F:\MLpractrice\ct\output\b\7.jpg
# Processed and saved 000000 (6).png with method 'LUT Color Map' as F:\MLpractrice\ct\output\b\8.jpg
# Processed and saved 000000 (6).png with method 'Alpha Blending' as F:\MLpractrice\ct\output\b\9.jpg
# Processed and saved 000000 (6).png with method '3D Rendering' as F:\MLpractrice\ct\output\b\10.jpg
# Processed and saved 000000 (6).png with method 'Heatmap Visualization' as F:\MLpractrice\ct\output\b\11.jpg
# Processed and saved 000000 (6).png with method '3D Volume Rendering' as F:\MLpractrice\ct\output\b\12.jpg
# Processed and saved 000000 (6).png with method 'Interactive Segmentation' as F:\MLpractrice\ct\output\b\13.jpg
# Processing complete.

# %%
import os
import numpy as np
import matplotlib.pyplot as plt
from matplotlib import cm
from PIL import Image
import cv2

# Define input and output directories
input_directory = r'F:\MLpractrice\ct\data2'
output_directory = r'F:\MLpractrice\ct\output'

# Create the output directory if it doesn't exist
if not os.path.exists(output_directory):
    os.makedirs(output_directory)

# Method 1: Basic Color Map Application
def apply_color_map(ct_image, cmap='jet'):
    ct_image_normalized = (ct_image - np.min(ct_image)) / (np.max(ct_image) - np.min(ct_image))
    colored_image = cm.get_cmap(cmap)(ct_image_normalized)
    return (colored_image[:, :, :3] * 255).astype(np.uint8)

# Method 2: Adaptive Histogram Equalization with Color Map
def apply_adaptive_hist_eq(ct_image):
    clahe = cv2.createCLAHE(clipLimit=2.0, tileGridSize=(8, 8))
    enhanced_image = clahe.apply(ct_image)
    return apply_color_map(enhanced_image)

# Method 3: Contrast Stretching with Color Map
def apply_contrast_stretching(ct_image):
    min_val, max_val = np.min(ct_image), np.max(ct_image)
    stretched_image = (ct_image - min_val) / (max_val - min_val)
    return apply_color_map(stretched_image)

# Method 4: Gaussian Blur with Color Map
def apply_gaussian_blur(ct_image):
    blurred_image = cv2.GaussianBlur(ct_image, (5, 5), 0)
    return apply_color_map(blurred_image)

# Method 5: Edge Detection with Canny and Color Map
def apply_edge_detection(ct_image):
    edges = cv2.Canny(ct_image, 100, 200)
    return apply_color_map(edges)

# Method 6: Random Color Palettes (Color Overlay)
def apply_random_color_palette(ct_image):
    random_colored = np.random.rand(*ct_image.shape, 3)
    colored_image = ct_image[:, :, None] * random_colored
    return (colored_image * 255).astype(np.uint8)

# Method 7: Non-Linear Color Stretching (Gamma Correction)
def apply_gamma_correction(ct_image, gamma=1.2):
    gamma_corrected = np.power(ct_image / float(np.max(ct_image)), gamma) * 255
    return apply_color_map(gamma_corrected)

# Method 8: LUT (Lookup Table) Color Mapping (Use predefined LUT)
def apply_lut_color_map(ct_image):
    colored_image = cm.plasma((ct_image - np.min(ct_image)) / (np.max(ct_image) - np.min(ct_image)))
    return (colored_image[:, :, :3] * 255).astype(np.uint8)

# Method 9: Alpha Blending (Threshold-based)
def apply_alpha_blending(ct_image):
    thresholded_image = ct_image > 100
    colored_image = apply_color_map(ct_image)
    thresholded_image_rgb = np.stack([thresholded_image] * 3, axis=-1)
    alpha = 0.5
    final_image = alpha * colored_image + (1 - alpha) * thresholded_image_rgb * 255
    return final_image.astype(np.uint8)

# Method 10: 3D Rendering (Placeholder for 2D images)
def apply_3d_rendering(ct_image):
    return apply_color_map(ct_image)

# Method 11: Heatmap Visualization for Anomaly Detection
def apply_heatmap(ct_image):
    heatmap_image = cm.hot((ct_image - np.min(ct_image)) / (np.max(ct_image) - np.min(ct_image)))
    return (heatmap_image[:, :, :3] * 255).astype(np.uint8)

# Method 12: 3D Volume Rendering (Placeholder for 3D visualization)
def apply_3d_volume_rendering(ct_image):
    return apply_color_map(ct_image)

# Method 13: Interactive Visualization with Segmented Regions
def apply_interactive_visualization(ct_image):
    segmented_image = ct_image > 100
    segmented_colored = cm.plasma(segmented_image.astype(np.float32))
    return (segmented_colored[:, :, :3] * 255).astype(np.uint8)

# Traverse the input directory and process each image in the subfolders
for root, dirs, files in os.walk(input_directory):
    # For each image file in the directory
    for image_file in files:
        if image_file.endswith('.jpg') or image_file.endswith('.png'):
            try:
                # Construct the full input path for the image
                image_path = os.path.join(root, image_file)
                
                # Load the image using PIL
                image = Image.open(image_path)
                
                # Convert image to grayscale
                ct_image = np.array(image.convert('L'))  # Convert to grayscale
                
                # Create the same folder structure in the output directory
                relative_path = os.path.relpath(root, input_directory)  # Get relative folder structure
                output_folder = os.path.join(output_directory, relative_path)
                if not os.path.exists(output_folder):
                    os.makedirs(output_folder)
                
                # Apply all methods and save the output images
                methods = [
                    ("Basic_Color_Map", apply_color_map(ct_image, cmap='jet')),
                    ("Adaptive_Histogram_Equalization", apply_adaptive_hist_eq(ct_image)),
                    ("Contrast_Stretching", apply_contrast_stretching(ct_image)),
                    ("Gaussian_Blur", apply_gaussian_blur(ct_image)),
                    ("Edge_Detection", apply_edge_detection(ct_image)),
                    ("Random_Color_Palette", apply_random_color_palette(ct_image)),
                    ("Gamma_Correction", apply_gamma_correction(ct_image, gamma=1.5)),
                    ("LUT_Color_Map", apply_lut_color_map(ct_image)),
                    ("Alpha_Blending", apply_alpha_blending(ct_image)),
                    ("3D_Rendering", apply_3d_rendering(ct_image)),
                    ("Heatmap_Visualization", apply_heatmap(ct_image)),
                    ("3D_Volume_Rendering", apply_3d_volume_rendering(ct_image)),
                    ("Interactive_Segmentation", apply_interactive_visualization(ct_image))
                ]
                
                # Save the images as .jpg in the output folder with unique names
                for method_name, result_image in methods:
                    # Generate the output file name using method name and image file name
                    output_image_path = os.path.join(output_folder, f"{os.path.splitext(image_file)[0]}_{method_name}.jpg")
                    Image.fromarray(result_image).save(output_image_path, format='JPEG')
                    print(f"Processed and saved {image_file} with method '{method_name}' as {output_image_path}")
            
            except Exception as e:
                print(f"Error processing {image_file} in {root}: {e}")

print("Processing complete.")
# Out:
# C:\Users\AIC\AppData\Local\Temp\ipykernel_14264\573043872.py:19: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap(obj)`` instead.
#   colored_image = cm.get_cmap(cmap)(ct_image_normalized)
# Processed and saved 00000(6).png with method 'Basic_Color_Map' as F:\MLpractrice\ct\output\a\00000(6)_Basic_Color_Map.jpg
# Processed and saved 00000(6).png with method 'Adaptive_Histogram_Equalization' as F:\MLpractrice\ct\output\a\00000(6)_Adaptive_Histogram_Equalization.jpg
# Processed and saved 00000(6).png with method 'Contrast_Stretching' as F:\MLpractrice\ct\output\a\00000(6)_Contrast_Stretching.jpg
# Processed and saved 00000(6).png with method 'Gaussian_Blur' as F:\MLpractrice\ct\output\a\00000(6)_Gaussian_Blur.jpg
# Processed and saved 00000(6).png with method 'Edge_Detection' as F:\MLpractrice\ct\output\a\00000(6)_Edge_Detection.jpg
# Processed and saved 00000(6).png with method 'Random_Color_Palette' as F:\MLpractrice\ct\output\a\00000(6)_Random_Color_Palette.jpg
# Processed and saved 00000(6).png with method 'Gamma_Correction' as F:\MLpractrice\ct\output\a\00000(6)_Gamma_Correction.jpg
# Processed and saved 00000(6).png with method 'LUT_Color_Map' as F:\MLpractrice\ct\output\a\00000(6)_LUT_Color_Map.jpg
# Processed and saved 00000(6).png with method 'Alpha_Blending' as F:\MLpractrice\ct\output\a\00000(6)_Alpha_Blending.jpg
# Processed and saved 00000(6).png with method '3D_Rendering' as F:\MLpractrice\ct\output\a\00000(6)_3D_Rendering.jpg
# Processed and saved 00000(6).png with method 'Heatmap_Visualization' as F:\MLpractrice\ct\output\a\00000(6)_Heatmap_Visualization.jpg
# Processed and saved 00000(6).png with method '3D_Volume_Rendering' as F:\MLpractrice\ct\output\a\00000(6)_3D_Volume_Rendering.jpg
# Processed and saved 00000(6).png with method 'Interactive_Segmentation' as F:\MLpractrice\ct\output\a\00000(6)_Interactive_Segmentation.jpg
# Processed and saved 000000 (6).png with method 'Basic_Color_Map' as F:\MLpractrice\ct\output\a\000000 (6)_Basic_Color_Map.jpg
# Processed and saved 000000 (6).png with method 'Adaptive_Histogram_Equalization' as F:\MLpractrice\ct\output\a\000000 (6)_Adaptive_Histogram_Equalization.jpg
# Processed and saved 000000 (6).png with method 'Contrast_Stretching' as F:\MLpractrice\ct\output\a\000000 (6)_Contrast_Stretching.jpg
# Processed and saved 000000 (6).png with method 'Gaussian_Blur' as F:\MLpractrice\ct\output\a\000000 (6)_Gaussian_Blur.jpg
# Processed and saved 000000 (6).png with method 'Edge_Detection' as F:\MLpractrice\ct\output\a\000000 (6)_Edge_Detection.jpg
# Processed and saved 000000 (6).png with method 'Random_Color_Palette' as F:\MLpractrice\ct\output\a\000000 (6)_Random_Color_Palette.jpg
# Processed and saved 000000 (6).png with method 'Gamma_Correction' as F:\MLpractrice\ct\output\a\000000 (6)_Gamma_Correction.jpg
# Processed and saved 000000 (6).png with method 'LUT_Color_Map' as F:\MLpractrice\ct\output\a\000000 (6)_LUT_Color_Map.jpg
# Processed and saved 000000 (6).png with method 'Alpha_Blending' as F:\MLpractrice\ct\output\a\000000 (6)_Alpha_Blending.jpg
# Processed and saved 000000 (6).png with method '3D_Rendering' as F:\MLpractrice\ct\output\a\000000 (6)_3D_Rendering.jpg
# Processed and saved 000000 (6).png with method 'Heatmap_Visualization' as F:\MLpractrice\ct\output\a\000000 (6)_Heatmap_Visualization.jpg
# Processed and saved 000000 (6).png with method '3D_Volume_Rendering' as F:\MLpractrice\ct\output\a\000000 (6)_3D_Volume_Rendering.jpg
# Processed and saved 000000 (6).png with method 'Interactive_Segmentation' as F:\MLpractrice\ct\output\a\000000 (6)_Interactive_Segmentation.jpg
# Processed and saved 00000(6).png with method 'Basic_Color_Map' as F:\MLpractrice\ct\output\b\00000(6)_Basic_Color_Map.jpg
# Processed and saved 00000(6).png with method 'Adaptive_Histogram_Equalization' as F:\MLpractrice\ct\output\b\00000(6)_Adaptive_Histogram_Equalization.jpg
# Processed and saved 00000(6).png with method 'Contrast_Stretching' as F:\MLpractrice\ct\output\b\00000(6)_Contrast_Stretching.jpg
# Processed and saved 00000(6).png with method 'Gaussian_Blur' as F:\MLpractrice\ct\output\b\00000(6)_Gaussian_Blur.jpg
# Processed and saved 00000(6).png with method 'Edge_Detection' as F:\MLpractrice\ct\output\b\00000(6)_Edge_Detection.jpg
# Processed and saved 00000(6).png with method 'Random_Color_Palette' as F:\MLpractrice\ct\output\b\00000(6)_Random_Color_Palette.jpg
# Processed and saved 00000(6).png with method 'Gamma_Correction' as F:\MLpractrice\ct\output\b\00000(6)_Gamma_Correction.jpg
# Processed and saved 00000(6).png with method 'LUT_Color_Map' as F:\MLpractrice\ct\output\b\00000(6)_LUT_Color_Map.jpg
# Processed and saved 00000(6).png with method 'Alpha_Blending' as F:\MLpractrice\ct\output\b\00000(6)_Alpha_Blending.jpg
# Processed and saved 00000(6).png with method '3D_Rendering' as F:\MLpractrice\ct\output\b\00000(6)_3D_Rendering.jpg
# Processed and saved 00000(6).png with method 'Heatmap_Visualization' as F:\MLpractrice\ct\output\b\00000(6)_Heatmap_Visualization.jpg
# Processed and saved 00000(6).png with method '3D_Volume_Rendering' as F:\MLpractrice\ct\output\b\00000(6)_3D_Volume_Rendering.jpg
# Processed and saved 00000(6).png with method 'Interactive_Segmentation' as F:\MLpractrice\ct\output\b\00000(6)_Interactive_Segmentation.jpg
# Processed and saved 000000 (6).png with method 'Basic_Color_Map' as F:\MLpractrice\ct\output\b\000000 (6)_Basic_Color_Map.jpg
# Processed and saved 000000 (6).png with method 'Adaptive_Histogram_Equalization' as F:\MLpractrice\ct\output\b\000000 (6)_Adaptive_Histogram_Equalization.jpg
# Processed and saved 000000 (6).png with method 'Contrast_Stretching' as F:\MLpractrice\ct\output\b\000000 (6)_Contrast_Stretching.jpg
# Processed and saved 000000 (6).png with method 'Gaussian_Blur' as F:\MLpractrice\ct\output\b\000000 (6)_Gaussian_Blur.jpg
# Processed and saved 000000 (6).png with method 'Edge_Detection' as F:\MLpractrice\ct\output\b\000000 (6)_Edge_Detection.jpg
# Processed and saved 000000 (6).png with method 'Random_Color_Palette' as F:\MLpractrice\ct\output\b\000000 (6)_Random_Color_Palette.jpg
# Processed and saved 000000 (6).png with method 'Gamma_Correction' as F:\MLpractrice\ct\output\b\000000 (6)_Gamma_Correction.jpg
# Processed and saved 000000 (6).png with method 'LUT_Color_Map' as F:\MLpractrice\ct\output\b\000000 (6)_LUT_Color_Map.jpg
# Processed and saved 000000 (6).png with method 'Alpha_Blending' as F:\MLpractrice\ct\output\b\000000 (6)_Alpha_Blending.jpg
# Processed and saved 000000 (6).png with method '3D_Rendering' as F:\MLpractrice\ct\output\b\000000 (6)_3D_Rendering.jpg
# Processed and saved 000000 (6).png with method 'Heatmap_Visualization' as F:\MLpractrice\ct\output\b\000000 (6)_Heatmap_Visualization.jpg
# Processed and saved 000000 (6).png with method '3D_Volume_Rendering' as F:\MLpractrice\ct\output\b\000000 (6)_3D_Volume_Rendering.jpg
# Processed and saved 000000 (6).png with method 'Interactive_Segmentation' as F:\MLpractrice\ct\output\b\000000 (6)_Interactive_Segmentation.jpg
# Processing complete.

# %%
import os
import numpy as np
import matplotlib.pyplot as plt
from matplotlib import cm
from PIL import Image
import cv2

# Define input and output directories
input_directory = r'F:\MLpractrice\ct\data2'
output_directory = r'F:\MLpractrice\ct\output'

# Create the output directory if it doesn't exist
if not os.path.exists(output_directory):
    os.makedirs(output_directory)

# Method 1: Basic Color Map Application
def apply_color_map(ct_image, cmap='jet'):
    ct_image_normalized = (ct_image - np.min(ct_image)) / (np.max(ct_image) - np.min(ct_image))
    colored_image = cm.get_cmap(cmap)(ct_image_normalized)
    return (colored_image[:, :, :3] * 255).astype(np.uint8)

# Method 2: Adaptive Histogram Equalization with Color Map
def apply_adaptive_hist_eq(ct_image):
    clahe = cv2.createCLAHE(clipLimit=2.0, tileGridSize=(8, 8))
    enhanced_image = clahe.apply(ct_image)
    return apply_color_map(enhanced_image)

# Method 3: Contrast Stretching with Color Map
def apply_contrast_stretching(ct_image):
    min_val, max_val = np.min(ct_image), np.max(ct_image)
    stretched_image = (ct_image - min_val) / (max_val - min_val)
    return apply_color_map(stretched_image)

# Method 4: Gaussian Blur with Color Map
def apply_gaussian_blur(ct_image):
    blurred_image = cv2.GaussianBlur(ct_image, (5, 5), 0)
    return apply_color_map(blurred_image)

# Method 5: Edge Detection with Canny and Color Map
def apply_edge_detection(ct_image):
    edges = cv2.Canny(ct_image, 100, 200)
    return apply_color_map(edges)

# Method 6: Random Color Palettes (Color Overlay)
def apply_random_color_palette(ct_image):
    random_colored = np.random.rand(*ct_image.shape, 3)
    colored_image = ct_image[:, :, None] * random_colored
    return (colored_image * 255).astype(np.uint8)

# Method 7: Non-Linear Color Stretching (Gamma Correction)
def apply_gamma_correction(ct_image, gamma=1.2):
    gamma_corrected = np.power(ct_image / float(np.max(ct_image)), gamma) * 255
    return apply_color_map(gamma_corrected)

# Method 8: LUT (Lookup Table) Color Mapping (Use predefined LUT)
def apply_lut_color_map(ct_image):
    colored_image = cm.plasma((ct_image - np.min(ct_image)) / (np.max(ct_image) - np.min(ct_image)))
    return (colored_image[:, :, :3] * 255).astype(np.uint8)

# Method 9: Alpha Blending (Threshold-based)
def apply_alpha_blending(ct_image):
    thresholded_image = ct_image > 100
    colored_image = apply_color_map(ct_image)
    thresholded_image_rgb = np.stack([thresholded_image] * 3, axis=-1)
    alpha = 0.5
    final_image = alpha * colored_image + (1 - alpha) * thresholded_image_rgb * 255
    return final_image.astype(np.uint8)

# Method 10: 3D Rendering (Placeholder for 2D images)
def apply_3d_rendering(ct_image):
    return apply_color_map(ct_image)

# Method 11: Heatmap Visualization for Anomaly Detection
def apply_heatmap(ct_image):
    heatmap_image = cm.hot((ct_image - np.min(ct_image)) / (np.max(ct_image) - np.min(ct_image)))
    return (heatmap_image[:, :, :3] * 255).astype(np.uint8)

# Method 12: 3D Volume Rendering (Placeholder for 3D visualization)
def apply_3d_volume_rendering(ct_image):
    return apply_color_map(ct_image)

# Method 13: Interactive Visualization with Segmented Regions
def apply_interactive_visualization(ct_image):
    segmented_image = ct_image > 100
    segmented_colored = cm.plasma(segmented_image.astype(np.float32))
    return (segmented_colored[:, :, :3] * 255).astype(np.uint8)

# Traverse the input directory and process each image in the subfolders
for root, dirs, files in os.walk(input_directory):
    # For each image file in the directory
    for image_file in files:
        if image_file.endswith('.jpg') or image_file.endswith('.png'):
            try:
                # Construct the full input path for the image
                image_path = os.path.join(root, image_file)
                
                # Load the image using PIL
                image = Image.open(image_path)
                
                # Convert image to grayscale
                ct_image = np.array(image.convert('L'))  # Convert to grayscale
                
                # Create the same folder structure in the output directory
                relative_path = os.path.relpath(root, input_directory)  # Get relative folder structure
                output_folder = os.path.join(output_directory, relative_path)
                if not os.path.exists(output_folder):
                    os.makedirs(output_folder)
                
                # Apply all methods and save the output images with sequential names
                methods = [
                    apply_color_map(ct_image, cmap='jet'),
                    apply_adaptive_hist_eq(ct_image),
                    apply_contrast_stretching(ct_image),
                    apply_gaussian_blur(ct_image),
                    apply_edge_detection(ct_image),
                    apply_random_color_palette(ct_image),
                    apply_gamma_correction(ct_image, gamma=1.5),
                    apply_lut_color_map(ct_image),
                    apply_alpha_blending(ct_image),
                    apply_3d_rendering(ct_image),
                    apply_heatmap(ct_image),
                    apply_3d_volume_rendering(ct_image),
                    apply_interactive_visualization(ct_image)
                ]
                
                # Save the images as .jpg in the output folder, using sequential names like 1.jpg, 2.jpg, 3.jpg...
                for idx, result_image in enumerate(methods):
                    # Use the original image file name to avoid overwriting
                    output_image_path = os.path.join(output_folder, f"{os.path.splitext(image_file)[0]}_{idx+1}.jpg")
                    Image.fromarray(result_image).save(output_image_path, format='JPEG')
                    print(f"Processed and saved {image_file} as {output_image_path}")
            
            except Exception as e:
                print(f"Error processing {image_file} in {root}: {e}")

print("Processing complete.")
# Out:
# C:\Users\AIC\AppData\Local\Temp\ipykernel_14264\1734249957.py:19: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap(obj)`` instead.
#   colored_image = cm.get_cmap(cmap)(ct_image_normalized)
# Processed and saved 00000(6).png as F:\MLpractrice\ct\output\a\00000(6)_1.jpg
# Processed and saved 00000(6).png as F:\MLpractrice\ct\output\a\00000(6)_2.jpg
# Processed and saved 00000(6).png as F:\MLpractrice\ct\output\a\00000(6)_3.jpg
# Processed and saved 00000(6).png as F:\MLpractrice\ct\output\a\00000(6)_4.jpg
# Processed and saved 00000(6).png as F:\MLpractrice\ct\output\a\00000(6)_5.jpg
# Processed and saved 00000(6).png as F:\MLpractrice\ct\output\a\00000(6)_6.jpg
# Processed and saved 00000(6).png as F:\MLpractrice\ct\output\a\00000(6)_7.jpg
# Processed and saved 00000(6).png as F:\MLpractrice\ct\output\a\00000(6)_8.jpg
# Processed and saved 00000(6).png as F:\MLpractrice\ct\output\a\00000(6)_9.jpg
# Processed and saved 00000(6).png as F:\MLpractrice\ct\output\a\00000(6)_10.jpg
# Processed and saved 00000(6).png as F:\MLpractrice\ct\output\a\00000(6)_11.jpg
# Processed and saved 00000(6).png as F:\MLpractrice\ct\output\a\00000(6)_12.jpg
# Processed and saved 00000(6).png as F:\MLpractrice\ct\output\a\00000(6)_13.jpg
# Processed and saved 000000 (6).png as F:\MLpractrice\ct\output\a\000000 (6)_1.jpg
# Processed and saved 000000 (6).png as F:\MLpractrice\ct\output\a\000000 (6)_2.jpg
# Processed and saved 000000 (6).png as F:\MLpractrice\ct\output\a\000000 (6)_3.jpg
# Processed and saved 000000 (6).png as F:\MLpractrice\ct\output\a\000000 (6)_4.jpg
# Processed and saved 000000 (6).png as F:\MLpractrice\ct\output\a\000000 (6)_5.jpg
# Processed and saved 000000 (6).png as F:\MLpractrice\ct\output\a\000000 (6)_6.jpg
# Processed and saved 000000 (6).png as F:\MLpractrice\ct\output\a\000000 (6)_7.jpg
# Processed and saved 000000 (6).png as F:\MLpractrice\ct\output\a\000000 (6)_8.jpg
# Processed and saved 000000 (6).png as F:\MLpractrice\ct\output\a\000000 (6)_9.jpg
# Processed and saved 000000 (6).png as F:\MLpractrice\ct\output\a\000000 (6)_10.jpg
# Processed and saved 000000 (6).png as F:\MLpractrice\ct\output\a\000000 (6)_11.jpg
# Processed and saved 000000 (6).png as F:\MLpractrice\ct\output\a\000000 (6)_12.jpg
# Processed and saved 000000 (6).png as F:\MLpractrice\ct\output\a\000000 (6)_13.jpg
# Processed and saved 00000(6).png as F:\MLpractrice\ct\output\b\00000(6)_1.jpg
# Processed and saved 00000(6).png as F:\MLpractrice\ct\output\b\00000(6)_2.jpg
# Processed and saved 00000(6).png as F:\MLpractrice\ct\output\b\00000(6)_3.jpg
# Processed and saved 00000(6).png as F:\MLpractrice\ct\output\b\00000(6)_4.jpg
# Processed and saved 00000(6).png as F:\MLpractrice\ct\output\b\00000(6)_5.jpg
# Processed and saved 00000(6).png as F:\MLpractrice\ct\output\b\00000(6)_6.jpg
# Processed and saved 00000(6).png as F:\MLpractrice\ct\output\b\00000(6)_7.jpg
# Processed and saved 00000(6).png as F:\MLpractrice\ct\output\b\00000(6)_8.jpg
# Processed and saved 00000(6).png as F:\MLpractrice\ct\output\b\00000(6)_9.jpg
# Processed and saved 00000(6).png as F:\MLpractrice\ct\output\b\00000(6)_10.jpg
# Processed and saved 00000(6).png as F:\MLpractrice\ct\output\b\00000(6)_11.jpg
# Processed and saved 00000(6).png as F:\MLpractrice\ct\output\b\00000(6)_12.jpg
# Processed and saved 00000(6).png as F:\MLpractrice\ct\output\b\00000(6)_13.jpg
# Processed and saved 000000 (6).png as F:\MLpractrice\ct\output\b\000000 (6)_1.jpg
# Processed and saved 000000 (6).png as F:\MLpractrice\ct\output\b\000000 (6)_2.jpg
# Processed and saved 000000 (6).png as F:\MLpractrice\ct\output\b\000000 (6)_3.jpg
# Processed and saved 000000 (6).png as F:\MLpractrice\ct\output\b\000000 (6)_4.jpg
# Processed and saved 000000 (6).png as F:\MLpractrice\ct\output\b\000000 (6)_5.jpg
# Processed and saved 000000 (6).png as F:\MLpractrice\ct\output\b\000000 (6)_6.jpg
# Processed and saved 000000 (6).png as F:\MLpractrice\ct\output\b\000000 (6)_7.jpg
# Processed and saved 000000 (6).png as F:\MLpractrice\ct\output\b\000000 (6)_8.jpg
# Processed and saved 000000 (6).png as F:\MLpractrice\ct\output\b\000000 (6)_9.jpg
# Processed and saved 000000 (6).png as F:\MLpractrice\ct\output\b\000000 (6)_10.jpg
# Processed and saved 000000 (6).png as F:\MLpractrice\ct\output\b\000000 (6)_11.jpg
# Processed and saved 000000 (6).png as F:\MLpractrice\ct\output\b\000000 (6)_12.jpg
# Processed and saved 000000 (6).png as F:\MLpractrice\ct\output\b\000000 (6)_13.jpg
# Processing complete.

# %%
import os
import numpy as np
import matplotlib.pyplot as plt
from matplotlib import cm
from PIL import Image
import cv2

# Define input and output directories
input_directory = r'F:\MLpractrice\ct\data2'
output_directory = r'F:\MLpractrice\ct\output'

# Create the output directory if it doesn't exist
if not os.path.exists(output_directory):
    os.makedirs(output_directory)

# Method 1: Basic Color Map Application
def apply_color_map(ct_image, cmap='jet'):
    ct_image_normalized = (ct_image - np.min(ct_image)) / (np.max(ct_image) - np.min(ct_image))
    colored_image = cm.get_cmap(cmap)(ct_image_normalized)
    return (colored_image[:, :, :3] * 255).astype(np.uint8)

# Method 2: Adaptive Histogram Equalization with Color Map
def apply_adaptive_hist_eq(ct_image):
    clahe = cv2.createCLAHE(clipLimit=2.0, tileGridSize=(8, 8))
    enhanced_image = clahe.apply(ct_image)
    return apply_color_map(enhanced_image)

# Method 3: Contrast Stretching with Color Map
def apply_contrast_stretching(ct_image):
    min_val, max_val = np.min(ct_image), np.max(ct_image)
    stretched_image = (ct_image - min_val) / (max_val - min_val)
    return apply_color_map(stretched_image)

# Method 4: Gaussian Blur with Color Map
def apply_gaussian_blur(ct_image):
    blurred_image = cv2.GaussianBlur(ct_image, (5, 5), 0)
    return apply_color_map(blurred_image)

# Method 5: Edge Detection with Canny and Color Map
def apply_edge_detection(ct_image):
    edges = cv2.Canny(ct_image, 100, 200)
    return apply_color_map(edges)

# Method 6: Random Color Palettes (Color Overlay)
def apply_random_color_palette(ct_image):
    random_colored = np.random.rand(*ct_image.shape, 3)
    colored_image = ct_image[:, :, None] * random_colored
    return (colored_image * 255).astype(np.uint8)

# Method 7: Non-Linear Color Stretching (Gamma Correction)
def apply_gamma_correction(ct_image, gamma=1.2):
    gamma_corrected = np.power(ct_image / float(np.max(ct_image)), gamma) * 255
    return apply_color_map(gamma_corrected)

# Method 8: LUT (Lookup Table) Color Mapping (Use predefined LUT)
def apply_lut_color_map(ct_image):
    colored_image = cm.plasma((ct_image - np.min(ct_image)) / (np.max(ct_image) - np.min(ct_image)))
    return (colored_image[:, :, :3] * 255).astype(np.uint8)

# Method 9: Alpha Blending (Threshold-based)
def apply_alpha_blending(ct_image):
    thresholded_image = ct_image > 100
    colored_image = apply_color_map(ct_image)
    thresholded_image_rgb = np.stack([thresholded_image] * 3, axis=-1)
    alpha = 0.5
    final_image = alpha * colored_image + (1 - alpha) * thresholded_image_rgb * 255
    return final_image.astype(np.uint8)

# Method 10: 3D Rendering (Placeholder for 2D images)
def apply_3d_rendering(ct_image):
    return apply_color_map(ct_image)

# Method 11: Heatmap Visualization for Anomaly Detection
def apply_heatmap(ct_image):
    heatmap_image = cm.hot((ct_image - np.min(ct_image)) / (np.max(ct_image) - np.min(ct_image)))
    return (heatmap_image[:, :, :3] * 255).astype(np.uint8)

# Method 12: 3D Volume Rendering (Placeholder for 3D visualization)
def apply_3d_volume_rendering(ct_image):
    return apply_color_map(ct_image)

# Method 13: Interactive Visualization with Segmented Regions
def apply_interactive_visualization(ct_image):
    segmented_image = ct_image > 100
    segmented_colored = cm.plasma(segmented_image.astype(np.float32))
    return (segmented_colored[:, :, :3] * 255).astype(np.uint8)

# Traverse the input directory and process each image in the subfolders
for root, dirs, files in os.walk(input_directory):
    # For each image file in the directory
    for image_file in files:
        if image_file.endswith('.jpg') or image_file.endswith('.png'):
            try:
                # Construct the full input path for the image
                image_path = os.path.join(root, image_file)
                
                # Load the image using PIL
                image = Image.open(image_path)
                
                # Convert image to grayscale
                ct_image = np.array(image.convert('L'))  # Convert to grayscale
                
                # Create the same folder structure in the output directory
                relative_path = os.path.relpath(root, input_directory)  # Get relative folder structure
                output_folder = os.path.join(output_directory, relative_path)
                if not os.path.exists(output_folder):
                    os.makedirs(output_folder)

                # Define a method-to-folder mapping for naming purposes
                method_folders = [
                    "Basic_Color_Map",
                    "Adaptive_Histogram_Equalization",
                    "Contrast_Stretching",
                    "Gaussian_Blur",
                    "Edge_Detection",
                    "Random_Color_Palette",
                    "Gamma_Correction",
                    "LUT_Color_Map",
                    "Alpha_Blending",
                    "3D_Rendering",
                    "Heatmap_Visualization",
                    "3D_Volume_Rendering",
                    "Interactive_Segmentation"
                ]
                
                # Save images in their respective method folders
                for idx, method in enumerate([apply_color_map,
                                              apply_adaptive_hist_eq,
                                              apply_contrast_stretching,
                                              apply_gaussian_blur,
                                              apply_edge_detection,
                                              apply_random_color_palette,
                                              apply_gamma_correction,
                                              apply_lut_color_map,
                                              apply_alpha_blending,
                                              apply_3d_rendering,
                                              apply_heatmap,
                                              apply_3d_volume_rendering,
                                              apply_interactive_visualization]):
                    # Create method folder if it doesn't exist
                    method_folder = os.path.join(output_folder, method_folders[idx])
                    if not os.path.exists(method_folder):
                        os.makedirs(method_folder)
                    
                    # Apply the method to the image
                    result_image = method(ct_image)
                    
                    # Save the image with a sequential number in the method folder
                    image_name_without_extension = os.path.splitext(image_file)[0]
                    output_image_path = os.path.join(method_folder, f"{image_name_without_extension}_{idx+1}.jpg")
                    Image.fromarray(result_image).save(output_image_path, format='JPEG')
                    print(f"Processed and saved {image_file} with method '{method_folders[idx]}' as {output_image_path}")
            
            except Exception as e:
                print(f"Error processing {image_file} in {root}: {e}")

print("Processing complete.")
# Out:
# C:\Users\AIC\AppData\Local\Temp\ipykernel_14264\3231811973.py:19: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap(obj)`` instead.
#   colored_image = cm.get_cmap(cmap)(ct_image_normalized)
# Processed and saved 00000(6).png with method 'Basic_Color_Map' as F:\MLpractrice\ct\output\a\Basic_Color_Map\00000(6)_1.jpg
# Processed and saved 00000(6).png with method 'Adaptive_Histogram_Equalization' as F:\MLpractrice\ct\output\a\Adaptive_Histogram_Equalization\00000(6)_2.jpg
# Processed and saved 00000(6).png with method 'Contrast_Stretching' as F:\MLpractrice\ct\output\a\Contrast_Stretching\00000(6)_3.jpg
# Processed and saved 00000(6).png with method 'Gaussian_Blur' as F:\MLpractrice\ct\output\a\Gaussian_Blur\00000(6)_4.jpg
# Processed and saved 00000(6).png with method 'Edge_Detection' as F:\MLpractrice\ct\output\a\Edge_Detection\00000(6)_5.jpg
# Processed and saved 00000(6).png with method 'Random_Color_Palette' as F:\MLpractrice\ct\output\a\Random_Color_Palette\00000(6)_6.jpg
# Processed and saved 00000(6).png with method 'Gamma_Correction' as F:\MLpractrice\ct\output\a\Gamma_Correction\00000(6)_7.jpg
# Processed and saved 00000(6).png with method 'LUT_Color_Map' as F:\MLpractrice\ct\output\a\LUT_Color_Map\00000(6)_8.jpg
# Processed and saved 00000(6).png with method 'Alpha_Blending' as F:\MLpractrice\ct\output\a\Alpha_Blending\00000(6)_9.jpg
# Processed and saved 00000(6).png with method '3D_Rendering' as F:\MLpractrice\ct\output\a\3D_Rendering\00000(6)_10.jpg
# Processed and saved 00000(6).png with method 'Heatmap_Visualization' as F:\MLpractrice\ct\output\a\Heatmap_Visualization\00000(6)_11.jpg
# Processed and saved 00000(6).png with method '3D_Volume_Rendering' as F:\MLpractrice\ct\output\a\3D_Volume_Rendering\00000(6)_12.jpg
# Processed and saved 00000(6).png with method 'Interactive_Segmentation' as F:\MLpractrice\ct\output\a\Interactive_Segmentation\00000(6)_13.jpg
# Processed and saved 000000 (6).png with method 'Basic_Color_Map' as F:\MLpractrice\ct\output\a\Basic_Color_Map\000000 (6)_1.jpg
# Processed and saved 000000 (6).png with method 'Adaptive_Histogram_Equalization' as F:\MLpractrice\ct\output\a\Adaptive_Histogram_Equalization\000000 (6)_2.jpg
# Processed and saved 000000 (6).png with method 'Contrast_Stretching' as F:\MLpractrice\ct\output\a\Contrast_Stretching\000000 (6)_3.jpg
# Processed and saved 000000 (6).png with method 'Gaussian_Blur' as F:\MLpractrice\ct\output\a\Gaussian_Blur\000000 (6)_4.jpg
# Processed and saved 000000 (6).png with method 'Edge_Detection' as F:\MLpractrice\ct\output\a\Edge_Detection\000000 (6)_5.jpg
# Processed and saved 000000 (6).png with method 'Random_Color_Palette' as F:\MLpractrice\ct\output\a\Random_Color_Palette\000000 (6)_6.jpg
# Processed and saved 000000 (6).png with method 'Gamma_Correction' as F:\MLpractrice\ct\output\a\Gamma_Correction\000000 (6)_7.jpg
# Processed and saved 000000 (6).png with method 'LUT_Color_Map' as F:\MLpractrice\ct\output\a\LUT_Color_Map\000000 (6)_8.jpg
# Processed and saved 000000 (6).png with method 'Alpha_Blending' as F:\MLpractrice\ct\output\a\Alpha_Blending\000000 (6)_9.jpg
# Processed and saved 000000 (6).png with method '3D_Rendering' as F:\MLpractrice\ct\output\a\3D_Rendering\000000 (6)_10.jpg
# Processed and saved 000000 (6).png with method 'Heatmap_Visualization' as F:\MLpractrice\ct\output\a\Heatmap_Visualization\000000 (6)_11.jpg
# Processed and saved 000000 (6).png with method '3D_Volume_Rendering' as F:\MLpractrice\ct\output\a\3D_Volume_Rendering\000000 (6)_12.jpg
# Processed and saved 000000 (6).png with method 'Interactive_Segmentation' as F:\MLpractrice\ct\output\a\Interactive_Segmentation\000000 (6)_13.jpg
# Processed and saved 00000(6).png with method 'Basic_Color_Map' as F:\MLpractrice\ct\output\b\Basic_Color_Map\00000(6)_1.jpg
# Processed and saved 00000(6).png with method 'Adaptive_Histogram_Equalization' as F:\MLpractrice\ct\output\b\Adaptive_Histogram_Equalization\00000(6)_2.jpg
# Processed and saved 00000(6).png with method 'Contrast_Stretching' as F:\MLpractrice\ct\output\b\Contrast_Stretching\00000(6)_3.jpg
# Processed and saved 00000(6).png with method 'Gaussian_Blur' as F:\MLpractrice\ct\output\b\Gaussian_Blur\00000(6)_4.jpg
# Processed and saved 00000(6).png with method 'Edge_Detection' as F:\MLpractrice\ct\output\b\Edge_Detection\00000(6)_5.jpg
# Processed and saved 00000(6).png with method 'Random_Color_Palette' as F:\MLpractrice\ct\output\b\Random_Color_Palette\00000(6)_6.jpg
# Processed and saved 00000(6).png with method 'Gamma_Correction' as F:\MLpractrice\ct\output\b\Gamma_Correction\00000(6)_7.jpg
# Processed and saved 00000(6).png with method 'LUT_Color_Map' as F:\MLpractrice\ct\output\b\LUT_Color_Map\00000(6)_8.jpg
# Processed and saved 00000(6).png with method 'Alpha_Blending' as F:\MLpractrice\ct\output\b\Alpha_Blending\00000(6)_9.jpg
# Processed and saved 00000(6).png with method '3D_Rendering' as F:\MLpractrice\ct\output\b\3D_Rendering\00000(6)_10.jpg
# Processed and saved 00000(6).png with method 'Heatmap_Visualization' as F:\MLpractrice\ct\output\b\Heatmap_Visualization\00000(6)_11.jpg
# Processed and saved 00000(6).png with method '3D_Volume_Rendering' as F:\MLpractrice\ct\output\b\3D_Volume_Rendering\00000(6)_12.jpg
# Processed and saved 00000(6).png with method 'Interactive_Segmentation' as F:\MLpractrice\ct\output\b\Interactive_Segmentation\00000(6)_13.jpg
# Processed and saved 000000 (6).png with method 'Basic_Color_Map' as F:\MLpractrice\ct\output\b\Basic_Color_Map\000000 (6)_1.jpg
# Processed and saved 000000 (6).png with method 'Adaptive_Histogram_Equalization' as F:\MLpractrice\ct\output\b\Adaptive_Histogram_Equalization\000000 (6)_2.jpg
# Processed and saved 000000 (6).png with method 'Contrast_Stretching' as F:\MLpractrice\ct\output\b\Contrast_Stretching\000000 (6)_3.jpg
# Processed and saved 000000 (6).png with method 'Gaussian_Blur' as F:\MLpractrice\ct\output\b\Gaussian_Blur\000000 (6)_4.jpg
# Processed and saved 000000 (6).png with method 'Edge_Detection' as F:\MLpractrice\ct\output\b\Edge_Detection\000000 (6)_5.jpg
# Processed and saved 000000 (6).png with method 'Random_Color_Palette' as F:\MLpractrice\ct\output\b\Random_Color_Palette\000000 (6)_6.jpg
# Processed and saved 000000 (6).png with method 'Gamma_Correction' as F:\MLpractrice\ct\output\b\Gamma_Correction\000000 (6)_7.jpg
# Processed and saved 000000 (6).png with method 'LUT_Color_Map' as F:\MLpractrice\ct\output\b\LUT_Color_Map\000000 (6)_8.jpg
# Processed and saved 000000 (6).png with method 'Alpha_Blending' as F:\MLpractrice\ct\output\b\Alpha_Blending\000000 (6)_9.jpg
# Processed and saved 000000 (6).png with method '3D_Rendering' as F:\MLpractrice\ct\output\b\3D_Rendering\000000 (6)_10.jpg
# Processed and saved 000000 (6).png with method 'Heatmap_Visualization' as F:\MLpractrice\ct\output\b\Heatmap_Visualization\000000 (6)_11.jpg
# Processed and saved 000000 (6).png with method '3D_Volume_Rendering' as F:\MLpractrice\ct\output\b\3D_Volume_Rendering\000000 (6)_12.jpg
# Processed and saved 000000 (6).png with method 'Interactive_Segmentation' as F:\MLpractrice\ct\output\b\Interactive_Segmentation\000000 (6)_13.jpg
# Processing complete.

# %%
https://www.kaggle.com/datasets/mohamedhanyyy/chest-ctscan-images

# %%
import os
import numpy as np
import matplotlib.pyplot as plt
from matplotlib import cm
from PIL import Image
import cv2

# Define input and output directories
input_directory = r'F:\MLpractrice\ct\data'
output_directory = r'F:\MLpractrice\ct\output'

# Create the output directory if it doesn't exist
if not os.path.exists(output_directory):
    os.makedirs(output_directory)

# Method 1: Basic Color Map Application
def apply_color_map(ct_image, cmap='jet'):
    ct_image_normalized = (ct_image - np.min(ct_image)) / (np.max(ct_image) - np.min(ct_image))
    colored_image = cm.get_cmap(cmap)(ct_image_normalized)
    return (colored_image[:, :, :3] * 255).astype(np.uint8)

# Method 2: Adaptive Histogram Equalization with Color Map
def apply_adaptive_hist_eq(ct_image):
    clahe = cv2.createCLAHE(clipLimit=2.0, tileGridSize=(8, 8))
    enhanced_image = clahe.apply(ct_image)
    return apply_color_map(enhanced_image)

# Method 3: Contrast Stretching with Color Map
def apply_contrast_stretching(ct_image):
    min_val, max_val = np.min(ct_image), np.max(ct_image)
    stretched_image = (ct_image - min_val) / (max_val - min_val)
    return apply_color_map(stretched_image)

# Method 4: Gaussian Blur with Color Map
def apply_gaussian_blur(ct_image):
    blurred_image = cv2.GaussianBlur(ct_image, (5, 5), 0)
    return apply_color_map(blurred_image)

# Method 5: Edge Detection with Canny and Color Map
def apply_edge_detection(ct_image):
    edges = cv2.Canny(ct_image, 100, 200)
    return apply_color_map(edges)

# Method 6: Random Color Palettes (Color Overlay)
def apply_random_color_palette(ct_image):
    random_colored = np.random.rand(*ct_image.shape, 3)
    colored_image = ct_image[:, :, None] * random_colored
    return (colored_image * 255).astype(np.uint8)

# Method 7: Non-Linear Color Stretching (Gamma Correction)
def apply_gamma_correction(ct_image, gamma=1.2):
    gamma_corrected = np.power(ct_image / float(np.max(ct_image)), gamma) * 255
    return apply_color_map(gamma_corrected)

# Method 8: LUT (Lookup Table) Color Mapping (Use predefined LUT)
def apply_lut_color_map(ct_image):
    colored_image = cm.plasma((ct_image - np.min(ct_image)) / (np.max(ct_image) - np.min(ct_image)))
    return (colored_image[:, :, :3] * 255).astype(np.uint8)

# Method 9: Alpha Blending (Threshold-based)
def apply_alpha_blending(ct_image):
    thresholded_image = ct_image > 100
    colored_image = apply_color_map(ct_image)
    thresholded_image_rgb = np.stack([thresholded_image] * 3, axis=-1)
    alpha = 0.5
    final_image = alpha * colored_image + (1 - alpha) * thresholded_image_rgb * 255
    return final_image.astype(np.uint8)

# Method 10: 3D Rendering (Placeholder for 2D images)
def apply_3d_rendering(ct_image):
    return apply_color_map(ct_image)

# Method 11: Heatmap Visualization for Anomaly Detection
def apply_heatmap(ct_image):
    heatmap_image = cm.hot((ct_image - np.min(ct_image)) / (np.max(ct_image) - np.min(ct_image)))
    return (heatmap_image[:, :, :3] * 255).astype(np.uint8)

# Method 12: 3D Volume Rendering (Placeholder for 3D visualization)
def apply_3d_volume_rendering(ct_image):
    return apply_color_map(ct_image)

# Method 13: Interactive Visualization with Segmented Regions
def apply_interactive_visualization(ct_image):
    segmented_image = ct_image > 100
    segmented_colored = cm.plasma(segmented_image.astype(np.float32))
    return (segmented_colored[:, :, :3] * 255).astype(np.uint8)

# Traverse the input directory and process each image in the subfolders
for root, dirs, files in os.walk(input_directory):
    # For each image file in the directory
    for image_file in files:
        if image_file.endswith('.jpg') or image_file.endswith('.png'):
            try:
                # Construct the full input path for the image
                image_path = os.path.join(root, image_file)
                
                # Load the image using PIL
                image = Image.open(image_path)
                
                # Convert image to grayscale
                ct_image = np.array(image.convert('L'))  # Convert to grayscale
                
                # Create the same folder structure in the output directory
                relative_path = os.path.relpath(root, input_directory)  # Get relative folder structure
                output_folder = os.path.join(output_directory, relative_path)
                if not os.path.exists(output_folder):
                    os.makedirs(output_folder)

                # Define a method-to-folder mapping for naming purposes
                method_folders = [
                    "Basic_Color_Map",
                    "Adaptive_Histogram_Equalization",
                    "Contrast_Stretching",
                    "Gaussian_Blur",
                    "Edge_Detection",
                    "Random_Color_Palette",
                    "Gamma_Correction",
                    "LUT_Color_Map",
                    "Alpha_Blending",
                    "3D_Rendering",
                    "Heatmap_Visualization",
                    "3D_Volume_Rendering",
                    "Interactive_Segmentation"
                ]
                
                # Save images in their respective method folders
                for idx, method in enumerate([apply_color_map,
                                              apply_adaptive_hist_eq,
                                              apply_contrast_stretching,
                                              apply_gaussian_blur,
                                              apply_edge_detection,
                                              apply_random_color_palette,
                                              apply_gamma_correction,
                                              apply_lut_color_map,
                                              apply_alpha_blending,
                                              apply_3d_rendering,
                                              apply_heatmap,
                                              apply_3d_volume_rendering,
                                              apply_interactive_visualization]):
                    # Create method folder if it doesn't exist
                    method_folder = os.path.join(output_folder, method_folders[idx])
                    if not os.path.exists(method_folder):
                        os.makedirs(method_folder)
                    
                    # Apply the method to the image
                    result_image = method(ct_image)
                    
                    # Save the image with a sequential number in the method folder
                    image_name_without_extension = os.path.splitext(image_file)[0]
                    output_image_path = os.path.join(method_folder, f"{image_name_without_extension}_{idx+1}.jpg")
                    Image.fromarray(result_image).save(output_image_path, format='JPEG')
                    print(f"Processed and saved {image_file} with method '{method_folders[idx]}' as {output_image_path}")
            
            except Exception as e:
                print(f"Error processing {image_file} in {root}: {e}")

print("Processing complete.")
# Out:
# C:\Users\AIC\AppData\Local\Temp\ipykernel_14264\3006613876.py:19: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap(obj)`` instead.
#   colored_image = cm.get_cmap(cmap)(ct_image_normalized)
# Processed and saved 000000 (6).png with method 'Basic_Color_Map' as F:\MLpractrice\ct\output\train\adenocarcinoma_left.lower.lobe_T2_N0_M0_Ib\Basic_Color_Map\000000 (6)_1.jpg
# Processed and saved 000000 (6).png with method 'Adaptive_Histogram_Equalization' as F:\MLpractrice\ct\output\train\adenocarcinoma_left.lower.lobe_T2_N0_M0_Ib\Adaptive_Histogram_Equalization\000000 (6)_2.jpg
# Processed and saved 000000 (6).png with method 'Contrast_Stretching' as F:\MLpractrice\ct\output\train\adenocarcinoma_left.lower.lobe_T2_N0_M0_Ib\Contrast_Stretching\000000 (6)_3.jpg
# Processed and saved 000000 (6).png with method 'Gaussian_Blur' as F:\MLpractrice\ct\output\train\adenocarcinoma_left.lower.lobe_T2_N0_M0_Ib\Gaussian_Blur\000000 (6)_4.jpg
# Processed and saved 000000 (6).png with method 'Edge_Detection' as F:\MLpractrice\ct\output\train\adenocarcinoma_left.lower.lobe_T2_N0_M0_Ib\Edge_Detection\000000 (6)_5.jpg
# Processed and saved 000000 (6).png with method 'Random_Color_Palette' as F:\MLpractrice\ct\output\train\adenocarcinoma_left.lower.lobe_T2_N0_M0_Ib\Random_Color_Palette\000000 (6)_6.jpg
# Processed and saved 000000 (6).png with method 'Gamma_Correction' as F:\MLpractrice\ct\output\train\adenocarcinoma_left.lower.lobe_T2_N0_M0_Ib\Gamma_Correction\000000 (6)_7.jpg
# Processed and saved 000000 (6).png with method 'LUT_Color_Map' as F:\MLpractrice\ct\output\train\adenocarcinoma_left.lower.lobe_T2_N0_M0_Ib\LUT_Color_Map\000000 (6)_8.jpg
# Processed and saved 000000 (6).png with method 'Alpha_Blending' as F:\MLpractrice\ct\output\train\adenocarcinoma_left.lower.lobe_T2_N0_M0_Ib\Alpha_Blending\000000 (6)_9.jpg
# Processed and saved 000000 (6).png with method '3D_Rendering' as F:\MLpractrice\ct\output\train\adenocarcinoma_left.lower.lobe_T2_N0_M0_Ib\3D_Rendering\000000 (6)_10.jpg
# Processed and saved 000000 (6).png with method 'Heatmap_Visualization' as F:\MLpractrice\ct\output\train\adenocarcinoma_left.lower.lobe_T2_N0_M0_Ib\Heatmap_Visualization\000000 (6)_11.jpg
# Processed and saved 000000 (6).png with method '3D_Volume_Rendering' as F:\MLpractrice\ct\output\train\adenocarcinoma_left.lower.lobe_T2_N0_M0_Ib\3D_Volume_Rendering\000000 (6)_12.jpg
# Processed and saved 000000 (6).png with method 'Interactive_Segmentation' as F:\MLpractrice\ct\output\train\adenocarcinoma_left.lower.lobe_T2_N0_M0_Ib\Interactive_Segmentation\000000 (6)_13.jpg
# Processed and saved 000005 (3).png with method 'Basic_Color_Map' as F:\MLpractrice\ct\output\train\adenocarcinoma_left.lower.lobe_T2_N0_M0_Ib\Basic_Color_Map\000005 (3)_1.jpg
# Processed and saved 000005 (3).png with method 'Adaptive_Histogram_Equalization' as F:\MLpractrice\ct\output\train\adenocarcinoma_left.lower.lobe_T2_N0_M0_Ib\Adaptive_Histogram_Equalization\000005 (3)_2.jpg
# Processed and saved 000005 (3).png with method 'Contrast_Stretching' as F:\MLpractrice\ct\output\train\adenocarcinoma_left.lower.lobe_T2_N0_M0_Ib\Contrast_Stretching\000005 (3)_3.jpg
# Processed and saved 000005 (3).png with method 'Gaussian_Blur' as F:\MLpractrice\ct\output\train\adenocarcinoma_left.lower.lobe_T2_N0_M0_Ib\Gaussian_Blur\000005 (3)_4.jpg
# Processed and saved 000005 (3).png with method 'Edge_Detection' as F:\MLpractrice\ct\output\train\adenocarcinoma_left.lower.lobe_T2_N0_M0_Ib\Edge_Detection\000005 (3)_5.jpg
# Processed and saved 000005 (3).png with method 'Random_Color_Palette' as F:\MLpractrice\ct\output\train\adenocarcinoma_left.lower.lobe_T2_N0_M0_Ib\Random_Color_Palette\000005 (3)_6.jpg
# Processed and saved 000005 (3).png with method 'Gamma_Correction' as F:\MLpractrice\ct\output\train\adenocarcinoma_left.lower.lobe_T2_N0_M0_Ib\Gamma_Correction\000005 (3)_7.jpg
# Processed and saved 000005 (3).png with method 'LUT_Color_Map' as F:\MLpractrice\ct\output\train\adenocarcinoma_left.lower.lobe_T2_N0_M0_Ib\LUT_Color_Map\000005 (3)_8.jpg
# Processed and saved 000005 (3).png with method 'Alpha_Blending' as F:\MLpractrice\ct\output\train\adenocarcinoma_left.lower.lobe_T2_N0_M0_Ib\Alpha_Blending\000005 (3)_9.jpg
# Processed and saved 000005 (3).png with method '3D_Rendering' as F:\MLpractrice\ct\output\train\adenocarcinoma_left.lower.lobe_T2_N0_M0_Ib\3D_Rendering\000005 (3)_10.jpg
# Processed and saved 000005 (3).png with method 'Heatmap_Visualization' as F:\MLpractrice\ct\output\train\adenocarcinoma_left.lower.lobe_T2_N0_M0_Ib\Heatmap_Visualization\000005 (3)_11.jpg
# Processed and saved 000005 (3).png with method '3D_Volume_Rendering' as F:\MLpractrice\ct\output\train\adenocarcinoma_left.lower.lobe_T2_N0_M0_Ib\3D_Volume_Rendering\000005 (3)_12.jpg
# Processed and saved 000005 (3).png with method 'Interactive_Segmentation' as F:\MLpractrice\ct\output\train\adenocarcinoma_left.lower.lobe_T2_N0_M0_Ib\Interactive_Segmentation\000005 (3)_13.jpg
# Processed and saved 000005 (9).png with method 'Basic_Color_Map' as F:\MLpractrice\ct\output\train\adenocarcinoma_left.lower.lobe_T2_N0_M0_Ib\Basic_Color_Map\000005 (9)_1.jpg
# Processed and saved 000005 (9).png with method 'Adaptive_Histogram_Equalization' as F:\MLpractrice\ct\output\train\adenocarcinoma_left.lower.lobe_T2_N0_M0_Ib\Adaptive_Histogram_Equalization\000005 (9)_2.jpg
# Processed and saved 000005 (9).png with method 'Contrast_Stretching' as F:\MLpractrice\ct\output\train\adenocarcinoma_left.lower.lobe_T2_N0_M0_Ib\Contrast_Stretching\000005 (9)_3.jpg
# Processed and saved 000005 (9).png with method 'Gaussian_Blur' as F:\MLpractrice\ct\output\train\adenocarcinoma_left.lower.lobe_T2_N0_M0_Ib\Gaussian_Blur\000005 (9)_4.jpg
# Processed and saved 000005 (9).png with method 'Edge_Detection' as F:\MLpractrice\ct\output\train\adenocarcinoma_left.lower.lobe_T2_N0_M0_Ib\Edge_Detection\000005 (9)_5.jpg
# Processed and saved 000005 (9).png with method 'Random_Color_Palette' as F:\MLpractrice\ct\output\train\adenocarcinoma_left.lower.lobe_T2_N0_M0_Ib\Random_Color_Palette\000005 (9)_6.jpg
# Processed and saved 000005 (9).png with method 'Gamma_Correction' as F:\MLpractrice\ct\output\train\adenocarcinoma_left.lower.lobe_T2_N0_M0_Ib\Gamma_Correction\000005 (9)_7.jpg
# Processed and saved 000005 (9).png with method 'LUT_Color_Map' as F:\MLpractrice\ct\output\train\adenocarcinoma_left.lower.lobe_T2_N0_M0_Ib\LUT_Color_Map\000005 (9)_8.jpg
# Processed and saved 000005 (9).png with method 'Alpha_Blending' as F:\MLpractrice\ct\output\train\adenocarcinoma_left.lower.lobe_T2_N0_M0_Ib\Alpha_Blending\000005 (9)_9.jpg
# Processed and saved 000005 (9).png with method '3D_Rendering' as F:\MLpractrice\ct\output\train\adenocarcinoma_left.lower.lobe_T2_N0_M0_Ib\3D_Rendering\000005 (9)_10.jpg
# Processed and saved 000005 (9).png with method 'Heatmap_Visualization' as F:\MLpractrice\ct\output\train\adenocarcinoma_left.lower.lobe_T2_N0_M0_Ib\Heatmap_Visualization\000005 (9)_11.jpg
# Processed and saved 000005 (9).png with method '3D_Volume_Rendering' as F:\MLpractrice\ct\output\train\adenocarcinoma_left.lower.lobe_T2_N0_M0_Ib\3D_Volume_Rendering\000005 (9)_12.jpg
# Processed and saved 000005 (9).png with method 'Interactive_Segmentation' as F:\MLpractrice\ct\output\train\adenocarcinoma_left.lower.lobe_T2_N0_M0_Ib\Interactive_Segmentation\000005 (9)_13.jpg
# Processed and saved 000008 (10).png with method 'Basic_Color_Map' as F:\MLpractrice\ct\output\train\adenocarcinoma_left.lower.lobe_T2_N0_M0_Ib\Basic_Color_Map\000008 (10)_1.jpg
# Processed and saved 000008 (10).png with method 'Adaptive_Histogram_Equalization' as F:\MLpractrice\ct\output\train\adenocarcinoma_left.lower.lobe_T2_N0_M0_Ib\Adaptive_Histogram_Equalization\000008 (10)_2.jpg
# Processed and saved 000008 (10).png with method 'Contrast_Stretching' as F:\MLpractrice\ct\output\train\adenocarcinoma_left.lower.lobe_T2_N0_M0_Ib\Contrast_Stretching\000008 (10)_3.jpg
# Processed and saved 000008 (10).png with method 'Gaussian_Blur' as F:\MLpractrice\ct\output\train\adenocarcinoma_left.lower.lobe_T2_N0_M0_Ib\Gaussian_Blur\000008 (10)_4.jpg
# Processed and saved 000008 (10).png with method 'Edge_Detection' as F:\MLpractrice\ct\output\train\adenocarcinoma_left.lower.lobe_T2_N0_M0_Ib\Edge_Detection\000008 (10)_5.jpg
# Processed and saved 000008 (10).png with method 'Random_Color_Palette' as F:\MLpractrice\ct\output\train\adenocarcinoma_left.lower.lobe_T2_N0_M0_Ib\Random_Color_Palette\000008 (10)_6.jpg
# Processed and saved 000008 (10).png with method 'Gamma_Correction' as F:\MLpractrice\ct\output\train\adenocarcinoma_left.lower.lobe_T2_N0_M0_Ib\Gamma_Correction\000008 (10)_7.jpg
# Processed and saved 000008 (10).png with method 'LUT_Color_Map' as F:\MLpractrice\ct\output\train\adenocarcinoma_left.lower.lobe_T2_N0_M0_Ib\LUT_Color_Map\000008 (10)_8.jpg
# Processed and saved 000008 (10).png with method 'Alpha_Blending' as F:\MLpractrice\ct\output\train\adenocarcinoma_left.lower.lobe_T2_N0_M0_Ib\Alpha_Blending\000008 (10)_9.jpg
# Processed and saved 000008 (10).png with method '3D_Rendering' as F:\MLpractrice\ct\output\train\adenocarcinoma_left.lower.lobe_T2_N0_M0_Ib\3D_Rendering\000008 (10)_10.jpg
# Processed and saved 000008 (10).png with method 'Heatmap_Visualization' as F:\MLpractrice\ct\output\train\adenocarcinoma_left.lower.lobe_T2_N0_M0_Ib\Heatmap_Visualization\000008 (10)_11.jpg
# Processed and saved 000008 (10).png with method '3D_Volume_Rendering' as F:\MLpractrice\ct\output\train\adenocarcinoma_left.lower.lobe_T2_N0_M0_Ib\3D_Volume_Rendering\000008 (10)_12.jpg
# Processed and saved 000008 (10).png with method 'Interactive_Segmentation' as F:\MLpractrice\ct\output\train\adenocarcinoma_left.lower.lobe_T2_N0_M0_Ib\Interactive_Segmentation\000008 (10)_13.jpg
# Processed and saved 000009 (3).png with method 'Basic_Color_Map' as F:\MLpractrice\ct\output\train\adenocarcinoma_left.lower.lobe_T2_N0_M0_Ib\Basic_Color_Map\000009 (3)_1.jpg
# Processed and saved 000009 (3).png with method 'Adaptive_Histogram_Equalization' as F:\MLpractrice\ct\output\train\adenocarcinoma_left.lower.lobe_T2_N0_M0_Ib\Adaptive_Histogram_Equalization\000009 (3)_2.jpg
# Processed and saved 000009 (3).png with method 'Contrast_Stretching' as F:\MLpractrice\ct\output\train\adenocarcinoma_left.lower.lobe_T2_N0_M0_Ib\Contrast_Stretching\000009 (3)_3.jpg
# Processed and saved 000009 (3).png with method 'Gaussian_Blur' as F:\MLpractrice\ct\output\train\adenocarcinoma_left.lower.lobe_T2_N0_M0_Ib\Gaussian_Blur\000009 (3)_4.jpg
# Processed and saved 000009 (3).png with method 'Edge_Detection' as F:\MLpractrice\ct\output\train\adenocarcinoma_left.lower.lobe_T2_N0_M0_Ib\Edge_Detection\000009 (3)_5.jpg
# Processed and saved 000009 (3).png with method 'Random_Color_Palette' as F:\MLpractrice\ct\output\train\adenocarcinoma_left.lower.lobe_T2_N0_M0_Ib\Random_Color_Palette\000009 (3)_6.jpg
# Processed and saved 000009 (3).png with method 'Gamma_Correction' as F:\MLpractrice\ct\output\train\adenocarcinoma_left.lower.lobe_T2_N0_M0_Ib\Gamma_Correction\000009 (3)_7.jpg
# Processed and saved 000009 (3).png with method 'LUT_Color_Map' as F:\MLpractrice\ct\output\train\adenocarcinoma_left.lower.lobe_T2_N0_M0_Ib\LUT_Color_Map\000009 (3)_8.jpg
# Processed and saved 000009 (3).png with method 'Alpha_Blending' as F:\MLpractrice\ct\output\train\adenocarcinoma_left.lower.lobe_T2_N0_M0_Ib\Alpha_Blending\000009 (3)_9.jpg
# Processed and saved 000009 (3).png with method '3D_Rendering' as F:\MLpractrice\ct\output\train\adenocarcinoma_left.lower.lobe_T2_N0_M0_Ib\3D_Rendering\000009 (3)_10.jpg
# Processed and saved 000009 (3).png with method 'Heatmap_Visualization' as F:\MLpractrice\ct\output\train\adenocarcinoma_left.lower.lobe_T2_N0_M0_Ib\Heatmap_Visualization\000009 (3)_11.jpg
# Processed and saved 000009 (3).png with method '3D_Volume_Rendering' as F:\MLpractrice\ct\output\train\adenocarcinoma_left.lower.lobe_T2_N0_M0_Ib\3D_Volume_Rendering\000009 (3)_12.jpg
# Processed and saved 000009 (3).png with method 'Interactive_Segmentation' as F:\MLpractrice\ct\output\train\adenocarcinoma_left.lower.lobe_T2_N0_M0_Ib\Interactive_Segmentation\000009 (3)_13.jpg
# Processed and saved 000009 (7).png with method 'Basic_Color_Map' as F:\MLpractrice\ct\output\train\adenocarcinoma_left.lower.lobe_T2_N0_M0_Ib\Basic_Color_Map\000009 (7)_1.jpg
# Processed and saved 000009 (7).png with method 'Adaptive_Histogram_Equalization' as F:\MLpractrice\ct\output\train\adenocarcinoma_left.lower.lobe_T2_N0_M0_Ib\Adaptive_Histogram_Equalization\000009 (7)_2.jpg
# Processed and saved 000009 (7).png with method 'Contrast_Stretching' as F:\MLpractrice\ct\output\train\adenocarcinoma_left.lower.lobe_T2_N0_M0_Ib\Contrast_Stretching\000009 (7)_3.jpg
# Processed and saved 000009 (7).png with method 'Gaussian_Blur' as F:\MLpractrice\ct\output\train\adenocarcinoma_left.lower.lobe_T2_N0_M0_Ib\Gaussian_Blur\000009 (7)_4.jpg
# Processed and saved 000009 (7).png with method 'Edge_Detection' as F:\MLpractrice\ct\output\train\adenocarcinoma_left.lower.lobe_T2_N0_M0_Ib\Edge_Detection\000009 (7)_5.jpg
# Processed and saved 000009 (7).png with method 'Random_Color_Palette' as F:\MLpractrice\ct\output\train\adenocarcinoma_left.lower.lobe_T2_N0_M0_Ib\Random_Color_Palette\000009 (7)_6.jpg
# Processed and saved 000009 (7).png with method 'Gamma_Correction' as F:\MLpractrice\ct\output\train\adenocarcinoma_left.lower.lobe_T2_N0_M0_Ib\Gamma_Correction\000009 (7)_7.jpg
# Processed and saved 000009 (7).png with method 'LUT_Color_Map' as F:\MLpractrice\ct\output\train\adenocarcinoma_left.lower.lobe_T2_N0_M0_Ib\LUT_Color_Map\000009 (7)_8.jpg
# Processed and saved 000009 (7).png with method 'Alpha_Blending' as F:\MLpractrice\ct\output\train\adenocarcinoma_left.lower.lobe_T2_N0_M0_Ib\Alpha_Blending\000009 (7)_9.jpg
# Processed and saved 000009 (7).png with method '3D_Rendering' as F:\MLpractrice\ct\output\train\adenocarcinoma_left.lower.lobe_T2_N0_M0_Ib\3D_Rendering\000009 (7)_10.jpg
# Processed and saved 000009 (7).png with method 'Heatmap_Visualization' as F:\MLpractrice\ct\output\train\adenocarcinoma_left.lower.lobe_T2_N0_M0_Ib\Heatmap_Visualization\000009 (7)_11.jpg
# Processed and saved 000009 (7).png with method '3D_Volume_Rendering' as F:\MLpractrice\ct\output\train\adenocarcinoma_left.lower.lobe_T2_N0_M0_Ib\3D_Volume_Rendering\000009 (7)_12.jpg
# Processed and saved 000009 (7).png with method 'Interactive_Segmentation' as F:\MLpractrice\ct\output\train\adenocarcinoma_left.lower.lobe_T2_N0_M0_Ib\Interactive_Segmentation\000009 (7)_13.jpg
# Processed and saved 000013 (4).png with method 'Basic_Color_Map' as F:\MLpractrice\ct\output\train\adenocarcinoma_left.lower.lobe_T2_N0_M0_Ib\Basic_Color_Map\000013 (4)_1.jpg
# Processed and saved 000013 (4).png with method 'Adaptive_Histogram_Equalization' as F:\MLpractrice\ct\output\train\adenocarcinoma_left.lower.lobe_T2_N0_M0_Ib\Adaptive_Histogram_Equalization\000013 (4)_2.jpg
# Processed and saved 000013 (4).png with method 'Contrast_Stretching' as F:\MLpractrice\ct\output\train\adenocarcinoma_left.lower.lobe_T2_N0_M0_Ib\Contrast_Stretching\000013 (4)_3.jpg
# Processed and saved 000013 (4).png with method 'Gaussian_Blur' as F:\MLpractrice\ct\output\train\adenocarcinoma_left.lower.lobe_T2_N0_M0_Ib\Gaussian_Blur\000013 (4)_4.jpg
# Processed and saved 000013 (4).png with method 'Edge_Detection' as F:\MLpractrice\ct\output\train\adenocarcinoma_left.lower.lobe_T2_N0_M0_Ib\Edge_Detection\000013 (4)_5.jpg
# Processed and saved 000013 (4).png with method 'Random_Color_Palette' as F:\MLpractrice\ct\output\train\adenocarcinoma_left.lower.lobe_T2_N0_M0_Ib\Random_Color_Palette\000013 (4)_6.jpg
# Processed and saved 000013 (4).png with method 'Gamma_Correction' as F:\MLpractrice\ct\output\train\adenocarcinoma_left.lower.lobe_T2_N0_M0_Ib\Gamma_Correction\000013 (4)_7.jpg
# Processed and saved 000013 (4).png with method 'LUT_Color_Map' as F:\MLpractrice\ct\output\train\adenocarcinoma_left.lower.lobe_T2_N0_M0_Ib\LUT_Color_Map\000013 (4)_8.jpg
# Processed and saved 000013 (4).png with method 'Alpha_Blending' as F:\MLpractrice\ct\output\train\adenocarcinoma_left.lower.lobe_T2_N0_M0_Ib\Alpha_Blending\000013 (4)_9.jpg
# Processed and saved 000013 (4).png with method '3D_Rendering' as F:\MLpractrice\ct\output\train\adenocarcinoma_left.lower.lobe_T2_N0_M0_Ib\3D_Rendering\000013 (4)_10.jpg
# Processed and saved 000013 (4).png with method 'Heatmap_Visualization' as F:\MLpractrice\ct\output\train\adenocarcinoma_left.lower.lobe_T2_N0_M0_Ib\Heatmap_Visualization\000013 (4)_11.jpg
# Processed and saved 000013 (4).png with method '3D_Volume_Rendering' as F:\MLpractrice\ct\output\train\adenocarcinoma_left.lower.lobe_T2_N0_M0_Ib\3D_Volume_Rendering\000013 (4)_12.jpg
# Processed and saved 000013 (4).png with method 'Interactive_Segmentation' as F:\MLpractrice\ct\output\train\adenocarcinoma_left.lower.lobe_T2_N0_M0_Ib\Interactive_Segmentation\000013 (4)_13.jpg
# Processed and saved 000013 (8).png with method 'Basic_Color_Map' as F:\MLpractrice\ct\output\train\adenocarcinoma_left.lower.lobe_T2_N0_M0_Ib\Basic_Color_Map\000013 (8)_1.jpg
# Processed and saved 000013 (8).png with method 'Adaptive_Histogram_Equalization' as F:\MLpractrice\ct\output\train\adenocarcinoma_left.lower.lobe_T2_N0_M0_Ib\Adaptive_Histogram_Equalization\000013 (8)_2.jpg
# Processed and saved 000013 (8).png with method 'Contrast_Stretching' as F:\MLpractrice\ct\output\train\adenocarcinoma_left.lower.lobe_T2_N0_M0_Ib\Contrast_Stretching\000013 (8)_3.jpg
# Processed and saved 000013 (8).png with method 'Gaussian_Blur' as F:\MLpractrice\ct\output\train\adenocarcinoma_left.lower.lobe_T2_N0_M0_Ib\Gaussian_Blur\000013 (8)_4.jpg
# Processed and saved 000013 (8).png with method 'Edge_Detection' as F:\MLpractrice\ct\output\train\adenocarcinoma_left.lower.lobe_T2_N0_M0_Ib\Edge_Detection\000013 (8)_5.jpg
# Processed and saved 000013 (8).png with method 'Random_Color_Palette' as F:\MLpractrice\ct\output\train\adenocarcinoma_left.lower.lobe_T2_N0_M0_Ib\Random_Color_Palette\000013 (8)_6.jpg
# Processed and saved 000013 (8).png with method 'Gamma_Correction' as F:\MLpractrice\ct\output\train\adenocarcinoma_left.lower.lobe_T2_N0_M0_Ib\Gamma_Correction\000013 (8)_7.jpg
# Processed and saved 000013 (8).png with method 'LUT_Color_Map' as F:\MLpractrice\ct\output\train\adenocarcinoma_left.lower.lobe_T2_N0_M0_Ib\LUT_Color_Map\000013 (8)_8.jpg
# Processed and saved 000013 (8).png with method 'Alpha_Blending' as F:\MLpractrice\ct\output\train\adenocarcinoma_left.lower.lobe_T2_N0_M0_Ib\Alpha_Blending\000013 (8)_9.jpg
# Processed and saved 000013 (8).png with method '3D_Rendering' as F:\MLpractrice\ct\output\train\adenocarcinoma_left.lower.lobe_T2_N0_M0_Ib\3D_Rendering\000013 (8)_10.jpg
# Processed and saved 000013 (8).png with method 'Heatmap_Visualization' as F:\MLpractrice\ct\output\train\adenocarcinoma_left.lower.lobe_T2_N0_M0_Ib\Heatmap_Visualization\000013 (8)_11.jpg
# Processed and saved 000013 (8).png with method '3D_Volume_Rendering' as F:\MLpractrice\ct\output\train\adenocarcinoma_left.lower.lobe_T2_N0_M0_Ib\3D_Volume_Rendering\000013 (8)_12.jpg
# Processed and saved 000013 (8).png with method 'Interactive_Segmentation' as F:\MLpractrice\ct\output\train\adenocarcinoma_left.lower.lobe_T2_N0_M0_Ib\Interactive_Segmentation\000013 (8)_13.jpg
# Processed and saved 000014 (7).png with method 'Basic_Color_Map' as F:\MLpractrice\ct\output\train\adenocarcinoma_left.lower.lobe_T2_N0_M0_Ib\Basic_Color_Map\000014 (7)_1.jpg
# Processed and saved 000014 (7).png with method 'Adaptive_Histogram_Equalization' as F:\MLpractrice\ct\output\train\adenocarcinoma_left.lower.lobe_T2_N0_M0_Ib\Adaptive_Histogram_Equalization\000014 (7)_2.jpg
# Processed and saved 000014 (7).png with method 'Contrast_Stretching' as F:\MLpractrice\ct\output\train\adenocarcinoma_left.lower.lobe_T2_N0_M0_Ib\Contrast_Stretching\000014 (7)_3.jpg
# Processed and saved 000014 (7).png with method 'Gaussian_Blur' as F:\MLpractrice\ct\output\train\adenocarcinoma_left.lower.lobe_T2_N0_M0_Ib\Gaussian_Blur\000014 (7)_4.jpg
# Processed and saved 000014 (7).png with method 'Edge_Detection' as F:\MLpractrice\ct\output\train\adenocarcinoma_left.lower.lobe_T2_N0_M0_Ib\Edge_Detection\000014 (7)_5.jpg
# Processed and saved 000014 (7).png with method 'Random_Color_Palette' as F:\MLpractrice\ct\output\train\adenocarcinoma_left.lower.lobe_T2_N0_M0_Ib\Random_Color_Palette\000014 (7)_6.jpg
# Processed and saved 000014 (7).png with method 'Gamma_Correction' as F:\MLpractrice\ct\output\train\adenocarcinoma_left.lower.lobe_T2_N0_M0_Ib\Gamma_Correction\000014 (7)_7.jpg
# Processed and saved 000014 (7).png with method 'LUT_Color_Map' as F:\MLpractrice\ct\output\train\adenocarcinoma_left.lower.lobe_T2_N0_M0_Ib\LUT_Color_Map\000014 (7)_8.jpg
# Processed and saved 000014 (7).png with method 'Alpha_Blending' as F:\MLpractrice\ct\output\train\adenocarcinoma_left.lower.lobe_T2_N0_M0_Ib\Alpha_Blending\000014 (7)_9.jpg
# Processed and saved 000014 (7).png with method '3D_Rendering' as F:\MLpractrice\ct\output\train\adenocarcinoma_left.lower.lobe_T2_N0_M0_Ib\3D_Rendering\000014 (7)_10.jpg
# Processed and saved 000014 (7).png with method 'Heatmap_Visualization' as F:\MLpractrice\ct\output\train\adenocarcinoma_left.lower.lobe_T2_N0_M0_Ib\Heatmap_Visualization\000014 (7)_11.jpg
# Processed and saved 000014 (7).png with method '3D_Volume_Rendering' as F:\MLpractrice\ct\output\train\adenocarcinoma_left.lower.lobe_T2_N0_M0_Ib\3D_Volume_Rendering\000014 (7)_12.jpg
# Processed and saved 000014 (7).png with method 'Interactive_Segmentation' as F:\MLpractrice\ct\output\train\adenocarcinoma_left.lower.lobe_T2_N0_M0_Ib\Interactive_Segmentation\000014 (7)_13.jpg
# Processed and saved 000015 (10).png with method 'Basic_Color_Map' as F:\MLpractrice\ct\output\train\adenocarcinoma_left.lower.lobe_T2_N0_M0_Ib\Basic_Color_Map\000015 (10)_1.jpg
# Processed and saved 000015 (10).png with method 'Adaptive_Histogram_Equalization' as F:\MLpractrice\ct\output\train\adenocarcinoma_left.lower.lobe_T2_N0_M0_Ib\Adaptive_Histogram_Equalization\000015 (10)_2.jpg
# Processed and saved 000015 (10).png with method 'Contrast_Stretching' as F:\MLpractrice\ct\output\train\adenocarcinoma_left.lower.lobe_T2_N0_M0_Ib\Contrast_Stretching\000015 (10)_3.jpg
# Processed and saved 000015 (10).png with method 'Gaussian_Blur' as F:\MLpractrice\ct\output\train\adenocarcinoma_left.lower.lobe_T2_N0_M0_Ib\Gaussian_Blur\000015 (10)_4.jpg
# Processed and saved 000015 (10).png with method 'Edge_Detection' as F:\MLpractrice\ct\output\train\adenocarcinoma_left.lower.lobe_T2_N0_M0_Ib\Edge_Detection\000015 (10)_5.jpg
# Processed and saved 000015 (10).png with method 'Random_Color_Palette' as F:\MLpractrice\ct\output\train\adenocarcinoma_left.lower.lobe_T2_N0_M0_Ib\Random_Color_Palette\000015 (10)_6.jpg
# Processed and saved 000015 (10).png with method 'Gamma_Correction' as F:\MLpractrice\ct\output\train\adenocarcinoma_left.lower.lobe_T2_N0_M0_Ib\Gamma_Correction\000015 (10)_7.jpg
# Processed and saved 000015 (10).png with method 'LUT_Color_Map' as F:\MLpractrice\ct\output\train\adenocarcinoma_left.lower.lobe_T2_N0_M0_Ib\LUT_Color_Map\000015 (10)_8.jpg
# Processed and saved 000015 (10).png with method 'Alpha_Blending' as F:\MLpractrice\ct\output\train\adenocarcinoma_left.lower.lobe_T2_N0_M0_Ib\Alpha_Blending\000015 (10)_9.jpg
# Processed and saved 000015 (10).png with method '3D_Rendering' as F:\MLpractrice\ct\output\train\adenocarcinoma_left.lower.lobe_T2_N0_M0_Ib\3D_Rendering\000015 (10)_10.jpg
# Processed and saved 000015 (10).png with method 'Heatmap_Visualization' as F:\MLpractrice\ct\output\train\adenocarcinoma_left.lower.lobe_T2_N0_M0_Ib\Heatmap_Visualization\000015 (10)_11.jpg
# Processed and saved 000015 (10).png with method '3D_Volume_Rendering' as F:\MLpractrice\ct\output\train\adenocarcinoma_left.lower.lobe_T2_N0_M0_Ib\3D_Volume_Rendering\000015 (10)_12.jpg
# Processed and saved 000015 (10).png with method 'Interactive_Segmentation' as F:\MLpractrice\ct\output\train\adenocarcinoma_left.lower.lobe_T2_N0_M0_Ib\Interactive_Segmentation\000015 (10)_13.jpg
# Processed and saved 000015 (4).png with method 'Basic_Color_Map' as F:\MLpractrice\ct\output\train\adenocarcinoma_left.lower.lobe_T2_N0_M0_Ib\Basic_Color_Map\000015 (4)_1.jpg
# Processed and saved 000015 (4).png with method 'Adaptive_Histogram_Equalization' as F:\MLpractrice\ct\output\train\adenocarcinoma_left.lower.lobe_T2_N0_M0_Ib\Adaptive_Histogram_Equalization\000015 (4)_2.jpg
# Processed and saved 000015 (4).png with method 'Contrast_Stretching' as F:\MLpractrice\ct\output\train\adenocarcinoma_left.lower.lobe_T2_N0_M0_Ib\Contrast_Stretching\000015 (4)_3.jpg
# Processed and saved 000015 (4).png with method 'Gaussian_Blur' as F:\MLpractrice\ct\output\train\adenocarcinoma_left.lower.lobe_T2_N0_M0_Ib\Gaussian_Blur\000015 (4)_4.jpg
# Processed and saved 000015 (4).png with method 'Edge_Detection' as F:\MLpractrice\ct\output\train\adenocarcinoma_left.lower.lobe_T2_N0_M0_Ib\Edge_Detection\000015 (4)_5.jpg
# Processed and saved 000015 (4).png with method 'Random_Color_Palette' as F:\MLpractrice\ct\output\train\adenocarcinoma_left.lower.lobe_T2_N0_M0_Ib\Random_Color_Palette\000015 (4)_6.jpg
# Processed and saved 000015 (4).png with method 'Gamma_Correction' as F:\MLpractrice\ct\output\train\adenocarcinoma_left.lower.lobe_T2_N0_M0_Ib\Gamma_Correction\000015 (4)_7.jpg
# Processed and saved 000015 (4).png with method 'LUT_Color_Map' as F:\MLpractrice\ct\output\train\adenocarcinoma_left.lower.lobe_T2_N0_M0_Ib\LUT_Color_Map\000015 (4)_8.jpg
# Processed and saved 000015 (4).png with method 'Alpha_Blending' as F:\MLpractrice\ct\output\train\adenocarcinoma_left.lower.lobe_T2_N0_M0_Ib\Alpha_Blending\000015 (4)_9.jpg
# Processed and saved 000015 (4).png with method '3D_Rendering' as F:\MLpractrice\ct\output\train\adenocarcinoma_left.lower.lobe_T2_N0_M0_Ib\3D_Rendering\000015 (4)_10.jpg
# Processed and saved 000015 (4).png with method 'Heatmap_Visualization' as F:\MLpractrice\ct\output\train\adenocarcinoma_left.lower.lobe_T2_N0_M0_Ib\Heatmap_Visualization\000015 (4)_11.jpg
# Processed and saved 000015 (4).png with method '3D_Volume_Rendering' as F:\MLpractrice\ct\output\train\adenocarcinoma_left.lower.lobe_T2_N0_M0_Ib\3D_Volume_Rendering\000015 (4)_12.jpg
# Processed and saved 000015 (4).png with method 'Interactive_Segmentation' as F:\MLpractrice\ct\output\train\adenocarcinoma_left.lower.lobe_T2_N0_M0_Ib\Interactive_Segmentation\000015 (4)_13.jpg
# Processed and saved 000015 (9).png with method 'Basic_Color_Map' as F:\MLpractrice\ct\output\train\adenocarcinoma_left.lower.lobe_T2_N0_M0_Ib\Basic_Color_Map\000015 (9)_1.jpg
# Processed and saved 000015 (9).png with method 'Adaptive_Histogram_Equalization' as F:\MLpractrice\ct\output\train\adenocarcinoma_left.lower.lobe_T2_N0_M0_Ib\Adaptive_Histogram_Equalization\000015 (9)_2.jpg
# Processed and saved 000015 (9).png with method 'Contrast_Stretching' as F:\MLpractrice\ct\output\train\adenocarcinoma_left.lower.lobe_T2_N0_M0_Ib\Contrast_Stretching\000015 (9)_3.jpg
# Processed and saved 000015 (9).png with method 'Gaussian_Blur' as F:\MLpractrice\ct\output\train\adenocarcinoma_left.lower.lobe_T2_N0_M0_Ib\Gaussian_Blur\000015 (9)_4.jpg
# Processed and saved 000015 (9).png with method 'Edge_Detection' as F:\MLpractrice\ct\output\train\adenocarcinoma_left.lower.lobe_T2_N0_M0_Ib\Edge_Detection\000015 (9)_5.jpg
# Processed and saved 000015 (9).png with method 'Random_Color_Palette' as F:\MLpractrice\ct\output\train\adenocarcinoma_left.lower.lobe_T2_N0_M0_Ib\Random_Color_Palette\000015 (9)_6.jpg
# Processed and saved 000015 (9).png with method 'Gamma_Correction' as F:\MLpractrice\ct\output\train\adenocarcinoma_left.lower.lobe_T2_N0_M0_Ib\Gamma_Correction\000015 (9)_7.jpg
# Processed and saved 000015 (9).png with method 'LUT_Color_Map' as F:\MLpractrice\ct\output\train\adenocarcinoma_left.lower.lobe_T2_N0_M0_Ib\LUT_Color_Map\000015 (9)_8.jpg
# Processed and saved 000015 (9).png with method 'Alpha_Blending' as F:\MLpractrice\ct\output\train\adenocarcinoma_left.lower.lobe_T2_N0_M0_Ib\Alpha_Blending\000015 (9)_9.jpg
# Processed and saved 000015 (9).png with method '3D_Rendering' as F:\MLpractrice\ct\output\train\adenocarcinoma_left.lower.lobe_T2_N0_M0_Ib\3D_Rendering\000015 (9)_10.jpg
# Processed and saved 000015 (9).png with method 'Heatmap_Visualization' as F:\MLpractrice\ct\output\train\adenocarcinoma_left.lower.lobe_T2_N0_M0_Ib\Heatmap_Visualization\000015 (9)_11.jpg
# Processed and saved 000015 (9).png with method '3D_Volume_Rendering' as F:\MLpractrice\ct\output\train\adenocarcinoma_left.lower.lobe_T2_N0_M0_Ib\3D_Volume_Rendering\000015 (9)_12.jpg
# Processed and saved 000015 (9).png with method 'Interactive_Segmentation' as F:\MLpractrice\ct\output\train\adenocarcinoma_left.lower.lobe_T2_N0_M0_Ib\Interactive_Segmentation\000015 (9)_13.jpg
# Processed and saved 000016 (9).png with method 'Basic_Color_Map' as F:\MLpractrice\ct\output\train\adenocarcinoma_left.lower.lobe_T2_N0_M0_Ib\Basic_Color_Map\000016 (9)_1.jpg
# Processed and saved 000016 (9).png with method 'Adaptive_Histogram_Equalization' as F:\MLpractrice\ct\output\train\adenocarcinoma_left.lower.lobe_T2_N0_M0_Ib\Adaptive_Histogram_Equalization\000016 (9)_2.jpg
# Processed and saved 000016 (9).png with method 'Contrast_Stretching' as F:\MLpractrice\ct\output\train\adenocarcinoma_left.lower.lobe_T2_N0_M0_Ib\Contrast_Stretching\000016 (9)_3.jpg
# Processed and saved 000016 (9).png with method 'Gaussian_Blur' as F:\MLpractrice\ct\output\train\adenocarcinoma_left.lower.lobe_T2_N0_M0_Ib\Gaussian_Blur\000016 (9)_4.jpg
# Processed and saved 000016 (9).png with method 'Edge_Detection' as F:\MLpractrice\ct\output\train\adenocarcinoma_left.lower.lobe_T2_N0_M0_Ib\Edge_Detection\000016 (9)_5.jpg
# Processed and saved 000016 (9).png with method 'Random_Color_Palette' as F:\MLpractrice\ct\output\train\adenocarcinoma_left.lower.lobe_T2_N0_M0_Ib\Random_Color_Palette\000016 (9)_6.jpg
# Processed and saved 000016 (9).png with method 'Gamma_Correction' as F:\MLpractrice\ct\output\train\adenocarcinoma_left.lower.lobe_T2_N0_M0_Ib\Gamma_Correction\000016 (9)_7.jpg
# Processed and saved 000016 (9).png with method 'LUT_Color_Map' as F:\MLpractrice\ct\output\train\adenocarcinoma_left.lower.lobe_T2_N0_M0_Ib\LUT_Color_Map\000016 (9)_8.jpg
# Processed and saved 000016 (9).png with method 'Alpha_Blending' as F:\MLpractrice\ct\output\train\adenocarcinoma_left.lower.lobe_T2_N0_M0_Ib\Alpha_Blending\000016 (9)_9.jpg
# Processed and saved 000016 (9).png with method '3D_Rendering' as F:\MLpractrice\ct\output\train\adenocarcinoma_left.lower.lobe_T2_N0_M0_Ib\3D_Rendering\000016 (9)_10.jpg
# Processed and saved 000016 (9).png with method 'Heatmap_Visualization' as F:\MLpractrice\ct\output\train\adenocarcinoma_left.lower.lobe_T2_N0_M0_Ib\Heatmap_Visualization\000016 (9)_11.jpg
# Processed and saved 000016 (9).png with method '3D_Volume_Rendering' as F:\MLpractrice\ct\output\train\adenocarcinoma_left.lower.lobe_T2_N0_M0_Ib\3D_Volume_Rendering\000016 (9)_12.jpg
# Processed and saved 000016 (9).png with method 'Interactive_Segmentation' as F:\MLpractrice\ct\output\train\adenocarcinoma_left.lower.lobe_T2_N0_M0_Ib\Interactive_Segmentation\000016 (9)_13.jpg
# Processed and saved 000017 (6).png with method 'Basic_Color_Map' as F:\MLpractrice\ct\output\train\adenocarcinoma_left.lower.lobe_T2_N0_M0_Ib\Basic_Color_Map\000017 (6)_1.jpg
# Processed and saved 000017 (6).png with method 'Adaptive_Histogram_Equalization' as F:\MLpractrice\ct\output\train\adenocarcinoma_left.lower.lobe_T2_N0_M0_Ib\Adaptive_Histogram_Equalization\000017 (6)_2.jpg
# Processed and saved 000017 (6).png with method 'Contrast_Stretching' as F:\MLpractrice\ct\output\train\adenocarcinoma_left.lower.lobe_T2_N0_M0_Ib\Contrast_Stretching\000017 (6)_3.jpg
# Processed and saved 000017 (6).png with method 'Gaussian_Blur' as F:\MLpractrice\ct\output\train\adenocarcinoma_left.lower.lobe_T2_N0_M0_Ib\Gaussian_Blur\000017 (6)_4.jpg
# Processed and saved 000017 (6).png with method 'Edge_Detection' as F:\MLpractrice\ct\output\train\adenocarcinoma_left.lower.lobe_T2_N0_M0_Ib\Edge_Detection\000017 (6)_5.jpg
# Processed and saved 000017 (6).png with method 'Random_Color_Palette' as F:\MLpractrice\ct\output\train\adenocarcinoma_left.lower.lobe_T2_N0_M0_Ib\Random_Color_Palette\000017 (6)_6.jpg
# Processed and saved 000017 (6).png with method 'Gamma_Correction' as F:\MLpractrice\ct\output\train\adenocarcinoma_left.lower.lobe_T2_N0_M0_Ib\Gamma_Correction\000017 (6)_7.jpg
# Processed and saved 000017 (6).png with method 'LUT_Color_Map' as F:\MLpractrice\ct\output\train\adenocarcinoma_left.lower.lobe_T2_N0_M0_Ib\LUT_Color_Map\000017 (6)_8.jpg
# Processed and saved 000017 (6).png with method 'Alpha_Blending' as F:\MLpractrice\ct\output\train\adenocarcinoma_left.lower.lobe_T2_N0_M0_Ib\Alpha_Blending\000017 (6)_9.jpg
# Processed and saved 000017 (6).png with method '3D_Rendering' as F:\MLpractrice\ct\output\train\adenocarcinoma_left.lower.lobe_T2_N0_M0_Ib\3D_Rendering\000017 (6)_10.jpg
# Processed and saved 000017 (6).png with method 'Heatmap_Visualization' as F:\MLpractrice\ct\output\train\adenocarcinoma_left.lower.lobe_T2_N0_M0_Ib\Heatmap_Visualization\000017 (6)_11.jpg
# Processed and saved 000017 (6).png with method '3D_Volume_Rendering' as F:\MLpractrice\ct\output\train\adenocarcinoma_left.lower.lobe_T2_N0_M0_Ib\3D_Volume_Rendering\000017 (6)_12.jpg
# Processed and saved 000017 (6).png with method 'Interactive_Segmentation' as F:\MLpractrice\ct\output\train\adenocarcinoma_left.lower.lobe_T2_N0_M0_Ib\Interactive_Segmentation\000017 (6)_13.jpg
# Processed and saved 000017 (8).png with method 'Basic_Color_Map' as F:\MLpractrice\ct\output\train\adenocarcinoma_left.lower.lobe_T2_N0_M0_Ib\Basic_Color_Map\000017 (8)_1.jpg
# Processed and saved 000017 (8).png with method 'Adaptive_Histogram_Equalization' as F:\MLpractrice\ct\output\train\adenocarcinoma_left.lower.lobe_T2_N0_M0_Ib\Adaptive_Histogram_Equalization\000017 (8)_2.jpg
# Processed and saved 000017 (8).png with method 'Contrast_Stretching' as F:\MLpractrice\ct\output\train\adenocarcinoma_left.lower.lobe_T2_N0_M0_Ib\Contrast_Stretching\000017 (8)_3.jpg
# Processed and saved 000017 (8).png with method 'Gaussian_Blur' as F:\MLpractrice\ct\output\train\adenocarcinoma_left.lower.lobe_T2_N0_M0_Ib\Gaussian_Blur\000017 (8)_4.jpg
# Processed and saved 000017 (8).png with method 'Edge_Detection' as F:\MLpractrice\ct\output\train\adenocarcinoma_left.lower.lobe_T2_N0_M0_Ib\Edge_Detection\000017 (8)_5.jpg
# Processed and saved 000017 (8).png with method 'Random_Color_Palette' as F:\MLpractrice\ct\output\train\adenocarcinoma_left.lower.lobe_T2_N0_M0_Ib\Random_Color_Palette\000017 (8)_6.jpg
# Processed and saved 000017 (8).png with method 'Gamma_Correction' as F:\MLpractrice\ct\output\train\adenocarcinoma_left.lower.lobe_T2_N0_M0_Ib\Gamma_Correction\000017 (8)_7.jpg
# Processed and saved 000017 (8).png with method 'LUT_Color_Map' as F:\MLpractrice\ct\output\train\adenocarcinoma_left.lower.lobe_T2_N0_M0_Ib\LUT_Color_Map\000017 (8)_8.jpg
# Processed and saved 000017 (8).png with method 'Alpha_Blending' as F:\MLpractrice\ct\output\train\adenocarcinoma_left.lower.lobe_T2_N0_M0_Ib\Alpha_Blending\000017 (8)_9.jpg
# Processed and saved 000017 (8).png with method '3D_Rendering' as F:\MLpractrice\ct\output\train\adenocarcinoma_left.lower.lobe_T2_N0_M0_Ib\3D_Rendering\000017 (8)_10.jpg
# Processed and saved 000017 (8).png with method 'Heatmap_Visualization' as F:\MLpractrice\ct\output\train\adenocarcinoma_left.lower.lobe_T2_N0_M0_Ib\Heatmap_Visualization\000017 (8)_11.jpg
# Processed and saved 000017 (8).png with method '3D_Volume_Rendering' as F:\MLpractrice\ct\output\train\adenocarcinoma_left.lower.lobe_T2_N0_M0_Ib\3D_Volume_Rendering\000017 (8)_12.jpg
# Processed and saved 000017 (8).png with method 'Interactive_Segmentation' as F:\MLpractrice\ct\output\train\adenocarcinoma_left.lower.lobe_T2_N0_M0_Ib\Interactive_Segmentation\000017 (8)_13.jpg
# Processed and saved 000018 (5).png with method 'Basic_Color_Map' as F:\MLpractrice\ct\output\train\adenocarcinoma_left.lower.lobe_T2_N0_M0_Ib\Basic_Color_Map\000018 (5)_1.jpg
# Processed and saved 000018 (5).png with method 'Adaptive_Histogram_Equalization' as F:\MLpractrice\ct\output\train\adenocarcinoma_left.lower.lobe_T2_N0_M0_Ib\Adaptive_Histogram_Equalization\000018 (5)_2.jpg
# Processed and saved 000018 (5).png with method 'Contrast_Stretching' as F:\MLpractrice\ct\output\train\adenocarcinoma_left.lower.lobe_T2_N0_M0_Ib\Contrast_Stretching\000018 (5)_3.jpg
# Processed and saved 000018 (5).png with method 'Gaussian_Blur' as F:\MLpractrice\ct\output\train\adenocarcinoma_left.lower.lobe_T2_N0_M0_Ib\Gaussian_Blur\000018 (5)_4.jpg
# Processed and saved 000018 (5).png with method 'Edge_Detection' as F:\MLpractrice\ct\output\train\adenocarcinoma_left.lower.lobe_T2_N0_M0_Ib\Edge_Detection\000018 (5)_5.jpg
# Processed and saved 000018 (5).png with method 'Random_Color_Palette' as F:\MLpractrice\ct\output\train\adenocarcinoma_left.lower.lobe_T2_N0_M0_Ib\Random_Color_Palette\000018 (5)_6.jpg
# Processed and saved 000018 (5).png with method 'Gamma_Correction' as F:\MLpractrice\ct\output\train\adenocarcinoma_left.lower.lobe_T2_N0_M0_Ib\Gamma_Correction\000018 (5)_7.jpg
# Processed and saved 000018 (5).png with method 'LUT_Color_Map' as F:\MLpractrice\ct\output\train\adenocarcinoma_left.lower.lobe_T2_N0_M0_Ib\LUT_Color_Map\000018 (5)_8.jpg
# Processed and saved 000018 (5).png with method 'Alpha_Blending' as F:\MLpractrice\ct\output\train\adenocarcinoma_left.lower.lobe_T2_N0_M0_Ib\Alpha_Blending\000018 (5)_9.jpg
# Processed and saved 000018 (5).png with method '3D_Rendering' as F:\MLpractrice\ct\output\train\adenocarcinoma_left.lower.lobe_T2_N0_M0_Ib\3D_Rendering\000018 (5)_10.jpg
# Processed and saved 000018 (5).png with method 'Heatmap_Visualization' as F:\MLpractrice\ct\output\train\adenocarcinoma_left.lower.lobe_T2_N0_M0_Ib\Heatmap_Visualization\000018 (5)_11.jpg
# Processed and saved 000018 (5).png with method '3D_Volume_Rendering' as F:\MLpractrice\ct\output\train\adenocarcinoma_left.lower.lobe_T2_N0_M0_Ib\3D_Volume_Rendering\000018 (5)_12.jpg
# Processed and saved 000018 (5).png with method 'Interactive_Segmentation' as F:\MLpractrice\ct\output\train\adenocarcinoma_left.lower.lobe_T2_N0_M0_Ib\Interactive_Segmentation\000018 (5)_13.jpg
# Processed and saved 000019 (5).png with method 'Basic_Color_Map' as F:\MLpractrice\ct\output\train\adenocarcinoma_left.lower.lobe_T2_N0_M0_Ib\Basic_Color_Map\000019 (5)_1.jpg
# Processed and saved 000019 (5).png with method 'Adaptive_Histogram_Equalization' as F:\MLpractrice\ct\output\train\adenocarcinoma_left.lower.lobe_T2_N0_M0_Ib\Adaptive_Histogram_Equalization\000019 (5)_2.jpg
# Processed and saved 000019 (5).png with method 'Contrast_Stretching' as F:\MLpractrice\ct\output\train\adenocarcinoma_left.lower.lobe_T2_N0_M0_Ib\Contrast_Stretching\000019 (5)_3.jpg
# Processed and saved 000019 (5).png with method 'Gaussian_Blur' as F:\MLpractrice\ct\output\train\adenocarcinoma_left.lower.lobe_T2_N0_M0_Ib\Gaussian_Blur\000019 (5)_4.jpg
# Processed and saved 000019 (5).png with method 'Edge_Detection' as F:\MLpractrice\ct\output\train\adenocarcinoma_left.lower.lobe_T2_N0_M0_Ib\Edge_Detection\000019 (5)_5.jpg
# Processed and saved 000019 (5).png with method 'Random_Color_Palette' as F:\MLpractrice\ct\output\train\adenocarcinoma_left.lower.lobe_T2_N0_M0_Ib\Random_Color_Palette\000019 (5)_6.jpg
# Processed and saved 000019 (5).png with method 'Gamma_Correction' as F:\MLpractrice\ct\output\train\adenocarcinoma_left.lower.lobe_T2_N0_M0_Ib\Gamma_Correction\000019 (5)_7.jpg
# Processed and saved 000019 (5).png with method 'LUT_Color_Map' as F:\MLpractrice\ct\output\train\adenocarcinoma_left.lower.lobe_T2_N0_M0_Ib\LUT_Color_Map\000019 (5)_8.jpg
# Processed and saved 000019 (5).png with method 'Alpha_Blending' as F:\MLpractrice\ct\output\train\adenocarcinoma_left.lower.lobe_T2_N0_M0_Ib\Alpha_Blending\000019 (5)_9.jpg
# Processed and saved 000019 (5).png with method '3D_Rendering' as F:\MLpractrice\ct\output\train\adenocarcinoma_left.lower.lobe_T2_N0_M0_Ib\3D_Rendering\000019 (5)_10.jpg
# Processed and saved 000019 (5).png with method 'Heatmap_Visualization' as F:\MLpractrice\ct\output\train\adenocarcinoma_left.lower.lobe_T2_N0_M0_Ib\Heatmap_Visualization\000019 (5)_11.jpg
# Processed and saved 000019 (5).png with method '3D_Volume_Rendering' as F:\MLpractrice\ct\output\train\adenocarcinoma_left.lower.lobe_T2_N0_M0_Ib\3D_Volume_Rendering\000019 (5)_12.jpg
# Processed and saved 000019 (5).png with method 'Interactive_Segmentation' as F:\MLpractrice\ct\output\train\adenocarcinoma_left.lower.lobe_T2_N0_M0_Ib\Interactive_Segmentation\000019 (5)_13.jpg
# Processed and saved 000020 (10).png with method 'Basic_Color_Map' as F:\MLpractrice\ct\output\train\adenocarcinoma_left.lower.lobe_T2_N0_M0_Ib\Basic_Color_Map\000020 (10)_1.jpg
# Processed and saved 000020 (10).png with method 'Adaptive_Histogram_Equalization' as F:\MLpractrice\ct\output\train\adenocarcinoma_left.lower.lobe_T2_N0_M0_Ib\Adaptive_Histogram_Equalization\000020 (10)_2.jpg
# Processed and saved 000020 (10).png with method 'Contrast_Stretching' as F:\MLpractrice\ct\output\train\adenocarcinoma_left.lower.lobe_T2_N0_M0_Ib\Contrast_Stretching\000020 (10)_3.jpg
# Processed and saved 000020 (10).png with method 'Gaussian_Blur' as F:\MLpractrice\ct\output\train\adenocarcinoma_left.lower.lobe_T2_N0_M0_Ib\Gaussian_Blur\000020 (10)_4.jpg
# Processed and saved 000020 (10).png with method 'Edge_Detection' as F:\MLpractrice\ct\output\train\adenocarcinoma_left.lower.lobe_T2_N0_M0_Ib\Edge_Detection\000020 (10)_5.jpg
# Processed and saved 000020 (10).png with method 'Random_Color_Palette' as F:\MLpractrice\ct\output\train\adenocarcinoma_left.lower.lobe_T2_N0_M0_Ib\Random_Color_Palette\000020 (10)_6.jpg
# Processed and saved 000020 (10).png with method 'Gamma_Correction' as F:\MLpractrice\ct\output\train\adenocarcinoma_left.lower.lobe_T2_N0_M0_Ib\Gamma_Correction\000020 (10)_7.jpg
# Processed and saved 000020 (10).png with method 'LUT_Color_Map' as F:\MLpractrice\ct\output\train\adenocarcinoma_left.lower.lobe_T2_N0_M0_Ib\LUT_Color_Map\000020 (10)_8.jpg
# Processed and saved 000020 (10).png with method 'Alpha_Blending' as F:\MLpractrice\ct\output\train\adenocarcinoma_left.lower.lobe_T2_N0_M0_Ib\Alpha_Blending\000020 (10)_9.jpg
# Processed and saved 000020 (10).png with method '3D_Rendering' as F:\MLpractrice\ct\output\train\adenocarcinoma_left.lower.lobe_T2_N0_M0_Ib\3D_Rendering\000020 (10)_10.jpg
# Processed and saved 000020 (10).png with method 'Heatmap_Visualization' as F:\MLpractrice\ct\output\train\adenocarcinoma_left.lower.lobe_T2_N0_M0_Ib\Heatmap_Visualization\000020 (10)_11.jpg
# Processed and saved 000020 (10).png with method '3D_Volume_Rendering' as F:\MLpractrice\ct\output\train\adenocarcinoma_left.lower.lobe_T2_N0_M0_Ib\3D_Volume_Rendering\000020 (10)_12.jpg
# Processed and saved 000020 (10).png with method 'Interactive_Segmentation' as F:\MLpractrice\ct\output\train\adenocarcinoma_left.lower.lobe_T2_N0_M0_Ib\Interactive_Segmentation\000020 (10)_13.jpg
# Processed and saved 000020 (5).png with method 'Basic_Color_Map' as F:\MLpractrice\ct\output\train\adenocarcinoma_left.lower.lobe_T2_N0_M0_Ib\Basic_Color_Map\000020 (5)_1.jpg
# Processed and saved 000020 (5).png with method 'Adaptive_Histogram_Equalization' as F:\MLpractrice\ct\output\train\adenocarcinoma_left.lower.lobe_T2_N0_M0_Ib\Adaptive_Histogram_Equalization\000020 (5)_2.jpg
# Processed and saved 000020 (5).png with method 'Contrast_Stretching' as F:\MLpractrice\ct\output\train\adenocarcinoma_left.lower.lobe_T2_N0_M0_Ib\Contrast_Stretching\000020 (5)_3.jpg
# Processed and saved 000020 (5).png with method 'Gaussian_Blur' as F:\MLpractrice\ct\output\train\adenocarcinoma_left.lower.lobe_T2_N0_M0_Ib\Gaussian_Blur\000020 (5)_4.jpg
# Processed and saved 000020 (5).png with method 'Edge_Detection' as F:\MLpractrice\ct\output\train\adenocarcinoma_left.lower.lobe_T2_N0_M0_Ib\Edge_Detection\000020 (5)_5.jpg
# Processed and saved 000020 (5).png with method 'Random_Color_Palette' as F:\MLpractrice\ct\output\train\adenocarcinoma_left.lower.lobe_T2_N0_M0_Ib\Random_Color_Palette\000020 (5)_6.jpg
# Processed and saved 000020 (5).png with method 'Gamma_Correction' as F:\MLpractrice\ct\output\train\adenocarcinoma_left.lower.lobe_T2_N0_M0_Ib\Gamma_Correction\000020 (5)_7.jpg
# Processed and saved 000020 (5).png with method 'LUT_Color_Map' as F:\MLpractrice\ct\output\train\adenocarcinoma_left.lower.lobe_T2_N0_M0_Ib\LUT_Color_Map\000020 (5)_8.jpg
# Processed and saved 000020 (5).png with method 'Alpha_Blending' as F:\MLpractrice\ct\output\train\adenocarcinoma_left.lower.lobe_T2_N0_M0_Ib\Alpha_Blending\000020 (5)_9.jpg
# Processed and saved 000020 (5).png with method '3D_Rendering' as F:\MLpractrice\ct\output\train\adenocarcinoma_left.lower.lobe_T2_N0_M0_Ib\3D_Rendering\000020 (5)_10.jpg
# Processed and saved 000020 (5).png with method 'Heatmap_Visualization' as F:\MLpractrice\ct\output\train\adenocarcinoma_left.lower.lobe_T2_N0_M0_Ib\Heatmap_Visualization\000020 (5)_11.jpg
# Processed and saved 000020 (5).png with method '3D_Volume_Rendering' as F:\MLpractrice\ct\output\train\adenocarcinoma_left.lower.lobe_T2_N0_M0_Ib\3D_Volume_Rendering\000020 (5)_12.jpg
# Processed and saved 000020 (5).png with method 'Interactive_Segmentation' as F:\MLpractrice\ct\output\train\adenocarcinoma_left.lower.lobe_T2_N0_M0_Ib\Interactive_Segmentation\000020 (5)_13.jpg
# Processed and saved 000020 (6).png with method 'Basic_Color_Map' as F:\MLpractrice\ct\output\train\adenocarcinoma_left.lower.lobe_T2_N0_M0_Ib\Basic_Color_Map\000020 (6)_1.jpg
# Processed and saved 000020 (6).png with method 'Adaptive_Histogram_Equalization' as F:\MLpractrice\ct\output\train\adenocarcinoma_left.lower.lobe_T2_N0_M0_Ib\Adaptive_Histogram_Equalization\000020 (6)_2.jpg
# Processed and saved 000020 (6).png with method 'Contrast_Stretching' as F:\MLpractrice\ct\output\train\adenocarcinoma_left.lower.lobe_T2_N0_M0_Ib\Contrast_Stretching\000020 (6)_3.jpg
# Processed and saved 000020 (6).png with method 'Gaussian_Blur' as F:\MLpractrice\ct\output\train\adenocarcinoma_left.lower.lobe_T2_N0_M0_Ib\Gaussian_Blur\000020 (6)_4.jpg
# Processed and saved 000020 (6).png with method 'Edge_Detection' as F:\MLpractrice\ct\output\train\adenocarcinoma_left.lower.lobe_T2_N0_M0_Ib\Edge_Detection\000020 (6)_5.jpg
# Processed and saved 000020 (6).png with method 'Random_Color_Palette' as F:\MLpractrice\ct\output\train\adenocarcinoma_left.lower.lobe_T2_N0_M0_Ib\Random_Color_Palette\000020 (6)_6.jpg
# Processed and saved 000020 (6).png with method 'Gamma_Correction' as F:\MLpractrice\ct\output\train\adenocarcinoma_left.lower.lobe_T2_N0_M0_Ib\Gamma_Correction\000020 (6)_7.jpg
# Processed and saved 000020 (6).png with method 'LUT_Color_Map' as F:\MLpractrice\ct\output\train\adenocarcinoma_left.lower.lobe_T2_N0_M0_Ib\LUT_Color_Map\000020 (6)_8.jpg
# Processed and saved 000020 (6).png with method 'Alpha_Blending' as F:\MLpractrice\ct\output\train\adenocarcinoma_left.lower.lobe_T2_N0_M0_Ib\Alpha_Blending\000020 (6)_9.jpg
# Processed and saved 000020 (6).png with method '3D_Rendering' as F:\MLpractrice\ct\output\train\adenocarcinoma_left.lower.lobe_T2_N0_M0_Ib\3D_Rendering\000020 (6)_10.jpg
# Processed and saved 000020 (6).png with method 'Heatmap_Visualization' as F:\MLpractrice\ct\output\train\adenocarcinoma_left.lower.lobe_T2_N0_M0_Ib\Heatmap_Visualization\000020 (6)_11.jpg
# Processed and saved 000020 (6).png with method '3D_Volume_Rendering' as F:\MLpractrice\ct\output\train\adenocarcinoma_left.lower.lobe_T2_N0_M0_Ib\3D_Volume_Rendering\000020 (6)_12.jpg
# Processed and saved 000020 (6).png with method 'Interactive_Segmentation' as F:\MLpractrice\ct\output\train\adenocarcinoma_left.lower.lobe_T2_N0_M0_Ib\Interactive_Segmentation\000020 (6)_13.jpg
# Processed and saved 000021 (3).png with method 'Basic_Color_Map' as F:\MLpractrice\ct\output\train\adenocarcinoma_left.lower.lobe_T2_N0_M0_Ib\Basic_Color_Map\000021 (3)_1.jpg
# Processed and saved 000021 (3).png with method 'Adaptive_Histogram_Equalization' as F:\MLpractrice\ct\output\train\adenocarcinoma_left.lower.lobe_T2_N0_M0_Ib\Adaptive_Histogram_Equalization\000021 (3)_2.jpg
# ...
# Processed and saved 000122.png with method 'Basic_Color_Map' as F:\MLpractrice\ct\output\train\squamous.cell.carcinoma_left.hilum_T1_N2_M0_IIIa\Basic_Color_Map\000122_1.jpg
# Processed and saved 000122.png with method 'Adaptive_Histogram_Equalization' as F:\MLpractrice\ct\output\train\squamous.cell.carcinoma_left.hilum_T1_N2_M0_IIIa\Adaptive_Histogram_Equalization\000122_2.jpg
# Processed and saved 000122.png with method 'Contrast_Stretching' as F:\MLpractrice\ct\output\train\squamous.cell.carcinoma_left.hilum_T1_N2_M0_IIIa\Contrast_Stretching\000122_3.jpg
# Processed and saved 000122.png with method 'Gaussian_Blur' as F:\MLpractrice\ct\output\train\squamous.cell.carcinoma_left.hilum_T1_N2_M0_IIIa\Gaussian_Blur\000122_4.jpg
# Processed and saved 000122.png with method 'Edge_Detection' as F:\MLpractrice\ct\output\train\squamous.cell.carcinoma_left.hilum_T1_N2_M0_IIIa\Edge_Detection\000122_5.jpg
# Processed and saved 000122.png with method 'Random_Color_Palette' as F:\MLpractrice\ct\output\train\squamous.cell.carcinoma_left.hilum_T1_N2_M0_IIIa\Random_Color_Palette\000122_6.jpg
# Processed and saved 000122.png with method 'Gamma_Correction' as F:\MLpractrice\ct\output\train\squamous.cell.carcinoma_left.hilum_T1_N2_M0_IIIa\Gamma_Correction\000122_7.jpg
# Processed and saved 000122.png with method 'LUT_Color_Map' as F:\MLpractrice\ct\output\train\squamous.cell.carcinoma_left.hilum_T1_N2_M0_IIIa\LUT_Color_Map\000122_8.jpg
# Processed and saved 000122.png with method 'Alpha_Blending' as F:\MLpractrice\ct\output\train\squamous.cell.carcinoma_left.hilum_T1_N2_M0_IIIa\Alpha_Blending\000122_9.jpg
# Processed and saved 000122.png with method '3D_Rendering' as F:\MLpractrice\ct\output\train\squamous.cell.carcinoma_left.hilum_T1_N2_M0_IIIa\3D_Rendering\000122_10.jpg
# Processed and saved 000122.png with method 'Heatmap_Visualization' as F:\MLpractrice\ct\output\train\squamous.cell.carcinoma_left.hilum_T1_N2_M0_IIIa\Heatmap_Visualization\000122_11.jpg
# Processed and saved 000122.png with method '3D_Volume_Rendering' as F:\MLpractrice\ct\output\train\squamous.cell.carcinoma_left.hilum_T1_N2_M0_IIIa\3D_Volume_Rendering\000122_12.jpg
# Processed and saved 000122.png with method 'Interactive_Segmentation' as F:\MLpractrice\ct\output\train\squamous.cell.carcinoma_left.hilum_T1_N2_M0_IIIa\Interactive_Segmentation\000122_13.jpg
# Processed and saved sq1.png with method 'Basic_Color_Map' as F:\MLpractrice\ct\output\train\squamous.cell.carcinoma_left.hilum_T1_N2_M0_IIIa\Basic_Color_Map\sq1_1.jpg
# Processed and saved sq1.png with method 'Adaptive_Histogram_Equalization' as F:\MLpractrice\ct\output\train\squamous.cell.carcinoma_left.hilum_T1_N2_M0_IIIa\Adaptive_Histogram_Equalization\sq1_2.jpg
# Processed and saved sq1.png with method 'Contrast_Stretching' as F:\MLpractrice\ct\output\train\squamous.cell.carcinoma_left.hilum_T1_N2_M0_IIIa\Contrast_Stretching\sq1_3.jpg
# Processed and saved sq1.png with method 'Gaussian_Blur' as F:\MLpractrice\ct\output\train\squamous.cell.carcinoma_left.hilum_T1_N2_M0_IIIa\Gaussian_Blur\sq1_4.jpg
# Processed and saved sq1.png with method 'Edge_Detection' as F:\MLpractrice\ct\output\train\squamous.cell.carcinoma_left.hilum_T1_N2_M0_IIIa\Edge_Detection\sq1_5.jpg
# Processed and saved sq1.png with method 'Random_Color_Palette' as F:\MLpractrice\ct\output\train\squamous.cell.carcinoma_left.hilum_T1_N2_M0_IIIa\Random_Color_Palette\sq1_6.jpg
# Processed and saved sq1.png with method 'Gamma_Correction' as F:\MLpractrice\ct\output\train\squamous.cell.carcinoma_left.hilum_T1_N2_M0_IIIa\Gamma_Correction\sq1_7.jpg
# Processed and saved sq1.png with method 'LUT_Color_Map' as F:\MLpractrice\ct\output\train\squamous.cell.carcinoma_left.hilum_T1_N2_M0_IIIa\LUT_Color_Map\sq1_8.jpg
# Processed and saved sq1.png with method 'Alpha_Blending' as F:\MLpractrice\ct\output\train\squamous.cell.carcinoma_left.hilum_T1_N2_M0_IIIa\Alpha_Blending\sq1_9.jpg
# Processed and saved sq1.png with method '3D_Rendering' as F:\MLpractrice\ct\output\train\squamous.cell.carcinoma_left.hilum_T1_N2_M0_IIIa\3D_Rendering\sq1_10.jpg
# Processed and saved sq1.png with method 'Heatmap_Visualization' as F:\MLpractrice\ct\output\train\squamous.cell.carcinoma_left.hilum_T1_N2_M0_IIIa\Heatmap_Visualization\sq1_11.jpg
# Processed and saved sq1.png with method '3D_Volume_Rendering' as F:\MLpractrice\ct\output\train\squamous.cell.carcinoma_left.hilum_T1_N2_M0_IIIa\3D_Volume_Rendering\sq1_12.jpg
# Processed and saved sq1.png with method 'Interactive_Segmentation' as F:\MLpractrice\ct\output\train\squamous.cell.carcinoma_left.hilum_T1_N2_M0_IIIa\Interactive_Segmentation\sq1_13.jpg
# Processed and saved sq2.png with method 'Basic_Color_Map' as F:\MLpractrice\ct\output\train\squamous.cell.carcinoma_left.hilum_T1_N2_M0_IIIa\Basic_Color_Map\sq2_1.jpg
# Processed and saved sq2.png with method 'Adaptive_Histogram_Equalization' as F:\MLpractrice\ct\output\train\squamous.cell.carcinoma_left.hilum_T1_N2_M0_IIIa\Adaptive_Histogram_Equalization\sq2_2.jpg
# Processed and saved sq2.png with method 'Contrast_Stretching' as F:\MLpractrice\ct\output\train\squamous.cell.carcinoma_left.hilum_T1_N2_M0_IIIa\Contrast_Stretching\sq2_3.jpg
# Processed and saved sq2.png with method 'Gaussian_Blur' as F:\MLpractrice\ct\output\train\squamous.cell.carcinoma_left.hilum_T1_N2_M0_IIIa\Gaussian_Blur\sq2_4.jpg
# Processed and saved sq2.png with method 'Edge_Detection' as F:\MLpractrice\ct\output\train\squamous.cell.carcinoma_left.hilum_T1_N2_M0_IIIa\Edge_Detection\sq2_5.jpg
# Processed and saved sq2.png with method 'Random_Color_Palette' as F:\MLpractrice\ct\output\train\squamous.cell.carcinoma_left.hilum_T1_N2_M0_IIIa\Random_Color_Palette\sq2_6.jpg
# Processed and saved sq2.png with method 'Gamma_Correction' as F:\MLpractrice\ct\output\train\squamous.cell.carcinoma_left.hilum_T1_N2_M0_IIIa\Gamma_Correction\sq2_7.jpg
# Processed and saved sq2.png with method 'LUT_Color_Map' as F:\MLpractrice\ct\output\train\squamous.cell.carcinoma_left.hilum_T1_N2_M0_IIIa\LUT_Color_Map\sq2_8.jpg
# Processed and saved sq2.png with method 'Alpha_Blending' as F:\MLpractrice\ct\output\train\squamous.cell.carcinoma_left.hilum_T1_N2_M0_IIIa\Alpha_Blending\sq2_9.jpg
# Processed and saved sq2.png with method '3D_Rendering' as F:\MLpractrice\ct\output\train\squamous.cell.carcinoma_left.hilum_T1_N2_M0_IIIa\3D_Rendering\sq2_10.jpg
# Processed and saved sq2.png with method 'Heatmap_Visualization' as F:\MLpractrice\ct\output\train\squamous.cell.carcinoma_left.hilum_T1_N2_M0_IIIa\Heatmap_Visualization\sq2_11.jpg
# Processed and saved sq2.png with method '3D_Volume_Rendering' as F:\MLpractrice\ct\output\train\squamous.cell.carcinoma_left.hilum_T1_N2_M0_IIIa\3D_Volume_Rendering\sq2_12.jpg
# Processed and saved sq2.png with method 'Interactive_Segmentation' as F:\MLpractrice\ct\output\train\squamous.cell.carcinoma_left.hilum_T1_N2_M0_IIIa\Interactive_Segmentation\sq2_13.jpg
# Processed and saved sq3.png with method 'Basic_Color_Map' as F:\MLpractrice\ct\output\train\squamous.cell.carcinoma_left.hilum_T1_N2_M0_IIIa\Basic_Color_Map\sq3_1.jpg
# Processed and saved sq3.png with method 'Adaptive_Histogram_Equalization' as F:\MLpractrice\ct\output\train\squamous.cell.carcinoma_left.hilum_T1_N2_M0_IIIa\Adaptive_Histogram_Equalization\sq3_2.jpg
# Processed and saved sq3.png with method 'Contrast_Stretching' as F:\MLpractrice\ct\output\train\squamous.cell.carcinoma_left.hilum_T1_N2_M0_IIIa\Contrast_Stretching\sq3_3.jpg
# Processed and saved sq3.png with method 'Gaussian_Blur' as F:\MLpractrice\ct\output\train\squamous.cell.carcinoma_left.hilum_T1_N2_M0_IIIa\Gaussian_Blur\sq3_4.jpg
# Processed and saved sq3.png with method 'Edge_Detection' as F:\MLpractrice\ct\output\train\squamous.cell.carcinoma_left.hilum_T1_N2_M0_IIIa\Edge_Detection\sq3_5.jpg
# Processed and saved sq3.png with method 'Random_Color_Palette' as F:\MLpractrice\ct\output\train\squamous.cell.carcinoma_left.hilum_T1_N2_M0_IIIa\Random_Color_Palette\sq3_6.jpg
# Processed and saved sq3.png with method 'Gamma_Correction' as F:\MLpractrice\ct\output\train\squamous.cell.carcinoma_left.hilum_T1_N2_M0_IIIa\Gamma_Correction\sq3_7.jpg
# Processed and saved sq3.png with method 'LUT_Color_Map' as F:\MLpractrice\ct\output\train\squamous.cell.carcinoma_left.hilum_T1_N2_M0_IIIa\LUT_Color_Map\sq3_8.jpg
# Processed and saved sq3.png with method 'Alpha_Blending' as F:\MLpractrice\ct\output\train\squamous.cell.carcinoma_left.hilum_T1_N2_M0_IIIa\Alpha_Blending\sq3_9.jpg
# Processed and saved sq3.png with method '3D_Rendering' as F:\MLpractrice\ct\output\train\squamous.cell.carcinoma_left.hilum_T1_N2_M0_IIIa\3D_Rendering\sq3_10.jpg
# Processed and saved sq3.png with method 'Heatmap_Visualization' as F:\MLpractrice\ct\output\train\squamous.cell.carcinoma_left.hilum_T1_N2_M0_IIIa\Heatmap_Visualization\sq3_11.jpg
# Processed and saved sq3.png with method '3D_Volume_Rendering' as F:\MLpractrice\ct\output\train\squamous.cell.carcinoma_left.hilum_T1_N2_M0_IIIa\3D_Volume_Rendering\sq3_12.jpg
# Processed and saved sq3.png with method 'Interactive_Segmentation' as F:\MLpractrice\ct\output\train\squamous.cell.carcinoma_left.hilum_T1_N2_M0_IIIa\Interactive_Segmentation\sq3_13.jpg
# Processed and saved sq4.png with method 'Basic_Color_Map' as F:\MLpractrice\ct\output\train\squamous.cell.carcinoma_left.hilum_T1_N2_M0_IIIa\Basic_Color_Map\sq4_1.jpg
# Processed and saved sq4.png with method 'Adaptive_Histogram_Equalization' as F:\MLpractrice\ct\output\train\squamous.cell.carcinoma_left.hilum_T1_N2_M0_IIIa\Adaptive_Histogram_Equalization\sq4_2.jpg
# Processed and saved sq4.png with method 'Contrast_Stretching' as F:\MLpractrice\ct\output\train\squamous.cell.carcinoma_left.hilum_T1_N2_M0_IIIa\Contrast_Stretching\sq4_3.jpg
# Processed and saved sq4.png with method 'Gaussian_Blur' as F:\MLpractrice\ct\output\train\squamous.cell.carcinoma_left.hilum_T1_N2_M0_IIIa\Gaussian_Blur\sq4_4.jpg
# Processed and saved sq4.png with method 'Edge_Detection' as F:\MLpractrice\ct\output\train\squamous.cell.carcinoma_left.hilum_T1_N2_M0_IIIa\Edge_Detection\sq4_5.jpg
# Processed and saved sq4.png with method 'Random_Color_Palette' as F:\MLpractrice\ct\output\train\squamous.cell.carcinoma_left.hilum_T1_N2_M0_IIIa\Random_Color_Palette\sq4_6.jpg
# Processed and saved sq4.png with method 'Gamma_Correction' as F:\MLpractrice\ct\output\train\squamous.cell.carcinoma_left.hilum_T1_N2_M0_IIIa\Gamma_Correction\sq4_7.jpg
# Processed and saved sq4.png with method 'LUT_Color_Map' as F:\MLpractrice\ct\output\train\squamous.cell.carcinoma_left.hilum_T1_N2_M0_IIIa\LUT_Color_Map\sq4_8.jpg
# Processed and saved sq4.png with method 'Alpha_Blending' as F:\MLpractrice\ct\output\train\squamous.cell.carcinoma_left.hilum_T1_N2_M0_IIIa\Alpha_Blending\sq4_9.jpg
# Processed and saved sq4.png with method '3D_Rendering' as F:\MLpractrice\ct\output\train\squamous.cell.carcinoma_left.hilum_T1_N2_M0_IIIa\3D_Rendering\sq4_10.jpg
# Processed and saved sq4.png with method 'Heatmap_Visualization' as F:\MLpractrice\ct\output\train\squamous.cell.carcinoma_left.hilum_T1_N2_M0_IIIa\Heatmap_Visualization\sq4_11.jpg
# Processed and saved sq4.png with method '3D_Volume_Rendering' as F:\MLpractrice\ct\output\train\squamous.cell.carcinoma_left.hilum_T1_N2_M0_IIIa\3D_Volume_Rendering\sq4_12.jpg
# Processed and saved sq4.png with method 'Interactive_Segmentation' as F:\MLpractrice\ct\output\train\squamous.cell.carcinoma_left.hilum_T1_N2_M0_IIIa\Interactive_Segmentation\sq4_13.jpg
# Processed and saved sq5.png with method 'Basic_Color_Map' as F:\MLpractrice\ct\output\train\squamous.cell.carcinoma_left.hilum_T1_N2_M0_IIIa\Basic_Color_Map\sq5_1.jpg
# Processed and saved sq5.png with method 'Adaptive_Histogram_Equalization' as F:\MLpractrice\ct\output\train\squamous.cell.carcinoma_left.hilum_T1_N2_M0_IIIa\Adaptive_Histogram_Equalization\sq5_2.jpg
# Processed and saved sq5.png with method 'Contrast_Stretching' as F:\MLpractrice\ct\output\train\squamous.cell.carcinoma_left.hilum_T1_N2_M0_IIIa\Contrast_Stretching\sq5_3.jpg
# Processed and saved sq5.png with method 'Gaussian_Blur' as F:\MLpractrice\ct\output\train\squamous.cell.carcinoma_left.hilum_T1_N2_M0_IIIa\Gaussian_Blur\sq5_4.jpg
# Processed and saved sq5.png with method 'Edge_Detection' as F:\MLpractrice\ct\output\train\squamous.cell.carcinoma_left.hilum_T1_N2_M0_IIIa\Edge_Detection\sq5_5.jpg
# Processed and saved sq5.png with method 'Random_Color_Palette' as F:\MLpractrice\ct\output\train\squamous.cell.carcinoma_left.hilum_T1_N2_M0_IIIa\Random_Color_Palette\sq5_6.jpg
# Processed and saved sq5.png with method 'Gamma_Correction' as F:\MLpractrice\ct\output\train\squamous.cell.carcinoma_left.hilum_T1_N2_M0_IIIa\Gamma_Correction\sq5_7.jpg
# Processed and saved sq5.png with method 'LUT_Color_Map' as F:\MLpractrice\ct\output\train\squamous.cell.carcinoma_left.hilum_T1_N2_M0_IIIa\LUT_Color_Map\sq5_8.jpg
# Processed and saved sq5.png with method 'Alpha_Blending' as F:\MLpractrice\ct\output\train\squamous.cell.carcinoma_left.hilum_T1_N2_M0_IIIa\Alpha_Blending\sq5_9.jpg
# Processed and saved sq5.png with method '3D_Rendering' as F:\MLpractrice\ct\output\train\squamous.cell.carcinoma_left.hilum_T1_N2_M0_IIIa\3D_Rendering\sq5_10.jpg
# Processed and saved sq5.png with method 'Heatmap_Visualization' as F:\MLpractrice\ct\output\train\squamous.cell.carcinoma_left.hilum_T1_N2_M0_IIIa\Heatmap_Visualization\sq5_11.jpg
# Processed and saved sq5.png with method '3D_Volume_Rendering' as F:\MLpractrice\ct\output\train\squamous.cell.carcinoma_left.hilum_T1_N2_M0_IIIa\3D_Volume_Rendering\sq5_12.jpg
# Processed and saved sq5.png with method 'Interactive_Segmentation' as F:\MLpractrice\ct\output\train\squamous.cell.carcinoma_left.hilum_T1_N2_M0_IIIa\Interactive_Segmentation\sq5_13.jpg
# Processed and saved sq6.png with method 'Basic_Color_Map' as F:\MLpractrice\ct\output\train\squamous.cell.carcinoma_left.hilum_T1_N2_M0_IIIa\Basic_Color_Map\sq6_1.jpg
# Processed and saved sq6.png with method 'Adaptive_Histogram_Equalization' as F:\MLpractrice\ct\output\train\squamous.cell.carcinoma_left.hilum_T1_N2_M0_IIIa\Adaptive_Histogram_Equalization\sq6_2.jpg
# Processed and saved sq6.png with method 'Contrast_Stretching' as F:\MLpractrice\ct\output\train\squamous.cell.carcinoma_left.hilum_T1_N2_M0_IIIa\Contrast_Stretching\sq6_3.jpg
# Processed and saved sq6.png with method 'Gaussian_Blur' as F:\MLpractrice\ct\output\train\squamous.cell.carcinoma_left.hilum_T1_N2_M0_IIIa\Gaussian_Blur\sq6_4.jpg
# Processed and saved sq6.png with method 'Edge_Detection' as F:\MLpractrice\ct\output\train\squamous.cell.carcinoma_left.hilum_T1_N2_M0_IIIa\Edge_Detection\sq6_5.jpg
# Processed and saved sq6.png with method 'Random_Color_Palette' as F:\MLpractrice\ct\output\train\squamous.cell.carcinoma_left.hilum_T1_N2_M0_IIIa\Random_Color_Palette\sq6_6.jpg
# Processed and saved sq6.png with method 'Gamma_Correction' as F:\MLpractrice\ct\output\train\squamous.cell.carcinoma_left.hilum_T1_N2_M0_IIIa\Gamma_Correction\sq6_7.jpg
# Processed and saved sq6.png with method 'LUT_Color_Map' as F:\MLpractrice\ct\output\train\squamous.cell.carcinoma_left.hilum_T1_N2_M0_IIIa\LUT_Color_Map\sq6_8.jpg
# Processed and saved sq6.png with method 'Alpha_Blending' as F:\MLpractrice\ct\output\train\squamous.cell.carcinoma_left.hilum_T1_N2_M0_IIIa\Alpha_Blending\sq6_9.jpg
# Processed and saved sq6.png with method '3D_Rendering' as F:\MLpractrice\ct\output\train\squamous.cell.carcinoma_left.hilum_T1_N2_M0_IIIa\3D_Rendering\sq6_10.jpg
# Processed and saved sq6.png with method 'Heatmap_Visualization' as F:\MLpractrice\ct\output\train\squamous.cell.carcinoma_left.hilum_T1_N2_M0_IIIa\Heatmap_Visualization\sq6_11.jpg
# Processed and saved sq6.png with method '3D_Volume_Rendering' as F:\MLpractrice\ct\output\train\squamous.cell.carcinoma_left.hilum_T1_N2_M0_IIIa\3D_Volume_Rendering\sq6_12.jpg
# Processed and saved sq6.png with method 'Interactive_Segmentation' as F:\MLpractrice\ct\output\train\squamous.cell.carcinoma_left.hilum_T1_N2_M0_IIIa\Interactive_Segmentation\sq6_13.jpg
# Processing complete.

# %%
4000+4
# Out:
# 4004

# %%
https://www.kaggle.com/datasets/trainingdatapro/computed-tomography-ct-of-the-brain

# %%
import os
import numpy as np
import matplotlib.pyplot as plt
from matplotlib import cm
from PIL import Image
import cv2

# Define input and output directories
input_directory = r'F:\MLpractrice\ct\data'
output_directory = r'F:\MLpractrice\ct\output'

# Create the output directory if it doesn't exist
if not os.path.exists(output_directory):
    os.makedirs(output_directory)

# Method 1: Basic Color Map Application
def apply_color_map(ct_image, cmap='jet'):
    ct_image_normalized = (ct_image - np.min(ct_image)) / (np.max(ct_image) - np.min(ct_image))
    colored_image = cm.get_cmap(cmap)(ct_image_normalized)
    return (colored_image[:, :, :3] * 255).astype(np.uint8)

# Method 2: Adaptive Histogram Equalization with Color Map
def apply_adaptive_hist_eq(ct_image):
    clahe = cv2.createCLAHE(clipLimit=2.0, tileGridSize=(8, 8))
    enhanced_image = clahe.apply(ct_image)
    return apply_color_map(enhanced_image)

# Method 3: Contrast Stretching with Color Map
def apply_contrast_stretching(ct_image):
    min_val, max_val = np.min(ct_image), np.max(ct_image)
    stretched_image = (ct_image - min_val) / (max_val - min_val)
    return apply_color_map(stretched_image)

# Method 4: Gaussian Blur with Color Map
def apply_gaussian_blur(ct_image):
    blurred_image = cv2.GaussianBlur(ct_image, (5, 5), 0)
    return apply_color_map(blurred_image)

# Method 5: Edge Detection with Canny and Color Map
def apply_edge_detection(ct_image):
    edges = cv2.Canny(ct_image, 100, 200)
    return apply_color_map(edges)

# Method 6: Random Color Palettes (Color Overlay)
def apply_random_color_palette(ct_image):
    random_colored = np.random.rand(*ct_image.shape, 3)
    colored_image = ct_image[:, :, None] * random_colored
    return (colored_image * 255).astype(np.uint8)

# Method 7: Non-Linear Color Stretching (Gamma Correction)
def apply_gamma_correction(ct_image, gamma=1.2):
    gamma_corrected = np.power(ct_image / float(np.max(ct_image)), gamma) * 255
    return apply_color_map(gamma_corrected)

# Method 8: LUT (Lookup Table) Color Mapping (Use predefined LUT)
def apply_lut_color_map(ct_image):
    colored_image = cm.plasma((ct_image - np.min(ct_image)) / (np.max(ct_image) - np.min(ct_image)))
    return (colored_image[:, :, :3] * 255).astype(np.uint8)

# Method 9: Alpha Blending (Threshold-based)
def apply_alpha_blending(ct_image):
    thresholded_image = ct_image > 100
    colored_image = apply_color_map(ct_image)
    thresholded_image_rgb = np.stack([thresholded_image] * 3, axis=-1)
    alpha = 0.5
    final_image = alpha * colored_image + (1 - alpha) * thresholded_image_rgb * 255
    return final_image.astype(np.uint8)

# Method 10: 3D Rendering (Placeholder for 2D images)
def apply_3d_rendering(ct_image):
    return apply_color_map(ct_image)

# Method 11: Heatmap Visualization for Anomaly Detection
def apply_heatmap(ct_image):
    heatmap_image = cm.hot((ct_image - np.min(ct_image)) / (np.max(ct_image) - np.min(ct_image)))
    return (heatmap_image[:, :, :3] * 255).astype(np.uint8)

# Method 12: 3D Volume Rendering (Placeholder for 3D visualization)
def apply_3d_volume_rendering(ct_image):
    return apply_color_map(ct_image)

# Method 13: Interactive Visualization with Segmented Regions
def apply_interactive_visualization(ct_image):
    segmented_image = ct_image > 100
    segmented_colored = cm.plasma(segmented_image.astype(np.float32))
    return (segmented_colored[:, :, :3] * 255).astype(np.uint8)

# Traverse the input directory and process each image in the subfolders
for root, dirs, files in os.walk(input_directory):
    # For each image file in the directory
    for image_file in files:
        if image_file.endswith('.jpg') or image_file.endswith('.png'):
            try:
                # Construct the full input path for the image
                image_path = os.path.join(root, image_file)
                
                # Load the image using PIL
                image = Image.open(image_path)
                
                # Convert image to grayscale
                ct_image = np.array(image.convert('L'))  # Convert to grayscale
                
                # Create the same folder structure in the output directory
                relative_path = os.path.relpath(root, input_directory)  # Get relative folder structure
                output_folder = os.path.join(output_directory, relative_path)
                if not os.path.exists(output_folder):
                    os.makedirs(output_folder)

                # Define a method-to-folder mapping for naming purposes
                method_folders = [
                    "Basic_Color_Map",
                    "Adaptive_Histogram_Equalization",
                    "Contrast_Stretching",
                    "Gaussian_Blur",
                    "Edge_Detection",
                    "Random_Color_Palette",
                    "Gamma_Correction",
                    "LUT_Color_Map",
                    "Alpha_Blending",
                    "3D_Rendering",
                    "Heatmap_Visualization",
                    "3D_Volume_Rendering",
                    "Interactive_Segmentation"
                ]
                
                # Save images in their respective method folders
                for idx, method in enumerate([apply_color_map,
                                              apply_adaptive_hist_eq,
                                              apply_contrast_stretching,
                                              apply_gaussian_blur,
                                              apply_edge_detection,
                                              apply_random_color_palette,
                                              apply_gamma_correction,
                                              apply_lut_color_map,
                                              apply_alpha_blending,
                                              apply_3d_rendering,
                                              apply_heatmap,
                                              apply_3d_volume_rendering,
                                              apply_interactive_visualization]):
                    # Create method folder if it doesn't exist
                    method_folder = os.path.join(output_folder, method_folders[idx])
                    if not os.path.exists(method_folder):
                        os.makedirs(method_folder)
                    
                    # Apply the method to the image
                    result_image = method(ct_image)
                    
                    # Save the image with a sequential number in the method folder
                    image_name_without_extension = os.path.splitext(image_file)[0]
                    output_image_path = os.path.join(method_folder, f"{image_name_without_extension}_{idx+1}.jpg")
                    Image.fromarray(result_image).save(output_image_path, format='JPEG')
                    print(f"Processed and saved {image_file} with method '{method_folders[idx]}' as {output_image_path}")
            
            except Exception as e:
                print(f"Error processing {image_file} in {root}: {e}")

print("Processing complete.")
# Out:
# C:\Users\AIC\AppData\Local\Temp\ipykernel_14264\3006613876.py:19: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap(obj)`` instead.
#   colored_image = cm.get_cmap(cmap)(ct_image_normalized)
# Processed and saved 0.jpg with method 'Basic_Color_Map' as F:\MLpractrice\ct\output\files\aneurysm\Basic_Color_Map\0_1.jpg
# Processed and saved 0.jpg with method 'Adaptive_Histogram_Equalization' as F:\MLpractrice\ct\output\files\aneurysm\Adaptive_Histogram_Equalization\0_2.jpg
# Processed and saved 0.jpg with method 'Contrast_Stretching' as F:\MLpractrice\ct\output\files\aneurysm\Contrast_Stretching\0_3.jpg
# Processed and saved 0.jpg with method 'Gaussian_Blur' as F:\MLpractrice\ct\output\files\aneurysm\Gaussian_Blur\0_4.jpg
# Processed and saved 0.jpg with method 'Edge_Detection' as F:\MLpractrice\ct\output\files\aneurysm\Edge_Detection\0_5.jpg
# Processed and saved 0.jpg with method 'Random_Color_Palette' as F:\MLpractrice\ct\output\files\aneurysm\Random_Color_Palette\0_6.jpg
# Processed and saved 0.jpg with method 'Gamma_Correction' as F:\MLpractrice\ct\output\files\aneurysm\Gamma_Correction\0_7.jpg
# Processed and saved 0.jpg with method 'LUT_Color_Map' as F:\MLpractrice\ct\output\files\aneurysm\LUT_Color_Map\0_8.jpg
# Processed and saved 0.jpg with method 'Alpha_Blending' as F:\MLpractrice\ct\output\files\aneurysm\Alpha_Blending\0_9.jpg
# Processed and saved 0.jpg with method '3D_Rendering' as F:\MLpractrice\ct\output\files\aneurysm\3D_Rendering\0_10.jpg
# Processed and saved 0.jpg with method 'Heatmap_Visualization' as F:\MLpractrice\ct\output\files\aneurysm\Heatmap_Visualization\0_11.jpg
# Processed and saved 0.jpg with method '3D_Volume_Rendering' as F:\MLpractrice\ct\output\files\aneurysm\3D_Volume_Rendering\0_12.jpg
# Processed and saved 0.jpg with method 'Interactive_Segmentation' as F:\MLpractrice\ct\output\files\aneurysm\Interactive_Segmentation\0_13.jpg
# Processed and saved 1.jpg with method 'Basic_Color_Map' as F:\MLpractrice\ct\output\files\aneurysm\Basic_Color_Map\1_1.jpg
# Processed and saved 1.jpg with method 'Adaptive_Histogram_Equalization' as F:\MLpractrice\ct\output\files\aneurysm\Adaptive_Histogram_Equalization\1_2.jpg
# Processed and saved 1.jpg with method 'Contrast_Stretching' as F:\MLpractrice\ct\output\files\aneurysm\Contrast_Stretching\1_3.jpg
# Processed and saved 1.jpg with method 'Gaussian_Blur' as F:\MLpractrice\ct\output\files\aneurysm\Gaussian_Blur\1_4.jpg
# Processed and saved 1.jpg with method 'Edge_Detection' as F:\MLpractrice\ct\output\files\aneurysm\Edge_Detection\1_5.jpg
# Processed and saved 1.jpg with method 'Random_Color_Palette' as F:\MLpractrice\ct\output\files\aneurysm\Random_Color_Palette\1_6.jpg
# Processed and saved 1.jpg with method 'Gamma_Correction' as F:\MLpractrice\ct\output\files\aneurysm\Gamma_Correction\1_7.jpg
# Processed and saved 1.jpg with method 'LUT_Color_Map' as F:\MLpractrice\ct\output\files\aneurysm\LUT_Color_Map\1_8.jpg
# Processed and saved 1.jpg with method 'Alpha_Blending' as F:\MLpractrice\ct\output\files\aneurysm\Alpha_Blending\1_9.jpg
# Processed and saved 1.jpg with method '3D_Rendering' as F:\MLpractrice\ct\output\files\aneurysm\3D_Rendering\1_10.jpg
# Processed and saved 1.jpg with method 'Heatmap_Visualization' as F:\MLpractrice\ct\output\files\aneurysm\Heatmap_Visualization\1_11.jpg
# Processed and saved 1.jpg with method '3D_Volume_Rendering' as F:\MLpractrice\ct\output\files\aneurysm\3D_Volume_Rendering\1_12.jpg
# Processed and saved 1.jpg with method 'Interactive_Segmentation' as F:\MLpractrice\ct\output\files\aneurysm\Interactive_Segmentation\1_13.jpg
# Processed and saved 10.jpg with method 'Basic_Color_Map' as F:\MLpractrice\ct\output\files\aneurysm\Basic_Color_Map\10_1.jpg
# Processed and saved 10.jpg with method 'Adaptive_Histogram_Equalization' as F:\MLpractrice\ct\output\files\aneurysm\Adaptive_Histogram_Equalization\10_2.jpg
# Processed and saved 10.jpg with method 'Contrast_Stretching' as F:\MLpractrice\ct\output\files\aneurysm\Contrast_Stretching\10_3.jpg
# Processed and saved 10.jpg with method 'Gaussian_Blur' as F:\MLpractrice\ct\output\files\aneurysm\Gaussian_Blur\10_4.jpg
# Processed and saved 10.jpg with method 'Edge_Detection' as F:\MLpractrice\ct\output\files\aneurysm\Edge_Detection\10_5.jpg
# Processed and saved 10.jpg with method 'Random_Color_Palette' as F:\MLpractrice\ct\output\files\aneurysm\Random_Color_Palette\10_6.jpg
# Processed and saved 10.jpg with method 'Gamma_Correction' as F:\MLpractrice\ct\output\files\aneurysm\Gamma_Correction\10_7.jpg
# Processed and saved 10.jpg with method 'LUT_Color_Map' as F:\MLpractrice\ct\output\files\aneurysm\LUT_Color_Map\10_8.jpg
# Processed and saved 10.jpg with method 'Alpha_Blending' as F:\MLpractrice\ct\output\files\aneurysm\Alpha_Blending\10_9.jpg
# Processed and saved 10.jpg with method '3D_Rendering' as F:\MLpractrice\ct\output\files\aneurysm\3D_Rendering\10_10.jpg
# Processed and saved 10.jpg with method 'Heatmap_Visualization' as F:\MLpractrice\ct\output\files\aneurysm\Heatmap_Visualization\10_11.jpg
# Processed and saved 10.jpg with method '3D_Volume_Rendering' as F:\MLpractrice\ct\output\files\aneurysm\3D_Volume_Rendering\10_12.jpg
# Processed and saved 10.jpg with method 'Interactive_Segmentation' as F:\MLpractrice\ct\output\files\aneurysm\Interactive_Segmentation\10_13.jpg
# Processed and saved 11.jpg with method 'Basic_Color_Map' as F:\MLpractrice\ct\output\files\aneurysm\Basic_Color_Map\11_1.jpg
# Processed and saved 11.jpg with method 'Adaptive_Histogram_Equalization' as F:\MLpractrice\ct\output\files\aneurysm\Adaptive_Histogram_Equalization\11_2.jpg
# Processed and saved 11.jpg with method 'Contrast_Stretching' as F:\MLpractrice\ct\output\files\aneurysm\Contrast_Stretching\11_3.jpg
# Processed and saved 11.jpg with method 'Gaussian_Blur' as F:\MLpractrice\ct\output\files\aneurysm\Gaussian_Blur\11_4.jpg
# Processed and saved 11.jpg with method 'Edge_Detection' as F:\MLpractrice\ct\output\files\aneurysm\Edge_Detection\11_5.jpg
# Processed and saved 11.jpg with method 'Random_Color_Palette' as F:\MLpractrice\ct\output\files\aneurysm\Random_Color_Palette\11_6.jpg
# Processed and saved 11.jpg with method 'Gamma_Correction' as F:\MLpractrice\ct\output\files\aneurysm\Gamma_Correction\11_7.jpg
# Processed and saved 11.jpg with method 'LUT_Color_Map' as F:\MLpractrice\ct\output\files\aneurysm\LUT_Color_Map\11_8.jpg
# Processed and saved 11.jpg with method 'Alpha_Blending' as F:\MLpractrice\ct\output\files\aneurysm\Alpha_Blending\11_9.jpg
# Processed and saved 11.jpg with method '3D_Rendering' as F:\MLpractrice\ct\output\files\aneurysm\3D_Rendering\11_10.jpg
# Processed and saved 11.jpg with method 'Heatmap_Visualization' as F:\MLpractrice\ct\output\files\aneurysm\Heatmap_Visualization\11_11.jpg
# Processed and saved 11.jpg with method '3D_Volume_Rendering' as F:\MLpractrice\ct\output\files\aneurysm\3D_Volume_Rendering\11_12.jpg
# Processed and saved 11.jpg with method 'Interactive_Segmentation' as F:\MLpractrice\ct\output\files\aneurysm\Interactive_Segmentation\11_13.jpg
# Processed and saved 12.jpg with method 'Basic_Color_Map' as F:\MLpractrice\ct\output\files\aneurysm\Basic_Color_Map\12_1.jpg
# Processed and saved 12.jpg with method 'Adaptive_Histogram_Equalization' as F:\MLpractrice\ct\output\files\aneurysm\Adaptive_Histogram_Equalization\12_2.jpg
# Processed and saved 12.jpg with method 'Contrast_Stretching' as F:\MLpractrice\ct\output\files\aneurysm\Contrast_Stretching\12_3.jpg
# Processed and saved 12.jpg with method 'Gaussian_Blur' as F:\MLpractrice\ct\output\files\aneurysm\Gaussian_Blur\12_4.jpg
# Processed and saved 12.jpg with method 'Edge_Detection' as F:\MLpractrice\ct\output\files\aneurysm\Edge_Detection\12_5.jpg
# Processed and saved 12.jpg with method 'Random_Color_Palette' as F:\MLpractrice\ct\output\files\aneurysm\Random_Color_Palette\12_6.jpg
# Processed and saved 12.jpg with method 'Gamma_Correction' as F:\MLpractrice\ct\output\files\aneurysm\Gamma_Correction\12_7.jpg
# Processed and saved 12.jpg with method 'LUT_Color_Map' as F:\MLpractrice\ct\output\files\aneurysm\LUT_Color_Map\12_8.jpg
# Processed and saved 12.jpg with method 'Alpha_Blending' as F:\MLpractrice\ct\output\files\aneurysm\Alpha_Blending\12_9.jpg
# Processed and saved 12.jpg with method '3D_Rendering' as F:\MLpractrice\ct\output\files\aneurysm\3D_Rendering\12_10.jpg
# Processed and saved 12.jpg with method 'Heatmap_Visualization' as F:\MLpractrice\ct\output\files\aneurysm\Heatmap_Visualization\12_11.jpg
# Processed and saved 12.jpg with method '3D_Volume_Rendering' as F:\MLpractrice\ct\output\files\aneurysm\3D_Volume_Rendering\12_12.jpg
# Processed and saved 12.jpg with method 'Interactive_Segmentation' as F:\MLpractrice\ct\output\files\aneurysm\Interactive_Segmentation\12_13.jpg
# Processed and saved 13.jpg with method 'Basic_Color_Map' as F:\MLpractrice\ct\output\files\aneurysm\Basic_Color_Map\13_1.jpg
# Processed and saved 13.jpg with method 'Adaptive_Histogram_Equalization' as F:\MLpractrice\ct\output\files\aneurysm\Adaptive_Histogram_Equalization\13_2.jpg
# Processed and saved 13.jpg with method 'Contrast_Stretching' as F:\MLpractrice\ct\output\files\aneurysm\Contrast_Stretching\13_3.jpg
# Processed and saved 13.jpg with method 'Gaussian_Blur' as F:\MLpractrice\ct\output\files\aneurysm\Gaussian_Blur\13_4.jpg
# Processed and saved 13.jpg with method 'Edge_Detection' as F:\MLpractrice\ct\output\files\aneurysm\Edge_Detection\13_5.jpg
# Processed and saved 13.jpg with method 'Random_Color_Palette' as F:\MLpractrice\ct\output\files\aneurysm\Random_Color_Palette\13_6.jpg
# Processed and saved 13.jpg with method 'Gamma_Correction' as F:\MLpractrice\ct\output\files\aneurysm\Gamma_Correction\13_7.jpg
# Processed and saved 13.jpg with method 'LUT_Color_Map' as F:\MLpractrice\ct\output\files\aneurysm\LUT_Color_Map\13_8.jpg
# Processed and saved 13.jpg with method 'Alpha_Blending' as F:\MLpractrice\ct\output\files\aneurysm\Alpha_Blending\13_9.jpg
# Processed and saved 13.jpg with method '3D_Rendering' as F:\MLpractrice\ct\output\files\aneurysm\3D_Rendering\13_10.jpg
# Processed and saved 13.jpg with method 'Heatmap_Visualization' as F:\MLpractrice\ct\output\files\aneurysm\Heatmap_Visualization\13_11.jpg
# Processed and saved 13.jpg with method '3D_Volume_Rendering' as F:\MLpractrice\ct\output\files\aneurysm\3D_Volume_Rendering\13_12.jpg
# Processed and saved 13.jpg with method 'Interactive_Segmentation' as F:\MLpractrice\ct\output\files\aneurysm\Interactive_Segmentation\13_13.jpg
# Processed and saved 14.jpg with method 'Basic_Color_Map' as F:\MLpractrice\ct\output\files\aneurysm\Basic_Color_Map\14_1.jpg
# Processed and saved 14.jpg with method 'Adaptive_Histogram_Equalization' as F:\MLpractrice\ct\output\files\aneurysm\Adaptive_Histogram_Equalization\14_2.jpg
# Processed and saved 14.jpg with method 'Contrast_Stretching' as F:\MLpractrice\ct\output\files\aneurysm\Contrast_Stretching\14_3.jpg
# Processed and saved 14.jpg with method 'Gaussian_Blur' as F:\MLpractrice\ct\output\files\aneurysm\Gaussian_Blur\14_4.jpg
# Processed and saved 14.jpg with method 'Edge_Detection' as F:\MLpractrice\ct\output\files\aneurysm\Edge_Detection\14_5.jpg
# Processed and saved 14.jpg with method 'Random_Color_Palette' as F:\MLpractrice\ct\output\files\aneurysm\Random_Color_Palette\14_6.jpg
# Processed and saved 14.jpg with method 'Gamma_Correction' as F:\MLpractrice\ct\output\files\aneurysm\Gamma_Correction\14_7.jpg
# Processed and saved 14.jpg with method 'LUT_Color_Map' as F:\MLpractrice\ct\output\files\aneurysm\LUT_Color_Map\14_8.jpg
# Processed and saved 14.jpg with method 'Alpha_Blending' as F:\MLpractrice\ct\output\files\aneurysm\Alpha_Blending\14_9.jpg
# Processed and saved 14.jpg with method '3D_Rendering' as F:\MLpractrice\ct\output\files\aneurysm\3D_Rendering\14_10.jpg
# Processed and saved 14.jpg with method 'Heatmap_Visualization' as F:\MLpractrice\ct\output\files\aneurysm\Heatmap_Visualization\14_11.jpg
# Processed and saved 14.jpg with method '3D_Volume_Rendering' as F:\MLpractrice\ct\output\files\aneurysm\3D_Volume_Rendering\14_12.jpg
# Processed and saved 14.jpg with method 'Interactive_Segmentation' as F:\MLpractrice\ct\output\files\aneurysm\Interactive_Segmentation\14_13.jpg
# Processed and saved 15.jpg with method 'Basic_Color_Map' as F:\MLpractrice\ct\output\files\aneurysm\Basic_Color_Map\15_1.jpg
# Processed and saved 15.jpg with method 'Adaptive_Histogram_Equalization' as F:\MLpractrice\ct\output\files\aneurysm\Adaptive_Histogram_Equalization\15_2.jpg
# Processed and saved 15.jpg with method 'Contrast_Stretching' as F:\MLpractrice\ct\output\files\aneurysm\Contrast_Stretching\15_3.jpg
# Processed and saved 15.jpg with method 'Gaussian_Blur' as F:\MLpractrice\ct\output\files\aneurysm\Gaussian_Blur\15_4.jpg
# Processed and saved 15.jpg with method 'Edge_Detection' as F:\MLpractrice\ct\output\files\aneurysm\Edge_Detection\15_5.jpg
# Processed and saved 15.jpg with method 'Random_Color_Palette' as F:\MLpractrice\ct\output\files\aneurysm\Random_Color_Palette\15_6.jpg
# Processed and saved 15.jpg with method 'Gamma_Correction' as F:\MLpractrice\ct\output\files\aneurysm\Gamma_Correction\15_7.jpg
# Processed and saved 15.jpg with method 'LUT_Color_Map' as F:\MLpractrice\ct\output\files\aneurysm\LUT_Color_Map\15_8.jpg
# Processed and saved 15.jpg with method 'Alpha_Blending' as F:\MLpractrice\ct\output\files\aneurysm\Alpha_Blending\15_9.jpg
# Processed and saved 15.jpg with method '3D_Rendering' as F:\MLpractrice\ct\output\files\aneurysm\3D_Rendering\15_10.jpg
# Processed and saved 15.jpg with method 'Heatmap_Visualization' as F:\MLpractrice\ct\output\files\aneurysm\Heatmap_Visualization\15_11.jpg
# Processed and saved 15.jpg with method '3D_Volume_Rendering' as F:\MLpractrice\ct\output\files\aneurysm\3D_Volume_Rendering\15_12.jpg
# Processed and saved 15.jpg with method 'Interactive_Segmentation' as F:\MLpractrice\ct\output\files\aneurysm\Interactive_Segmentation\15_13.jpg
# Processed and saved 16.jpg with method 'Basic_Color_Map' as F:\MLpractrice\ct\output\files\aneurysm\Basic_Color_Map\16_1.jpg
# Processed and saved 16.jpg with method 'Adaptive_Histogram_Equalization' as F:\MLpractrice\ct\output\files\aneurysm\Adaptive_Histogram_Equalization\16_2.jpg
# Processed and saved 16.jpg with method 'Contrast_Stretching' as F:\MLpractrice\ct\output\files\aneurysm\Contrast_Stretching\16_3.jpg
# Processed and saved 16.jpg with method 'Gaussian_Blur' as F:\MLpractrice\ct\output\files\aneurysm\Gaussian_Blur\16_4.jpg
# Processed and saved 16.jpg with method 'Edge_Detection' as F:\MLpractrice\ct\output\files\aneurysm\Edge_Detection\16_5.jpg
# Processed and saved 16.jpg with method 'Random_Color_Palette' as F:\MLpractrice\ct\output\files\aneurysm\Random_Color_Palette\16_6.jpg
# Processed and saved 16.jpg with method 'Gamma_Correction' as F:\MLpractrice\ct\output\files\aneurysm\Gamma_Correction\16_7.jpg
# Processed and saved 16.jpg with method 'LUT_Color_Map' as F:\MLpractrice\ct\output\files\aneurysm\LUT_Color_Map\16_8.jpg
# Processed and saved 16.jpg with method 'Alpha_Blending' as F:\MLpractrice\ct\output\files\aneurysm\Alpha_Blending\16_9.jpg
# Processed and saved 16.jpg with method '3D_Rendering' as F:\MLpractrice\ct\output\files\aneurysm\3D_Rendering\16_10.jpg
# Processed and saved 16.jpg with method 'Heatmap_Visualization' as F:\MLpractrice\ct\output\files\aneurysm\Heatmap_Visualization\16_11.jpg
# Processed and saved 16.jpg with method '3D_Volume_Rendering' as F:\MLpractrice\ct\output\files\aneurysm\3D_Volume_Rendering\16_12.jpg
# Processed and saved 16.jpg with method 'Interactive_Segmentation' as F:\MLpractrice\ct\output\files\aneurysm\Interactive_Segmentation\16_13.jpg
# Processed and saved 17.jpg with method 'Basic_Color_Map' as F:\MLpractrice\ct\output\files\aneurysm\Basic_Color_Map\17_1.jpg
# Processed and saved 17.jpg with method 'Adaptive_Histogram_Equalization' as F:\MLpractrice\ct\output\files\aneurysm\Adaptive_Histogram_Equalization\17_2.jpg
# Processed and saved 17.jpg with method 'Contrast_Stretching' as F:\MLpractrice\ct\output\files\aneurysm\Contrast_Stretching\17_3.jpg
# Processed and saved 17.jpg with method 'Gaussian_Blur' as F:\MLpractrice\ct\output\files\aneurysm\Gaussian_Blur\17_4.jpg
# Processed and saved 17.jpg with method 'Edge_Detection' as F:\MLpractrice\ct\output\files\aneurysm\Edge_Detection\17_5.jpg
# Processed and saved 17.jpg with method 'Random_Color_Palette' as F:\MLpractrice\ct\output\files\aneurysm\Random_Color_Palette\17_6.jpg
# Processed and saved 17.jpg with method 'Gamma_Correction' as F:\MLpractrice\ct\output\files\aneurysm\Gamma_Correction\17_7.jpg
# Processed and saved 17.jpg with method 'LUT_Color_Map' as F:\MLpractrice\ct\output\files\aneurysm\LUT_Color_Map\17_8.jpg
# Processed and saved 17.jpg with method 'Alpha_Blending' as F:\MLpractrice\ct\output\files\aneurysm\Alpha_Blending\17_9.jpg
# Processed and saved 17.jpg with method '3D_Rendering' as F:\MLpractrice\ct\output\files\aneurysm\3D_Rendering\17_10.jpg
# Processed and saved 17.jpg with method 'Heatmap_Visualization' as F:\MLpractrice\ct\output\files\aneurysm\Heatmap_Visualization\17_11.jpg
# Processed and saved 17.jpg with method '3D_Volume_Rendering' as F:\MLpractrice\ct\output\files\aneurysm\3D_Volume_Rendering\17_12.jpg
# Processed and saved 17.jpg with method 'Interactive_Segmentation' as F:\MLpractrice\ct\output\files\aneurysm\Interactive_Segmentation\17_13.jpg
# Processed and saved 18.jpg with method 'Basic_Color_Map' as F:\MLpractrice\ct\output\files\aneurysm\Basic_Color_Map\18_1.jpg
# Processed and saved 18.jpg with method 'Adaptive_Histogram_Equalization' as F:\MLpractrice\ct\output\files\aneurysm\Adaptive_Histogram_Equalization\18_2.jpg
# Processed and saved 18.jpg with method 'Contrast_Stretching' as F:\MLpractrice\ct\output\files\aneurysm\Contrast_Stretching\18_3.jpg
# Processed and saved 18.jpg with method 'Gaussian_Blur' as F:\MLpractrice\ct\output\files\aneurysm\Gaussian_Blur\18_4.jpg
# Processed and saved 18.jpg with method 'Edge_Detection' as F:\MLpractrice\ct\output\files\aneurysm\Edge_Detection\18_5.jpg
# Processed and saved 18.jpg with method 'Random_Color_Palette' as F:\MLpractrice\ct\output\files\aneurysm\Random_Color_Palette\18_6.jpg
# Processed and saved 18.jpg with method 'Gamma_Correction' as F:\MLpractrice\ct\output\files\aneurysm\Gamma_Correction\18_7.jpg
# Processed and saved 18.jpg with method 'LUT_Color_Map' as F:\MLpractrice\ct\output\files\aneurysm\LUT_Color_Map\18_8.jpg
# Processed and saved 18.jpg with method 'Alpha_Blending' as F:\MLpractrice\ct\output\files\aneurysm\Alpha_Blending\18_9.jpg
# Processed and saved 18.jpg with method '3D_Rendering' as F:\MLpractrice\ct\output\files\aneurysm\3D_Rendering\18_10.jpg
# Processed and saved 18.jpg with method 'Heatmap_Visualization' as F:\MLpractrice\ct\output\files\aneurysm\Heatmap_Visualization\18_11.jpg
# Processed and saved 18.jpg with method '3D_Volume_Rendering' as F:\MLpractrice\ct\output\files\aneurysm\3D_Volume_Rendering\18_12.jpg
# Processed and saved 18.jpg with method 'Interactive_Segmentation' as F:\MLpractrice\ct\output\files\aneurysm\Interactive_Segmentation\18_13.jpg
# Processed and saved 19.jpg with method 'Basic_Color_Map' as F:\MLpractrice\ct\output\files\aneurysm\Basic_Color_Map\19_1.jpg
# Processed and saved 19.jpg with method 'Adaptive_Histogram_Equalization' as F:\MLpractrice\ct\output\files\aneurysm\Adaptive_Histogram_Equalization\19_2.jpg
# Processed and saved 19.jpg with method 'Contrast_Stretching' as F:\MLpractrice\ct\output\files\aneurysm\Contrast_Stretching\19_3.jpg
# Processed and saved 19.jpg with method 'Gaussian_Blur' as F:\MLpractrice\ct\output\files\aneurysm\Gaussian_Blur\19_4.jpg
# Processed and saved 19.jpg with method 'Edge_Detection' as F:\MLpractrice\ct\output\files\aneurysm\Edge_Detection\19_5.jpg
# Processed and saved 19.jpg with method 'Random_Color_Palette' as F:\MLpractrice\ct\output\files\aneurysm\Random_Color_Palette\19_6.jpg
# Processed and saved 19.jpg with method 'Gamma_Correction' as F:\MLpractrice\ct\output\files\aneurysm\Gamma_Correction\19_7.jpg
# Processed and saved 19.jpg with method 'LUT_Color_Map' as F:\MLpractrice\ct\output\files\aneurysm\LUT_Color_Map\19_8.jpg
# Processed and saved 19.jpg with method 'Alpha_Blending' as F:\MLpractrice\ct\output\files\aneurysm\Alpha_Blending\19_9.jpg
# Processed and saved 19.jpg with method '3D_Rendering' as F:\MLpractrice\ct\output\files\aneurysm\3D_Rendering\19_10.jpg
# Processed and saved 19.jpg with method 'Heatmap_Visualization' as F:\MLpractrice\ct\output\files\aneurysm\Heatmap_Visualization\19_11.jpg
# Processed and saved 19.jpg with method '3D_Volume_Rendering' as F:\MLpractrice\ct\output\files\aneurysm\3D_Volume_Rendering\19_12.jpg
# Processed and saved 19.jpg with method 'Interactive_Segmentation' as F:\MLpractrice\ct\output\files\aneurysm\Interactive_Segmentation\19_13.jpg
# Processed and saved 2.jpg with method 'Basic_Color_Map' as F:\MLpractrice\ct\output\files\aneurysm\Basic_Color_Map\2_1.jpg
# Processed and saved 2.jpg with method 'Adaptive_Histogram_Equalization' as F:\MLpractrice\ct\output\files\aneurysm\Adaptive_Histogram_Equalization\2_2.jpg
# Processed and saved 2.jpg with method 'Contrast_Stretching' as F:\MLpractrice\ct\output\files\aneurysm\Contrast_Stretching\2_3.jpg
# Processed and saved 2.jpg with method 'Gaussian_Blur' as F:\MLpractrice\ct\output\files\aneurysm\Gaussian_Blur\2_4.jpg
# Processed and saved 2.jpg with method 'Edge_Detection' as F:\MLpractrice\ct\output\files\aneurysm\Edge_Detection\2_5.jpg
# Processed and saved 2.jpg with method 'Random_Color_Palette' as F:\MLpractrice\ct\output\files\aneurysm\Random_Color_Palette\2_6.jpg
# Processed and saved 2.jpg with method 'Gamma_Correction' as F:\MLpractrice\ct\output\files\aneurysm\Gamma_Correction\2_7.jpg
# Processed and saved 2.jpg with method 'LUT_Color_Map' as F:\MLpractrice\ct\output\files\aneurysm\LUT_Color_Map\2_8.jpg
# Processed and saved 2.jpg with method 'Alpha_Blending' as F:\MLpractrice\ct\output\files\aneurysm\Alpha_Blending\2_9.jpg
# Processed and saved 2.jpg with method '3D_Rendering' as F:\MLpractrice\ct\output\files\aneurysm\3D_Rendering\2_10.jpg
# Processed and saved 2.jpg with method 'Heatmap_Visualization' as F:\MLpractrice\ct\output\files\aneurysm\Heatmap_Visualization\2_11.jpg
# Processed and saved 2.jpg with method '3D_Volume_Rendering' as F:\MLpractrice\ct\output\files\aneurysm\3D_Volume_Rendering\2_12.jpg
# Processed and saved 2.jpg with method 'Interactive_Segmentation' as F:\MLpractrice\ct\output\files\aneurysm\Interactive_Segmentation\2_13.jpg
# Processed and saved 20.jpg with method 'Basic_Color_Map' as F:\MLpractrice\ct\output\files\aneurysm\Basic_Color_Map\20_1.jpg
# Processed and saved 20.jpg with method 'Adaptive_Histogram_Equalization' as F:\MLpractrice\ct\output\files\aneurysm\Adaptive_Histogram_Equalization\20_2.jpg
# Processed and saved 20.jpg with method 'Contrast_Stretching' as F:\MLpractrice\ct\output\files\aneurysm\Contrast_Stretching\20_3.jpg
# Processed and saved 20.jpg with method 'Gaussian_Blur' as F:\MLpractrice\ct\output\files\aneurysm\Gaussian_Blur\20_4.jpg
# Processed and saved 20.jpg with method 'Edge_Detection' as F:\MLpractrice\ct\output\files\aneurysm\Edge_Detection\20_5.jpg
# Processed and saved 20.jpg with method 'Random_Color_Palette' as F:\MLpractrice\ct\output\files\aneurysm\Random_Color_Palette\20_6.jpg
# Processed and saved 20.jpg with method 'Gamma_Correction' as F:\MLpractrice\ct\output\files\aneurysm\Gamma_Correction\20_7.jpg
# Processed and saved 20.jpg with method 'LUT_Color_Map' as F:\MLpractrice\ct\output\files\aneurysm\LUT_Color_Map\20_8.jpg
# Processed and saved 20.jpg with method 'Alpha_Blending' as F:\MLpractrice\ct\output\files\aneurysm\Alpha_Blending\20_9.jpg
# Processed and saved 20.jpg with method '3D_Rendering' as F:\MLpractrice\ct\output\files\aneurysm\3D_Rendering\20_10.jpg
# Processed and saved 20.jpg with method 'Heatmap_Visualization' as F:\MLpractrice\ct\output\files\aneurysm\Heatmap_Visualization\20_11.jpg
# Processed and saved 20.jpg with method '3D_Volume_Rendering' as F:\MLpractrice\ct\output\files\aneurysm\3D_Volume_Rendering\20_12.jpg
# Processed and saved 20.jpg with method 'Interactive_Segmentation' as F:\MLpractrice\ct\output\files\aneurysm\Interactive_Segmentation\20_13.jpg
# Processed and saved 21.jpg with method 'Basic_Color_Map' as F:\MLpractrice\ct\output\files\aneurysm\Basic_Color_Map\21_1.jpg
# Processed and saved 21.jpg with method 'Adaptive_Histogram_Equalization' as F:\MLpractrice\ct\output\files\aneurysm\Adaptive_Histogram_Equalization\21_2.jpg
# Processed and saved 21.jpg with method 'Contrast_Stretching' as F:\MLpractrice\ct\output\files\aneurysm\Contrast_Stretching\21_3.jpg
# Processed and saved 21.jpg with method 'Gaussian_Blur' as F:\MLpractrice\ct\output\files\aneurysm\Gaussian_Blur\21_4.jpg
# Processed and saved 21.jpg with method 'Edge_Detection' as F:\MLpractrice\ct\output\files\aneurysm\Edge_Detection\21_5.jpg
# Processed and saved 21.jpg with method 'Random_Color_Palette' as F:\MLpractrice\ct\output\files\aneurysm\Random_Color_Palette\21_6.jpg
# Processed and saved 21.jpg with method 'Gamma_Correction' as F:\MLpractrice\ct\output\files\aneurysm\Gamma_Correction\21_7.jpg
# Processed and saved 21.jpg with method 'LUT_Color_Map' as F:\MLpractrice\ct\output\files\aneurysm\LUT_Color_Map\21_8.jpg
# Processed and saved 21.jpg with method 'Alpha_Blending' as F:\MLpractrice\ct\output\files\aneurysm\Alpha_Blending\21_9.jpg
# Processed and saved 21.jpg with method '3D_Rendering' as F:\MLpractrice\ct\output\files\aneurysm\3D_Rendering\21_10.jpg
# Processed and saved 21.jpg with method 'Heatmap_Visualization' as F:\MLpractrice\ct\output\files\aneurysm\Heatmap_Visualization\21_11.jpg
# Processed and saved 21.jpg with method '3D_Volume_Rendering' as F:\MLpractrice\ct\output\files\aneurysm\3D_Volume_Rendering\21_12.jpg
# Processed and saved 21.jpg with method 'Interactive_Segmentation' as F:\MLpractrice\ct\output\files\aneurysm\Interactive_Segmentation\21_13.jpg
# Processed and saved 22.jpg with method 'Basic_Color_Map' as F:\MLpractrice\ct\output\files\aneurysm\Basic_Color_Map\22_1.jpg
# Processed and saved 22.jpg with method 'Adaptive_Histogram_Equalization' as F:\MLpractrice\ct\output\files\aneurysm\Adaptive_Histogram_Equalization\22_2.jpg
# Processed and saved 22.jpg with method 'Contrast_Stretching' as F:\MLpractrice\ct\output\files\aneurysm\Contrast_Stretching\22_3.jpg
# Processed and saved 22.jpg with method 'Gaussian_Blur' as F:\MLpractrice\ct\output\files\aneurysm\Gaussian_Blur\22_4.jpg
# Processed and saved 22.jpg with method 'Edge_Detection' as F:\MLpractrice\ct\output\files\aneurysm\Edge_Detection\22_5.jpg
# Processed and saved 22.jpg with method 'Random_Color_Palette' as F:\MLpractrice\ct\output\files\aneurysm\Random_Color_Palette\22_6.jpg
# Processed and saved 22.jpg with method 'Gamma_Correction' as F:\MLpractrice\ct\output\files\aneurysm\Gamma_Correction\22_7.jpg
# Processed and saved 22.jpg with method 'LUT_Color_Map' as F:\MLpractrice\ct\output\files\aneurysm\LUT_Color_Map\22_8.jpg
# Processed and saved 22.jpg with method 'Alpha_Blending' as F:\MLpractrice\ct\output\files\aneurysm\Alpha_Blending\22_9.jpg
# Processed and saved 22.jpg with method '3D_Rendering' as F:\MLpractrice\ct\output\files\aneurysm\3D_Rendering\22_10.jpg
# Processed and saved 22.jpg with method 'Heatmap_Visualization' as F:\MLpractrice\ct\output\files\aneurysm\Heatmap_Visualization\22_11.jpg
# Processed and saved 22.jpg with method '3D_Volume_Rendering' as F:\MLpractrice\ct\output\files\aneurysm\3D_Volume_Rendering\22_12.jpg
# Processed and saved 22.jpg with method 'Interactive_Segmentation' as F:\MLpractrice\ct\output\files\aneurysm\Interactive_Segmentation\22_13.jpg
# Processed and saved 23.jpg with method 'Basic_Color_Map' as F:\MLpractrice\ct\output\files\aneurysm\Basic_Color_Map\23_1.jpg
# Processed and saved 23.jpg with method 'Adaptive_Histogram_Equalization' as F:\MLpractrice\ct\output\files\aneurysm\Adaptive_Histogram_Equalization\23_2.jpg
# Processed and saved 23.jpg with method 'Contrast_Stretching' as F:\MLpractrice\ct\output\files\aneurysm\Contrast_Stretching\23_3.jpg
# Processed and saved 23.jpg with method 'Gaussian_Blur' as F:\MLpractrice\ct\output\files\aneurysm\Gaussian_Blur\23_4.jpg
# Processed and saved 23.jpg with method 'Edge_Detection' as F:\MLpractrice\ct\output\files\aneurysm\Edge_Detection\23_5.jpg
# Processed and saved 23.jpg with method 'Random_Color_Palette' as F:\MLpractrice\ct\output\files\aneurysm\Random_Color_Palette\23_6.jpg
# Processed and saved 23.jpg with method 'Gamma_Correction' as F:\MLpractrice\ct\output\files\aneurysm\Gamma_Correction\23_7.jpg
# Processed and saved 23.jpg with method 'LUT_Color_Map' as F:\MLpractrice\ct\output\files\aneurysm\LUT_Color_Map\23_8.jpg
# Processed and saved 23.jpg with method 'Alpha_Blending' as F:\MLpractrice\ct\output\files\aneurysm\Alpha_Blending\23_9.jpg
# Processed and saved 23.jpg with method '3D_Rendering' as F:\MLpractrice\ct\output\files\aneurysm\3D_Rendering\23_10.jpg
# Processed and saved 23.jpg with method 'Heatmap_Visualization' as F:\MLpractrice\ct\output\files\aneurysm\Heatmap_Visualization\23_11.jpg
# Processed and saved 23.jpg with method '3D_Volume_Rendering' as F:\MLpractrice\ct\output\files\aneurysm\3D_Volume_Rendering\23_12.jpg
# Processed and saved 23.jpg with method 'Interactive_Segmentation' as F:\MLpractrice\ct\output\files\aneurysm\Interactive_Segmentation\23_13.jpg
# Processed and saved 24.jpg with method 'Basic_Color_Map' as F:\MLpractrice\ct\output\files\aneurysm\Basic_Color_Map\24_1.jpg
# Processed and saved 24.jpg with method 'Adaptive_Histogram_Equalization' as F:\MLpractrice\ct\output\files\aneurysm\Adaptive_Histogram_Equalization\24_2.jpg
# Processed and saved 24.jpg with method 'Contrast_Stretching' as F:\MLpractrice\ct\output\files\aneurysm\Contrast_Stretching\24_3.jpg
# Processed and saved 24.jpg with method 'Gaussian_Blur' as F:\MLpractrice\ct\output\files\aneurysm\Gaussian_Blur\24_4.jpg
# Processed and saved 24.jpg with method 'Edge_Detection' as F:\MLpractrice\ct\output\files\aneurysm\Edge_Detection\24_5.jpg
# Processed and saved 24.jpg with method 'Random_Color_Palette' as F:\MLpractrice\ct\output\files\aneurysm\Random_Color_Palette\24_6.jpg
# Processed and saved 24.jpg with method 'Gamma_Correction' as F:\MLpractrice\ct\output\files\aneurysm\Gamma_Correction\24_7.jpg
# Processed and saved 24.jpg with method 'LUT_Color_Map' as F:\MLpractrice\ct\output\files\aneurysm\LUT_Color_Map\24_8.jpg
# Processed and saved 24.jpg with method 'Alpha_Blending' as F:\MLpractrice\ct\output\files\aneurysm\Alpha_Blending\24_9.jpg
# Processed and saved 24.jpg with method '3D_Rendering' as F:\MLpractrice\ct\output\files\aneurysm\3D_Rendering\24_10.jpg
# Processed and saved 24.jpg with method 'Heatmap_Visualization' as F:\MLpractrice\ct\output\files\aneurysm\Heatmap_Visualization\24_11.jpg
# Processed and saved 24.jpg with method '3D_Volume_Rendering' as F:\MLpractrice\ct\output\files\aneurysm\3D_Volume_Rendering\24_12.jpg
# Processed and saved 24.jpg with method 'Interactive_Segmentation' as F:\MLpractrice\ct\output\files\aneurysm\Interactive_Segmentation\24_13.jpg
# Processed and saved 25.jpg with method 'Basic_Color_Map' as F:\MLpractrice\ct\output\files\aneurysm\Basic_Color_Map\25_1.jpg
# Processed and saved 25.jpg with method 'Adaptive_Histogram_Equalization' as F:\MLpractrice\ct\output\files\aneurysm\Adaptive_Histogram_Equalization\25_2.jpg
# Processed and saved 25.jpg with method 'Contrast_Stretching' as F:\MLpractrice\ct\output\files\aneurysm\Contrast_Stretching\25_3.jpg
# Processed and saved 25.jpg with method 'Gaussian_Blur' as F:\MLpractrice\ct\output\files\aneurysm\Gaussian_Blur\25_4.jpg
# Processed and saved 25.jpg with method 'Edge_Detection' as F:\MLpractrice\ct\output\files\aneurysm\Edge_Detection\25_5.jpg
# Processed and saved 25.jpg with method 'Random_Color_Palette' as F:\MLpractrice\ct\output\files\aneurysm\Random_Color_Palette\25_6.jpg
# Processed and saved 25.jpg with method 'Gamma_Correction' as F:\MLpractrice\ct\output\files\aneurysm\Gamma_Correction\25_7.jpg
# Processed and saved 25.jpg with method 'LUT_Color_Map' as F:\MLpractrice\ct\output\files\aneurysm\LUT_Color_Map\25_8.jpg
# Processed and saved 25.jpg with method 'Alpha_Blending' as F:\MLpractrice\ct\output\files\aneurysm\Alpha_Blending\25_9.jpg
# Processed and saved 25.jpg with method '3D_Rendering' as F:\MLpractrice\ct\output\files\aneurysm\3D_Rendering\25_10.jpg
# Processed and saved 25.jpg with method 'Heatmap_Visualization' as F:\MLpractrice\ct\output\files\aneurysm\Heatmap_Visualization\25_11.jpg
# Processed and saved 25.jpg with method '3D_Volume_Rendering' as F:\MLpractrice\ct\output\files\aneurysm\3D_Volume_Rendering\25_12.jpg
# Processed and saved 25.jpg with method 'Interactive_Segmentation' as F:\MLpractrice\ct\output\files\aneurysm\Interactive_Segmentation\25_13.jpg
# Processed and saved 26.jpg with method 'Basic_Color_Map' as F:\MLpractrice\ct\output\files\aneurysm\Basic_Color_Map\26_1.jpg
# Processed and saved 26.jpg with method 'Adaptive_Histogram_Equalization' as F:\MLpractrice\ct\output\files\aneurysm\Adaptive_Histogram_Equalization\26_2.jpg
# Processed and saved 26.jpg with method 'Contrast_Stretching' as F:\MLpractrice\ct\output\files\aneurysm\Contrast_Stretching\26_3.jpg
# Processed and saved 26.jpg with method 'Gaussian_Blur' as F:\MLpractrice\ct\output\files\aneurysm\Gaussian_Blur\26_4.jpg
# Processed and saved 26.jpg with method 'Edge_Detection' as F:\MLpractrice\ct\output\files\aneurysm\Edge_Detection\26_5.jpg
# Processed and saved 26.jpg with method 'Random_Color_Palette' as F:\MLpractrice\ct\output\files\aneurysm\Random_Color_Palette\26_6.jpg
# Processed and saved 26.jpg with method 'Gamma_Correction' as F:\MLpractrice\ct\output\files\aneurysm\Gamma_Correction\26_7.jpg
# Processed and saved 26.jpg with method 'LUT_Color_Map' as F:\MLpractrice\ct\output\files\aneurysm\LUT_Color_Map\26_8.jpg
# Processed and saved 26.jpg with method 'Alpha_Blending' as F:\MLpractrice\ct\output\files\aneurysm\Alpha_Blending\26_9.jpg
# Processed and saved 26.jpg with method '3D_Rendering' as F:\MLpractrice\ct\output\files\aneurysm\3D_Rendering\26_10.jpg
# Processed and saved 26.jpg with method 'Heatmap_Visualization' as F:\MLpractrice\ct\output\files\aneurysm\Heatmap_Visualization\26_11.jpg
# Processed and saved 26.jpg with method '3D_Volume_Rendering' as F:\MLpractrice\ct\output\files\aneurysm\3D_Volume_Rendering\26_12.jpg
# Processed and saved 26.jpg with method 'Interactive_Segmentation' as F:\MLpractrice\ct\output\files\aneurysm\Interactive_Segmentation\26_13.jpg
# Processed and saved 27.jpg with method 'Basic_Color_Map' as F:\MLpractrice\ct\output\files\aneurysm\Basic_Color_Map\27_1.jpg
# Processed and saved 27.jpg with method 'Adaptive_Histogram_Equalization' as F:\MLpractrice\ct\output\files\aneurysm\Adaptive_Histogram_Equalization\27_2.jpg
# Processed and saved 27.jpg with method 'Contrast_Stretching' as F:\MLpractrice\ct\output\files\aneurysm\Contrast_Stretching\27_3.jpg
# Processed and saved 27.jpg with method 'Gaussian_Blur' as F:\MLpractrice\ct\output\files\aneurysm\Gaussian_Blur\27_4.jpg
# Processed and saved 27.jpg with method 'Edge_Detection' as F:\MLpractrice\ct\output\files\aneurysm\Edge_Detection\27_5.jpg
# Processed and saved 27.jpg with method 'Random_Color_Palette' as F:\MLpractrice\ct\output\files\aneurysm\Random_Color_Palette\27_6.jpg
# Processed and saved 27.jpg with method 'Gamma_Correction' as F:\MLpractrice\ct\output\files\aneurysm\Gamma_Correction\27_7.jpg
# Processed and saved 27.jpg with method 'LUT_Color_Map' as F:\MLpractrice\ct\output\files\aneurysm\LUT_Color_Map\27_8.jpg
# Processed and saved 27.jpg with method 'Alpha_Blending' as F:\MLpractrice\ct\output\files\aneurysm\Alpha_Blending\27_9.jpg
# Processed and saved 27.jpg with method '3D_Rendering' as F:\MLpractrice\ct\output\files\aneurysm\3D_Rendering\27_10.jpg
# Processed and saved 27.jpg with method 'Heatmap_Visualization' as F:\MLpractrice\ct\output\files\aneurysm\Heatmap_Visualization\27_11.jpg
# Processed and saved 27.jpg with method '3D_Volume_Rendering' as F:\MLpractrice\ct\output\files\aneurysm\3D_Volume_Rendering\27_12.jpg
# Processed and saved 27.jpg with method 'Interactive_Segmentation' as F:\MLpractrice\ct\output\files\aneurysm\Interactive_Segmentation\27_13.jpg
# Processed and saved 28.jpg with method 'Basic_Color_Map' as F:\MLpractrice\ct\output\files\aneurysm\Basic_Color_Map\28_1.jpg
# Processed and saved 28.jpg with method 'Adaptive_Histogram_Equalization' as F:\MLpractrice\ct\output\files\aneurysm\Adaptive_Histogram_Equalization\28_2.jpg
# Processed and saved 28.jpg with method 'Contrast_Stretching' as F:\MLpractrice\ct\output\files\aneurysm\Contrast_Stretching\28_3.jpg
# Processed and saved 28.jpg with method 'Gaussian_Blur' as F:\MLpractrice\ct\output\files\aneurysm\Gaussian_Blur\28_4.jpg
# Processed and saved 28.jpg with method 'Edge_Detection' as F:\MLpractrice\ct\output\files\aneurysm\Edge_Detection\28_5.jpg
# Processed and saved 28.jpg with method 'Random_Color_Palette' as F:\MLpractrice\ct\output\files\aneurysm\Random_Color_Palette\28_6.jpg
# Processed and saved 28.jpg with method 'Gamma_Correction' as F:\MLpractrice\ct\output\files\aneurysm\Gamma_Correction\28_7.jpg
# Processed and saved 28.jpg with method 'LUT_Color_Map' as F:\MLpractrice\ct\output\files\aneurysm\LUT_Color_Map\28_8.jpg
# Processed and saved 28.jpg with method 'Alpha_Blending' as F:\MLpractrice\ct\output\files\aneurysm\Alpha_Blending\28_9.jpg
# Processed and saved 28.jpg with method '3D_Rendering' as F:\MLpractrice\ct\output\files\aneurysm\3D_Rendering\28_10.jpg
# Processed and saved 28.jpg with method 'Heatmap_Visualization' as F:\MLpractrice\ct\output\files\aneurysm\Heatmap_Visualization\28_11.jpg
# Processed and saved 28.jpg with method '3D_Volume_Rendering' as F:\MLpractrice\ct\output\files\aneurysm\3D_Volume_Rendering\28_12.jpg
# Processed and saved 28.jpg with method 'Interactive_Segmentation' as F:\MLpractrice\ct\output\files\aneurysm\Interactive_Segmentation\28_13.jpg
# Processed and saved 29.jpg with method 'Basic_Color_Map' as F:\MLpractrice\ct\output\files\aneurysm\Basic_Color_Map\29_1.jpg
# Processed and saved 29.jpg with method 'Adaptive_Histogram_Equalization' as F:\MLpractrice\ct\output\files\aneurysm\Adaptive_Histogram_Equalization\29_2.jpg
# Processed and saved 29.jpg with method 'Contrast_Stretching' as F:\MLpractrice\ct\output\files\aneurysm\Contrast_Stretching\29_3.jpg
# Processed and saved 29.jpg with method 'Gaussian_Blur' as F:\MLpractrice\ct\output\files\aneurysm\Gaussian_Blur\29_4.jpg
# Processed and saved 29.jpg with method 'Edge_Detection' as F:\MLpractrice\ct\output\files\aneurysm\Edge_Detection\29_5.jpg
# Processed and saved 29.jpg with method 'Random_Color_Palette' as F:\MLpractrice\ct\output\files\aneurysm\Random_Color_Palette\29_6.jpg
# Processed and saved 29.jpg with method 'Gamma_Correction' as F:\MLpractrice\ct\output\files\aneurysm\Gamma_Correction\29_7.jpg
# Processed and saved 29.jpg with method 'LUT_Color_Map' as F:\MLpractrice\ct\output\files\aneurysm\LUT_Color_Map\29_8.jpg
# Processed and saved 29.jpg with method 'Alpha_Blending' as F:\MLpractrice\ct\output\files\aneurysm\Alpha_Blending\29_9.jpg
# Processed and saved 29.jpg with method '3D_Rendering' as F:\MLpractrice\ct\output\files\aneurysm\3D_Rendering\29_10.jpg
# Processed and saved 29.jpg with method 'Heatmap_Visualization' as F:\MLpractrice\ct\output\files\aneurysm\Heatmap_Visualization\29_11.jpg
# Processed and saved 29.jpg with method '3D_Volume_Rendering' as F:\MLpractrice\ct\output\files\aneurysm\3D_Volume_Rendering\29_12.jpg
# Processed and saved 29.jpg with method 'Interactive_Segmentation' as F:\MLpractrice\ct\output\files\aneurysm\Interactive_Segmentation\29_13.jpg
# Processed and saved 3.jpg with method 'Basic_Color_Map' as F:\MLpractrice\ct\output\files\aneurysm\Basic_Color_Map\3_1.jpg
# Processed and saved 3.jpg with method 'Adaptive_Histogram_Equalization' as F:\MLpractrice\ct\output\files\aneurysm\Adaptive_Histogram_Equalization\3_2.jpg
# Processed and saved 3.jpg with method 'Contrast_Stretching' as F:\MLpractrice\ct\output\files\aneurysm\Contrast_Stretching\3_3.jpg
# Processed and saved 3.jpg with method 'Gaussian_Blur' as F:\MLpractrice\ct\output\files\aneurysm\Gaussian_Blur\3_4.jpg
# Processed and saved 3.jpg with method 'Edge_Detection' as F:\MLpractrice\ct\output\files\aneurysm\Edge_Detection\3_5.jpg
# Processed and saved 3.jpg with method 'Random_Color_Palette' as F:\MLpractrice\ct\output\files\aneurysm\Random_Color_Palette\3_6.jpg
# Processed and saved 3.jpg with method 'Gamma_Correction' as F:\MLpractrice\ct\output\files\aneurysm\Gamma_Correction\3_7.jpg
# Processed and saved 3.jpg with method 'LUT_Color_Map' as F:\MLpractrice\ct\output\files\aneurysm\LUT_Color_Map\3_8.jpg
# Processed and saved 3.jpg with method 'Alpha_Blending' as F:\MLpractrice\ct\output\files\aneurysm\Alpha_Blending\3_9.jpg
# Processed and saved 3.jpg with method '3D_Rendering' as F:\MLpractrice\ct\output\files\aneurysm\3D_Rendering\3_10.jpg
# Processed and saved 3.jpg with method 'Heatmap_Visualization' as F:\MLpractrice\ct\output\files\aneurysm\Heatmap_Visualization\3_11.jpg
# Processed and saved 3.jpg with method '3D_Volume_Rendering' as F:\MLpractrice\ct\output\files\aneurysm\3D_Volume_Rendering\3_12.jpg
# Processed and saved 3.jpg with method 'Interactive_Segmentation' as F:\MLpractrice\ct\output\files\aneurysm\Interactive_Segmentation\3_13.jpg
# Processed and saved 30.jpg with method 'Basic_Color_Map' as F:\MLpractrice\ct\output\files\aneurysm\Basic_Color_Map\30_1.jpg
# Processed and saved 30.jpg with method 'Adaptive_Histogram_Equalization' as F:\MLpractrice\ct\output\files\aneurysm\Adaptive_Histogram_Equalization\30_2.jpg
# Processed and saved 30.jpg with method 'Contrast_Stretching' as F:\MLpractrice\ct\output\files\aneurysm\Contrast_Stretching\30_3.jpg
# Processed and saved 30.jpg with method 'Gaussian_Blur' as F:\MLpractrice\ct\output\files\aneurysm\Gaussian_Blur\30_4.jpg
# Processed and saved 30.jpg with method 'Edge_Detection' as F:\MLpractrice\ct\output\files\aneurysm\Edge_Detection\30_5.jpg
# Processed and saved 30.jpg with method 'Random_Color_Palette' as F:\MLpractrice\ct\output\files\aneurysm\Random_Color_Palette\30_6.jpg
# Processed and saved 30.jpg with method 'Gamma_Correction' as F:\MLpractrice\ct\output\files\aneurysm\Gamma_Correction\30_7.jpg
# Processed and saved 30.jpg with method 'LUT_Color_Map' as F:\MLpractrice\ct\output\files\aneurysm\LUT_Color_Map\30_8.jpg
# Processed and saved 30.jpg with method 'Alpha_Blending' as F:\MLpractrice\ct\output\files\aneurysm\Alpha_Blending\30_9.jpg
# Processed and saved 30.jpg with method '3D_Rendering' as F:\MLpractrice\ct\output\files\aneurysm\3D_Rendering\30_10.jpg
# Processed and saved 30.jpg with method 'Heatmap_Visualization' as F:\MLpractrice\ct\output\files\aneurysm\Heatmap_Visualization\30_11.jpg
# Processed and saved 30.jpg with method '3D_Volume_Rendering' as F:\MLpractrice\ct\output\files\aneurysm\3D_Volume_Rendering\30_12.jpg
# Processed and saved 30.jpg with method 'Interactive_Segmentation' as F:\MLpractrice\ct\output\files\aneurysm\Interactive_Segmentation\30_13.jpg
# Processed and saved 31.jpg with method 'Basic_Color_Map' as F:\MLpractrice\ct\output\files\aneurysm\Basic_Color_Map\31_1.jpg
# Processed and saved 31.jpg with method 'Adaptive_Histogram_Equalization' as F:\MLpractrice\ct\output\files\aneurysm\Adaptive_Histogram_Equalization\31_2.jpg
# Processed and saved 31.jpg with method 'Contrast_Stretching' as F:\MLpractrice\ct\output\files\aneurysm\Contrast_Stretching\31_3.jpg
# Processed and saved 31.jpg with method 'Gaussian_Blur' as F:\MLpractrice\ct\output\files\aneurysm\Gaussian_Blur\31_4.jpg
# Processed and saved 31.jpg with method 'Edge_Detection' as F:\MLpractrice\ct\output\files\aneurysm\Edge_Detection\31_5.jpg
# Processed and saved 31.jpg with method 'Random_Color_Palette' as F:\MLpractrice\ct\output\files\aneurysm\Random_Color_Palette\31_6.jpg
# Processed and saved 31.jpg with method 'Gamma_Correction' as F:\MLpractrice\ct\output\files\aneurysm\Gamma_Correction\31_7.jpg
# Processed and saved 31.jpg with method 'LUT_Color_Map' as F:\MLpractrice\ct\output\files\aneurysm\LUT_Color_Map\31_8.jpg
# Processed and saved 31.jpg with method 'Alpha_Blending' as F:\MLpractrice\ct\output\files\aneurysm\Alpha_Blending\31_9.jpg
# Processed and saved 31.jpg with method '3D_Rendering' as F:\MLpractrice\ct\output\files\aneurysm\3D_Rendering\31_10.jpg
# Processed and saved 31.jpg with method 'Heatmap_Visualization' as F:\MLpractrice\ct\output\files\aneurysm\Heatmap_Visualization\31_11.jpg
# Processed and saved 31.jpg with method '3D_Volume_Rendering' as F:\MLpractrice\ct\output\files\aneurysm\3D_Volume_Rendering\31_12.jpg
# Processed and saved 31.jpg with method 'Interactive_Segmentation' as F:\MLpractrice\ct\output\files\aneurysm\Interactive_Segmentation\31_13.jpg
# Processed and saved 32.jpg with method 'Basic_Color_Map' as F:\MLpractrice\ct\output\files\aneurysm\Basic_Color_Map\32_1.jpg
# Processed and saved 32.jpg with method 'Adaptive_Histogram_Equalization' as F:\MLpractrice\ct\output\files\aneurysm\Adaptive_Histogram_Equalization\32_2.jpg
# Processed and saved 32.jpg with method 'Contrast_Stretching' as F:\MLpractrice\ct\output\files\aneurysm\Contrast_Stretching\32_3.jpg
# Processed and saved 32.jpg with method 'Gaussian_Blur' as F:\MLpractrice\ct\output\files\aneurysm\Gaussian_Blur\32_4.jpg
# Processed and saved 32.jpg with method 'Edge_Detection' as F:\MLpractrice\ct\output\files\aneurysm\Edge_Detection\32_5.jpg
# Processed and saved 32.jpg with method 'Random_Color_Palette' as F:\MLpractrice\ct\output\files\aneurysm\Random_Color_Palette\32_6.jpg
# Processed and saved 32.jpg with method 'Gamma_Correction' as F:\MLpractrice\ct\output\files\aneurysm\Gamma_Correction\32_7.jpg
# Processed and saved 32.jpg with method 'LUT_Color_Map' as F:\MLpractrice\ct\output\files\aneurysm\LUT_Color_Map\32_8.jpg
# Processed and saved 32.jpg with method 'Alpha_Blending' as F:\MLpractrice\ct\output\files\aneurysm\Alpha_Blending\32_9.jpg
# Processed and saved 32.jpg with method '3D_Rendering' as F:\MLpractrice\ct\output\files\aneurysm\3D_Rendering\32_10.jpg
# Processed and saved 32.jpg with method 'Heatmap_Visualization' as F:\MLpractrice\ct\output\files\aneurysm\Heatmap_Visualization\32_11.jpg
# Processed and saved 32.jpg with method '3D_Volume_Rendering' as F:\MLpractrice\ct\output\files\aneurysm\3D_Volume_Rendering\32_12.jpg
# Processed and saved 32.jpg with method 'Interactive_Segmentation' as F:\MLpractrice\ct\output\files\aneurysm\Interactive_Segmentation\32_13.jpg
# Processed and saved 33.jpg with method 'Basic_Color_Map' as F:\MLpractrice\ct\output\files\aneurysm\Basic_Color_Map\33_1.jpg
# Processed and saved 33.jpg with method 'Adaptive_Histogram_Equalization' as F:\MLpractrice\ct\output\files\aneurysm\Adaptive_Histogram_Equalization\33_2.jpg
# Processed and saved 33.jpg with method 'Contrast_Stretching' as F:\MLpractrice\ct\output\files\aneurysm\Contrast_Stretching\33_3.jpg
# Processed and saved 33.jpg with method 'Gaussian_Blur' as F:\MLpractrice\ct\output\files\aneurysm\Gaussian_Blur\33_4.jpg
# Processed and saved 33.jpg with method 'Edge_Detection' as F:\MLpractrice\ct\output\files\aneurysm\Edge_Detection\33_5.jpg
# Processed and saved 33.jpg with method 'Random_Color_Palette' as F:\MLpractrice\ct\output\files\aneurysm\Random_Color_Palette\33_6.jpg
# Processed and saved 33.jpg with method 'Gamma_Correction' as F:\MLpractrice\ct\output\files\aneurysm\Gamma_Correction\33_7.jpg
# Processed and saved 33.jpg with method 'LUT_Color_Map' as F:\MLpractrice\ct\output\files\aneurysm\LUT_Color_Map\33_8.jpg
# Processed and saved 33.jpg with method 'Alpha_Blending' as F:\MLpractrice\ct\output\files\aneurysm\Alpha_Blending\33_9.jpg
# Processed and saved 33.jpg with method '3D_Rendering' as F:\MLpractrice\ct\output\files\aneurysm\3D_Rendering\33_10.jpg
# Processed and saved 33.jpg with method 'Heatmap_Visualization' as F:\MLpractrice\ct\output\files\aneurysm\Heatmap_Visualization\33_11.jpg
# Processed and saved 33.jpg with method '3D_Volume_Rendering' as F:\MLpractrice\ct\output\files\aneurysm\3D_Volume_Rendering\33_12.jpg
# Processed and saved 33.jpg with method 'Interactive_Segmentation' as F:\MLpractrice\ct\output\files\aneurysm\Interactive_Segmentation\33_13.jpg
# Processed and saved 34.jpg with method 'Basic_Color_Map' as F:\MLpractrice\ct\output\files\aneurysm\Basic_Color_Map\34_1.jpg
# ...
# Processed and saved 76.jpg with method 'Random_Color_Palette' as F:\MLpractrice\ct\output\files\tumor\Random_Color_Palette\76_6.jpg
# Processed and saved 76.jpg with method 'Gamma_Correction' as F:\MLpractrice\ct\output\files\tumor\Gamma_Correction\76_7.jpg
# Processed and saved 76.jpg with method 'LUT_Color_Map' as F:\MLpractrice\ct\output\files\tumor\LUT_Color_Map\76_8.jpg
# Processed and saved 76.jpg with method 'Alpha_Blending' as F:\MLpractrice\ct\output\files\tumor\Alpha_Blending\76_9.jpg
# Processed and saved 76.jpg with method '3D_Rendering' as F:\MLpractrice\ct\output\files\tumor\3D_Rendering\76_10.jpg
# Processed and saved 76.jpg with method 'Heatmap_Visualization' as F:\MLpractrice\ct\output\files\tumor\Heatmap_Visualization\76_11.jpg
# Processed and saved 76.jpg with method '3D_Volume_Rendering' as F:\MLpractrice\ct\output\files\tumor\3D_Volume_Rendering\76_12.jpg
# Processed and saved 76.jpg with method 'Interactive_Segmentation' as F:\MLpractrice\ct\output\files\tumor\Interactive_Segmentation\76_13.jpg
# Processed and saved 77.jpg with method 'Basic_Color_Map' as F:\MLpractrice\ct\output\files\tumor\Basic_Color_Map\77_1.jpg
# Processed and saved 77.jpg with method 'Adaptive_Histogram_Equalization' as F:\MLpractrice\ct\output\files\tumor\Adaptive_Histogram_Equalization\77_2.jpg
# Processed and saved 77.jpg with method 'Contrast_Stretching' as F:\MLpractrice\ct\output\files\tumor\Contrast_Stretching\77_3.jpg
# Processed and saved 77.jpg with method 'Gaussian_Blur' as F:\MLpractrice\ct\output\files\tumor\Gaussian_Blur\77_4.jpg
# Processed and saved 77.jpg with method 'Edge_Detection' as F:\MLpractrice\ct\output\files\tumor\Edge_Detection\77_5.jpg
# Processed and saved 77.jpg with method 'Random_Color_Palette' as F:\MLpractrice\ct\output\files\tumor\Random_Color_Palette\77_6.jpg
# Processed and saved 77.jpg with method 'Gamma_Correction' as F:\MLpractrice\ct\output\files\tumor\Gamma_Correction\77_7.jpg
# Processed and saved 77.jpg with method 'LUT_Color_Map' as F:\MLpractrice\ct\output\files\tumor\LUT_Color_Map\77_8.jpg
# Processed and saved 77.jpg with method 'Alpha_Blending' as F:\MLpractrice\ct\output\files\tumor\Alpha_Blending\77_9.jpg
# Processed and saved 77.jpg with method '3D_Rendering' as F:\MLpractrice\ct\output\files\tumor\3D_Rendering\77_10.jpg
# Processed and saved 77.jpg with method 'Heatmap_Visualization' as F:\MLpractrice\ct\output\files\tumor\Heatmap_Visualization\77_11.jpg
# Processed and saved 77.jpg with method '3D_Volume_Rendering' as F:\MLpractrice\ct\output\files\tumor\3D_Volume_Rendering\77_12.jpg
# Processed and saved 77.jpg with method 'Interactive_Segmentation' as F:\MLpractrice\ct\output\files\tumor\Interactive_Segmentation\77_13.jpg
# Processed and saved 78.jpg with method 'Basic_Color_Map' as F:\MLpractrice\ct\output\files\tumor\Basic_Color_Map\78_1.jpg
# Processed and saved 78.jpg with method 'Adaptive_Histogram_Equalization' as F:\MLpractrice\ct\output\files\tumor\Adaptive_Histogram_Equalization\78_2.jpg
# Processed and saved 78.jpg with method 'Contrast_Stretching' as F:\MLpractrice\ct\output\files\tumor\Contrast_Stretching\78_3.jpg
# Processed and saved 78.jpg with method 'Gaussian_Blur' as F:\MLpractrice\ct\output\files\tumor\Gaussian_Blur\78_4.jpg
# Processed and saved 78.jpg with method 'Edge_Detection' as F:\MLpractrice\ct\output\files\tumor\Edge_Detection\78_5.jpg
# Processed and saved 78.jpg with method 'Random_Color_Palette' as F:\MLpractrice\ct\output\files\tumor\Random_Color_Palette\78_6.jpg
# Processed and saved 78.jpg with method 'Gamma_Correction' as F:\MLpractrice\ct\output\files\tumor\Gamma_Correction\78_7.jpg
# Processed and saved 78.jpg with method 'LUT_Color_Map' as F:\MLpractrice\ct\output\files\tumor\LUT_Color_Map\78_8.jpg
# Processed and saved 78.jpg with method 'Alpha_Blending' as F:\MLpractrice\ct\output\files\tumor\Alpha_Blending\78_9.jpg
# Processed and saved 78.jpg with method '3D_Rendering' as F:\MLpractrice\ct\output\files\tumor\3D_Rendering\78_10.jpg
# Processed and saved 78.jpg with method 'Heatmap_Visualization' as F:\MLpractrice\ct\output\files\tumor\Heatmap_Visualization\78_11.jpg
# Processed and saved 78.jpg with method '3D_Volume_Rendering' as F:\MLpractrice\ct\output\files\tumor\3D_Volume_Rendering\78_12.jpg
# Processed and saved 78.jpg with method 'Interactive_Segmentation' as F:\MLpractrice\ct\output\files\tumor\Interactive_Segmentation\78_13.jpg
# Processed and saved 79.jpg with method 'Basic_Color_Map' as F:\MLpractrice\ct\output\files\tumor\Basic_Color_Map\79_1.jpg
# Processed and saved 79.jpg with method 'Adaptive_Histogram_Equalization' as F:\MLpractrice\ct\output\files\tumor\Adaptive_Histogram_Equalization\79_2.jpg
# Processed and saved 79.jpg with method 'Contrast_Stretching' as F:\MLpractrice\ct\output\files\tumor\Contrast_Stretching\79_3.jpg
# Processed and saved 79.jpg with method 'Gaussian_Blur' as F:\MLpractrice\ct\output\files\tumor\Gaussian_Blur\79_4.jpg
# Processed and saved 79.jpg with method 'Edge_Detection' as F:\MLpractrice\ct\output\files\tumor\Edge_Detection\79_5.jpg
# Processed and saved 79.jpg with method 'Random_Color_Palette' as F:\MLpractrice\ct\output\files\tumor\Random_Color_Palette\79_6.jpg
# Processed and saved 79.jpg with method 'Gamma_Correction' as F:\MLpractrice\ct\output\files\tumor\Gamma_Correction\79_7.jpg
# Processed and saved 79.jpg with method 'LUT_Color_Map' as F:\MLpractrice\ct\output\files\tumor\LUT_Color_Map\79_8.jpg
# Processed and saved 79.jpg with method 'Alpha_Blending' as F:\MLpractrice\ct\output\files\tumor\Alpha_Blending\79_9.jpg
# Processed and saved 79.jpg with method '3D_Rendering' as F:\MLpractrice\ct\output\files\tumor\3D_Rendering\79_10.jpg
# Processed and saved 79.jpg with method 'Heatmap_Visualization' as F:\MLpractrice\ct\output\files\tumor\Heatmap_Visualization\79_11.jpg
# Processed and saved 79.jpg with method '3D_Volume_Rendering' as F:\MLpractrice\ct\output\files\tumor\3D_Volume_Rendering\79_12.jpg
# Processed and saved 79.jpg with method 'Interactive_Segmentation' as F:\MLpractrice\ct\output\files\tumor\Interactive_Segmentation\79_13.jpg
# Processed and saved 8.jpg with method 'Basic_Color_Map' as F:\MLpractrice\ct\output\files\tumor\Basic_Color_Map\8_1.jpg
# Processed and saved 8.jpg with method 'Adaptive_Histogram_Equalization' as F:\MLpractrice\ct\output\files\tumor\Adaptive_Histogram_Equalization\8_2.jpg
# Processed and saved 8.jpg with method 'Contrast_Stretching' as F:\MLpractrice\ct\output\files\tumor\Contrast_Stretching\8_3.jpg
# Processed and saved 8.jpg with method 'Gaussian_Blur' as F:\MLpractrice\ct\output\files\tumor\Gaussian_Blur\8_4.jpg
# Processed and saved 8.jpg with method 'Edge_Detection' as F:\MLpractrice\ct\output\files\tumor\Edge_Detection\8_5.jpg
# Processed and saved 8.jpg with method 'Random_Color_Palette' as F:\MLpractrice\ct\output\files\tumor\Random_Color_Palette\8_6.jpg
# Processed and saved 8.jpg with method 'Gamma_Correction' as F:\MLpractrice\ct\output\files\tumor\Gamma_Correction\8_7.jpg
# Processed and saved 8.jpg with method 'LUT_Color_Map' as F:\MLpractrice\ct\output\files\tumor\LUT_Color_Map\8_8.jpg
# Processed and saved 8.jpg with method 'Alpha_Blending' as F:\MLpractrice\ct\output\files\tumor\Alpha_Blending\8_9.jpg
# Processed and saved 8.jpg with method '3D_Rendering' as F:\MLpractrice\ct\output\files\tumor\3D_Rendering\8_10.jpg
# Processed and saved 8.jpg with method 'Heatmap_Visualization' as F:\MLpractrice\ct\output\files\tumor\Heatmap_Visualization\8_11.jpg
# Processed and saved 8.jpg with method '3D_Volume_Rendering' as F:\MLpractrice\ct\output\files\tumor\3D_Volume_Rendering\8_12.jpg
# Processed and saved 8.jpg with method 'Interactive_Segmentation' as F:\MLpractrice\ct\output\files\tumor\Interactive_Segmentation\8_13.jpg
# Processed and saved 80.jpg with method 'Basic_Color_Map' as F:\MLpractrice\ct\output\files\tumor\Basic_Color_Map\80_1.jpg
# Processed and saved 80.jpg with method 'Adaptive_Histogram_Equalization' as F:\MLpractrice\ct\output\files\tumor\Adaptive_Histogram_Equalization\80_2.jpg
# Processed and saved 80.jpg with method 'Contrast_Stretching' as F:\MLpractrice\ct\output\files\tumor\Contrast_Stretching\80_3.jpg
# Processed and saved 80.jpg with method 'Gaussian_Blur' as F:\MLpractrice\ct\output\files\tumor\Gaussian_Blur\80_4.jpg
# Processed and saved 80.jpg with method 'Edge_Detection' as F:\MLpractrice\ct\output\files\tumor\Edge_Detection\80_5.jpg
# Processed and saved 80.jpg with method 'Random_Color_Palette' as F:\MLpractrice\ct\output\files\tumor\Random_Color_Palette\80_6.jpg
# Processed and saved 80.jpg with method 'Gamma_Correction' as F:\MLpractrice\ct\output\files\tumor\Gamma_Correction\80_7.jpg
# Processed and saved 80.jpg with method 'LUT_Color_Map' as F:\MLpractrice\ct\output\files\tumor\LUT_Color_Map\80_8.jpg
# Processed and saved 80.jpg with method 'Alpha_Blending' as F:\MLpractrice\ct\output\files\tumor\Alpha_Blending\80_9.jpg
# Processed and saved 80.jpg with method '3D_Rendering' as F:\MLpractrice\ct\output\files\tumor\3D_Rendering\80_10.jpg
# Processed and saved 80.jpg with method 'Heatmap_Visualization' as F:\MLpractrice\ct\output\files\tumor\Heatmap_Visualization\80_11.jpg
# Processed and saved 80.jpg with method '3D_Volume_Rendering' as F:\MLpractrice\ct\output\files\tumor\3D_Volume_Rendering\80_12.jpg
# Processed and saved 80.jpg with method 'Interactive_Segmentation' as F:\MLpractrice\ct\output\files\tumor\Interactive_Segmentation\80_13.jpg
# Processed and saved 81.jpg with method 'Basic_Color_Map' as F:\MLpractrice\ct\output\files\tumor\Basic_Color_Map\81_1.jpg
# Processed and saved 81.jpg with method 'Adaptive_Histogram_Equalization' as F:\MLpractrice\ct\output\files\tumor\Adaptive_Histogram_Equalization\81_2.jpg
# Processed and saved 81.jpg with method 'Contrast_Stretching' as F:\MLpractrice\ct\output\files\tumor\Contrast_Stretching\81_3.jpg
# Processed and saved 81.jpg with method 'Gaussian_Blur' as F:\MLpractrice\ct\output\files\tumor\Gaussian_Blur\81_4.jpg
# Processed and saved 81.jpg with method 'Edge_Detection' as F:\MLpractrice\ct\output\files\tumor\Edge_Detection\81_5.jpg
# Processed and saved 81.jpg with method 'Random_Color_Palette' as F:\MLpractrice\ct\output\files\tumor\Random_Color_Palette\81_6.jpg
# Processed and saved 81.jpg with method 'Gamma_Correction' as F:\MLpractrice\ct\output\files\tumor\Gamma_Correction\81_7.jpg
# Processed and saved 81.jpg with method 'LUT_Color_Map' as F:\MLpractrice\ct\output\files\tumor\LUT_Color_Map\81_8.jpg
# Processed and saved 81.jpg with method 'Alpha_Blending' as F:\MLpractrice\ct\output\files\tumor\Alpha_Blending\81_9.jpg
# Processed and saved 81.jpg with method '3D_Rendering' as F:\MLpractrice\ct\output\files\tumor\3D_Rendering\81_10.jpg
# Processed and saved 81.jpg with method 'Heatmap_Visualization' as F:\MLpractrice\ct\output\files\tumor\Heatmap_Visualization\81_11.jpg
# Processed and saved 81.jpg with method '3D_Volume_Rendering' as F:\MLpractrice\ct\output\files\tumor\3D_Volume_Rendering\81_12.jpg
# Processed and saved 81.jpg with method 'Interactive_Segmentation' as F:\MLpractrice\ct\output\files\tumor\Interactive_Segmentation\81_13.jpg
# Processed and saved 82.jpg with method 'Basic_Color_Map' as F:\MLpractrice\ct\output\files\tumor\Basic_Color_Map\82_1.jpg
# Processed and saved 82.jpg with method 'Adaptive_Histogram_Equalization' as F:\MLpractrice\ct\output\files\tumor\Adaptive_Histogram_Equalization\82_2.jpg
# Processed and saved 82.jpg with method 'Contrast_Stretching' as F:\MLpractrice\ct\output\files\tumor\Contrast_Stretching\82_3.jpg
# Processed and saved 82.jpg with method 'Gaussian_Blur' as F:\MLpractrice\ct\output\files\tumor\Gaussian_Blur\82_4.jpg
# Processed and saved 82.jpg with method 'Edge_Detection' as F:\MLpractrice\ct\output\files\tumor\Edge_Detection\82_5.jpg
# Processed and saved 82.jpg with method 'Random_Color_Palette' as F:\MLpractrice\ct\output\files\tumor\Random_Color_Palette\82_6.jpg
# Processed and saved 82.jpg with method 'Gamma_Correction' as F:\MLpractrice\ct\output\files\tumor\Gamma_Correction\82_7.jpg
# Processed and saved 82.jpg with method 'LUT_Color_Map' as F:\MLpractrice\ct\output\files\tumor\LUT_Color_Map\82_8.jpg
# Processed and saved 82.jpg with method 'Alpha_Blending' as F:\MLpractrice\ct\output\files\tumor\Alpha_Blending\82_9.jpg
# Processed and saved 82.jpg with method '3D_Rendering' as F:\MLpractrice\ct\output\files\tumor\3D_Rendering\82_10.jpg
# Processed and saved 82.jpg with method 'Heatmap_Visualization' as F:\MLpractrice\ct\output\files\tumor\Heatmap_Visualization\82_11.jpg
# Processed and saved 82.jpg with method '3D_Volume_Rendering' as F:\MLpractrice\ct\output\files\tumor\3D_Volume_Rendering\82_12.jpg
# Processed and saved 82.jpg with method 'Interactive_Segmentation' as F:\MLpractrice\ct\output\files\tumor\Interactive_Segmentation\82_13.jpg
# Processed and saved 83.jpg with method 'Basic_Color_Map' as F:\MLpractrice\ct\output\files\tumor\Basic_Color_Map\83_1.jpg
# Processed and saved 83.jpg with method 'Adaptive_Histogram_Equalization' as F:\MLpractrice\ct\output\files\tumor\Adaptive_Histogram_Equalization\83_2.jpg
# Processed and saved 83.jpg with method 'Contrast_Stretching' as F:\MLpractrice\ct\output\files\tumor\Contrast_Stretching\83_3.jpg
# Processed and saved 83.jpg with method 'Gaussian_Blur' as F:\MLpractrice\ct\output\files\tumor\Gaussian_Blur\83_4.jpg
# Processed and saved 83.jpg with method 'Edge_Detection' as F:\MLpractrice\ct\output\files\tumor\Edge_Detection\83_5.jpg
# Processed and saved 83.jpg with method 'Random_Color_Palette' as F:\MLpractrice\ct\output\files\tumor\Random_Color_Palette\83_6.jpg
# Processed and saved 83.jpg with method 'Gamma_Correction' as F:\MLpractrice\ct\output\files\tumor\Gamma_Correction\83_7.jpg
# Processed and saved 83.jpg with method 'LUT_Color_Map' as F:\MLpractrice\ct\output\files\tumor\LUT_Color_Map\83_8.jpg
# Processed and saved 83.jpg with method 'Alpha_Blending' as F:\MLpractrice\ct\output\files\tumor\Alpha_Blending\83_9.jpg
# Processed and saved 83.jpg with method '3D_Rendering' as F:\MLpractrice\ct\output\files\tumor\3D_Rendering\83_10.jpg
# Processed and saved 83.jpg with method 'Heatmap_Visualization' as F:\MLpractrice\ct\output\files\tumor\Heatmap_Visualization\83_11.jpg
# Processed and saved 83.jpg with method '3D_Volume_Rendering' as F:\MLpractrice\ct\output\files\tumor\3D_Volume_Rendering\83_12.jpg
# Processed and saved 83.jpg with method 'Interactive_Segmentation' as F:\MLpractrice\ct\output\files\tumor\Interactive_Segmentation\83_13.jpg
# Processed and saved 9.jpg with method 'Basic_Color_Map' as F:\MLpractrice\ct\output\files\tumor\Basic_Color_Map\9_1.jpg
# Processed and saved 9.jpg with method 'Adaptive_Histogram_Equalization' as F:\MLpractrice\ct\output\files\tumor\Adaptive_Histogram_Equalization\9_2.jpg
# Processed and saved 9.jpg with method 'Contrast_Stretching' as F:\MLpractrice\ct\output\files\tumor\Contrast_Stretching\9_3.jpg
# Processed and saved 9.jpg with method 'Gaussian_Blur' as F:\MLpractrice\ct\output\files\tumor\Gaussian_Blur\9_4.jpg
# Processed and saved 9.jpg with method 'Edge_Detection' as F:\MLpractrice\ct\output\files\tumor\Edge_Detection\9_5.jpg
# Processed and saved 9.jpg with method 'Random_Color_Palette' as F:\MLpractrice\ct\output\files\tumor\Random_Color_Palette\9_6.jpg
# Processed and saved 9.jpg with method 'Gamma_Correction' as F:\MLpractrice\ct\output\files\tumor\Gamma_Correction\9_7.jpg
# Processed and saved 9.jpg with method 'LUT_Color_Map' as F:\MLpractrice\ct\output\files\tumor\LUT_Color_Map\9_8.jpg
# Processed and saved 9.jpg with method 'Alpha_Blending' as F:\MLpractrice\ct\output\files\tumor\Alpha_Blending\9_9.jpg
# Processed and saved 9.jpg with method '3D_Rendering' as F:\MLpractrice\ct\output\files\tumor\3D_Rendering\9_10.jpg
# Processed and saved 9.jpg with method 'Heatmap_Visualization' as F:\MLpractrice\ct\output\files\tumor\Heatmap_Visualization\9_11.jpg
# Processed and saved 9.jpg with method '3D_Volume_Rendering' as F:\MLpractrice\ct\output\files\tumor\3D_Volume_Rendering\9_12.jpg
# Processed and saved 9.jpg with method 'Interactive_Segmentation' as F:\MLpractrice\ct\output\files\tumor\Interactive_Segmentation\9_13.jpg
# Processing complete.

# %%
4000+4
# Out:
# 4004

# %%
https://www.kaggle.com/datasets/hamdallak/the-iqothnccd-lung-cancer-dataset

# %%
import os
import numpy as np
import matplotlib.pyplot as plt
from matplotlib import cm
from PIL import Image
import cv2

# Define input and output directories
input_directory = r'F:\MLpractrice\ct\data'
output_directory = r'F:\MLpractrice\ct\output'

# Create the output directory if it doesn't exist
if not os.path.exists(output_directory):
    os.makedirs(output_directory)

# Method 1: Basic Color Map Application
def apply_color_map(ct_image, cmap='jet'):
    ct_image_normalized = (ct_image - np.min(ct_image)) / (np.max(ct_image) - np.min(ct_image))
    colored_image = cm.get_cmap(cmap)(ct_image_normalized)
    return (colored_image[:, :, :3] * 255).astype(np.uint8)

# Method 2: Adaptive Histogram Equalization with Color Map
def apply_adaptive_hist_eq(ct_image):
    clahe = cv2.createCLAHE(clipLimit=2.0, tileGridSize=(8, 8))
    enhanced_image = clahe.apply(ct_image)
    return apply_color_map(enhanced_image)

# Method 3: Contrast Stretching with Color Map
def apply_contrast_stretching(ct_image):
    min_val, max_val = np.min(ct_image), np.max(ct_image)
    stretched_image = (ct_image - min_val) / (max_val - min_val)
    return apply_color_map(stretched_image)

# Method 4: Gaussian Blur with Color Map
def apply_gaussian_blur(ct_image):
    blurred_image = cv2.GaussianBlur(ct_image, (5, 5), 0)
    return apply_color_map(blurred_image)

# Method 5: Edge Detection with Canny and Color Map
def apply_edge_detection(ct_image):
    edges = cv2.Canny(ct_image, 100, 200)
    return apply_color_map(edges)

# Method 6: Random Color Palettes (Color Overlay)
def apply_random_color_palette(ct_image):
    random_colored = np.random.rand(*ct_image.shape, 3)
    colored_image = ct_image[:, :, None] * random_colored
    return (colored_image * 255).astype(np.uint8)

# Method 7: Non-Linear Color Stretching (Gamma Correction)
def apply_gamma_correction(ct_image, gamma=1.2):
    gamma_corrected = np.power(ct_image / float(np.max(ct_image)), gamma) * 255
    return apply_color_map(gamma_corrected)

# Method 8: LUT (Lookup Table) Color Mapping (Use predefined LUT)
def apply_lut_color_map(ct_image):
    colored_image = cm.plasma((ct_image - np.min(ct_image)) / (np.max(ct_image) - np.min(ct_image)))
    return (colored_image[:, :, :3] * 255).astype(np.uint8)

# Method 9: Alpha Blending (Threshold-based)
def apply_alpha_blending(ct_image):
    thresholded_image = ct_image > 100
    colored_image = apply_color_map(ct_image)
    thresholded_image_rgb = np.stack([thresholded_image] * 3, axis=-1)
    alpha = 0.5
    final_image = alpha * colored_image + (1 - alpha) * thresholded_image_rgb * 255
    return final_image.astype(np.uint8)

# Method 10: 3D Rendering (Placeholder for 2D images)
def apply_3d_rendering(ct_image):
    return apply_color_map(ct_image)

# Method 11: Heatmap Visualization for Anomaly Detection
def apply_heatmap(ct_image):
    heatmap_image = cm.hot((ct_image - np.min(ct_image)) / (np.max(ct_image) - np.min(ct_image)))
    return (heatmap_image[:, :, :3] * 255).astype(np.uint8)

# Method 12: 3D Volume Rendering (Placeholder for 3D visualization)
def apply_3d_volume_rendering(ct_image):
    return apply_color_map(ct_image)

# Method 13: Interactive Visualization with Segmented Regions
def apply_interactive_visualization(ct_image):
    segmented_image = ct_image > 100
    segmented_colored = cm.plasma(segmented_image.astype(np.float32))
    return (segmented_colored[:, :, :3] * 255).astype(np.uint8)

# Traverse the input directory and process each image in the subfolders
for root, dirs, files in os.walk(input_directory):
    # For each image file in the directory
    for image_file in files:
        if image_file.endswith('.jpg') or image_file.endswith('.png'):
            try:
                # Construct the full input path for the image
                image_path = os.path.join(root, image_file)
                
                # Load the image using PIL
                image = Image.open(image_path)
                
                # Convert image to grayscale
                ct_image = np.array(image.convert('L'))  # Convert to grayscale
                
                # Create the same folder structure in the output directory
                relative_path = os.path.relpath(root, input_directory)  # Get relative folder structure
                output_folder = os.path.join(output_directory, relative_path)
                if not os.path.exists(output_folder):
                    os.makedirs(output_folder)

                # Define a method-to-folder mapping for naming purposes
                method_folders = [
                    "Basic_Color_Map",
                    "Adaptive_Histogram_Equalization",
                    "Contrast_Stretching",
                    "Gaussian_Blur",
                    "Edge_Detection",
                    "Random_Color_Palette",
                    "Gamma_Correction",
                    "LUT_Color_Map",
                    "Alpha_Blending",
                    "3D_Rendering",
                    "Heatmap_Visualization",
                    "3D_Volume_Rendering",
                    "Interactive_Segmentation"
                ]
                
                # Save images in their respective method folders
                for idx, method in enumerate([apply_color_map,
                                              apply_adaptive_hist_eq,
                                              apply_contrast_stretching,
                                              apply_gaussian_blur,
                                              apply_edge_detection,
                                              apply_random_color_palette,
                                              apply_gamma_correction,
                                              apply_lut_color_map,
                                              apply_alpha_blending,
                                              apply_3d_rendering,
                                              apply_heatmap,
                                              apply_3d_volume_rendering,
                                              apply_interactive_visualization]):
                    # Create method folder if it doesn't exist
                    method_folder = os.path.join(output_folder, method_folders[idx])
                    if not os.path.exists(method_folder):
                        os.makedirs(method_folder)
                    
                    # Apply the method to the image
                    result_image = method(ct_image)
                    
                    # Save the image with a sequential number in the method folder
                    image_name_without_extension = os.path.splitext(image_file)[0]
                    output_image_path = os.path.join(method_folder, f"{image_name_without_extension}_{idx+1}.jpg")
                    Image.fromarray(result_image).save(output_image_path, format='JPEG')
                    print(f"Processed and saved {image_file} with method '{method_folders[idx]}' as {output_image_path}")
            
            except Exception as e:
                print(f"Error processing {image_file} in {root}: {e}")

print("Processing complete.")
# Out:
# C:\Users\AIC\AppData\Local\Temp\ipykernel_14264\3006613876.py:19: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap(obj)`` instead.
#   colored_image = cm.get_cmap(cmap)(ct_image_normalized)
# Processed and saved Bengin case (1).jpg with method 'Basic_Color_Map' as F:\MLpractrice\ct\output\data\Bengin cases\Basic_Color_Map\Bengin case (1)_1.jpg
# Processed and saved Bengin case (1).jpg with method 'Adaptive_Histogram_Equalization' as F:\MLpractrice\ct\output\data\Bengin cases\Adaptive_Histogram_Equalization\Bengin case (1)_2.jpg
# Processed and saved Bengin case (1).jpg with method 'Contrast_Stretching' as F:\MLpractrice\ct\output\data\Bengin cases\Contrast_Stretching\Bengin case (1)_3.jpg
# Processed and saved Bengin case (1).jpg with method 'Gaussian_Blur' as F:\MLpractrice\ct\output\data\Bengin cases\Gaussian_Blur\Bengin case (1)_4.jpg
# Processed and saved Bengin case (1).jpg with method 'Edge_Detection' as F:\MLpractrice\ct\output\data\Bengin cases\Edge_Detection\Bengin case (1)_5.jpg
# Processed and saved Bengin case (1).jpg with method 'Random_Color_Palette' as F:\MLpractrice\ct\output\data\Bengin cases\Random_Color_Palette\Bengin case (1)_6.jpg
# Processed and saved Bengin case (1).jpg with method 'Gamma_Correction' as F:\MLpractrice\ct\output\data\Bengin cases\Gamma_Correction\Bengin case (1)_7.jpg
# Processed and saved Bengin case (1).jpg with method 'LUT_Color_Map' as F:\MLpractrice\ct\output\data\Bengin cases\LUT_Color_Map\Bengin case (1)_8.jpg
# Processed and saved Bengin case (1).jpg with method 'Alpha_Blending' as F:\MLpractrice\ct\output\data\Bengin cases\Alpha_Blending\Bengin case (1)_9.jpg
# Processed and saved Bengin case (1).jpg with method '3D_Rendering' as F:\MLpractrice\ct\output\data\Bengin cases\3D_Rendering\Bengin case (1)_10.jpg
# Processed and saved Bengin case (1).jpg with method 'Heatmap_Visualization' as F:\MLpractrice\ct\output\data\Bengin cases\Heatmap_Visualization\Bengin case (1)_11.jpg
# Processed and saved Bengin case (1).jpg with method '3D_Volume_Rendering' as F:\MLpractrice\ct\output\data\Bengin cases\3D_Volume_Rendering\Bengin case (1)_12.jpg
# Processed and saved Bengin case (1).jpg with method 'Interactive_Segmentation' as F:\MLpractrice\ct\output\data\Bengin cases\Interactive_Segmentation\Bengin case (1)_13.jpg
# Processed and saved Bengin case (10).jpg with method 'Basic_Color_Map' as F:\MLpractrice\ct\output\data\Bengin cases\Basic_Color_Map\Bengin case (10)_1.jpg
# Processed and saved Bengin case (10).jpg with method 'Adaptive_Histogram_Equalization' as F:\MLpractrice\ct\output\data\Bengin cases\Adaptive_Histogram_Equalization\Bengin case (10)_2.jpg
# Processed and saved Bengin case (10).jpg with method 'Contrast_Stretching' as F:\MLpractrice\ct\output\data\Bengin cases\Contrast_Stretching\Bengin case (10)_3.jpg
# Processed and saved Bengin case (10).jpg with method 'Gaussian_Blur' as F:\MLpractrice\ct\output\data\Bengin cases\Gaussian_Blur\Bengin case (10)_4.jpg
# Processed and saved Bengin case (10).jpg with method 'Edge_Detection' as F:\MLpractrice\ct\output\data\Bengin cases\Edge_Detection\Bengin case (10)_5.jpg
# Processed and saved Bengin case (10).jpg with method 'Random_Color_Palette' as F:\MLpractrice\ct\output\data\Bengin cases\Random_Color_Palette\Bengin case (10)_6.jpg
# Processed and saved Bengin case (10).jpg with method 'Gamma_Correction' as F:\MLpractrice\ct\output\data\Bengin cases\Gamma_Correction\Bengin case (10)_7.jpg
# Processed and saved Bengin case (10).jpg with method 'LUT_Color_Map' as F:\MLpractrice\ct\output\data\Bengin cases\LUT_Color_Map\Bengin case (10)_8.jpg
# Processed and saved Bengin case (10).jpg with method 'Alpha_Blending' as F:\MLpractrice\ct\output\data\Bengin cases\Alpha_Blending\Bengin case (10)_9.jpg
# Processed and saved Bengin case (10).jpg with method '3D_Rendering' as F:\MLpractrice\ct\output\data\Bengin cases\3D_Rendering\Bengin case (10)_10.jpg
# Processed and saved Bengin case (10).jpg with method 'Heatmap_Visualization' as F:\MLpractrice\ct\output\data\Bengin cases\Heatmap_Visualization\Bengin case (10)_11.jpg
# Processed and saved Bengin case (10).jpg with method '3D_Volume_Rendering' as F:\MLpractrice\ct\output\data\Bengin cases\3D_Volume_Rendering\Bengin case (10)_12.jpg
# Processed and saved Bengin case (10).jpg with method 'Interactive_Segmentation' as F:\MLpractrice\ct\output\data\Bengin cases\Interactive_Segmentation\Bengin case (10)_13.jpg
# Processed and saved Bengin case (100).jpg with method 'Basic_Color_Map' as F:\MLpractrice\ct\output\data\Bengin cases\Basic_Color_Map\Bengin case (100)_1.jpg
# Processed and saved Bengin case (100).jpg with method 'Adaptive_Histogram_Equalization' as F:\MLpractrice\ct\output\data\Bengin cases\Adaptive_Histogram_Equalization\Bengin case (100)_2.jpg
# Processed and saved Bengin case (100).jpg with method 'Contrast_Stretching' as F:\MLpractrice\ct\output\data\Bengin cases\Contrast_Stretching\Bengin case (100)_3.jpg
# Processed and saved Bengin case (100).jpg with method 'Gaussian_Blur' as F:\MLpractrice\ct\output\data\Bengin cases\Gaussian_Blur\Bengin case (100)_4.jpg
# Processed and saved Bengin case (100).jpg with method 'Edge_Detection' as F:\MLpractrice\ct\output\data\Bengin cases\Edge_Detection\Bengin case (100)_5.jpg
# Processed and saved Bengin case (100).jpg with method 'Random_Color_Palette' as F:\MLpractrice\ct\output\data\Bengin cases\Random_Color_Palette\Bengin case (100)_6.jpg
# Processed and saved Bengin case (100).jpg with method 'Gamma_Correction' as F:\MLpractrice\ct\output\data\Bengin cases\Gamma_Correction\Bengin case (100)_7.jpg
# Processed and saved Bengin case (100).jpg with method 'LUT_Color_Map' as F:\MLpractrice\ct\output\data\Bengin cases\LUT_Color_Map\Bengin case (100)_8.jpg
# Processed and saved Bengin case (100).jpg with method 'Alpha_Blending' as F:\MLpractrice\ct\output\data\Bengin cases\Alpha_Blending\Bengin case (100)_9.jpg
# Processed and saved Bengin case (100).jpg with method '3D_Rendering' as F:\MLpractrice\ct\output\data\Bengin cases\3D_Rendering\Bengin case (100)_10.jpg
# Processed and saved Bengin case (100).jpg with method 'Heatmap_Visualization' as F:\MLpractrice\ct\output\data\Bengin cases\Heatmap_Visualization\Bengin case (100)_11.jpg
# Processed and saved Bengin case (100).jpg with method '3D_Volume_Rendering' as F:\MLpractrice\ct\output\data\Bengin cases\3D_Volume_Rendering\Bengin case (100)_12.jpg
# Processed and saved Bengin case (100).jpg with method 'Interactive_Segmentation' as F:\MLpractrice\ct\output\data\Bengin cases\Interactive_Segmentation\Bengin case (100)_13.jpg
# Processed and saved Bengin case (101).jpg with method 'Basic_Color_Map' as F:\MLpractrice\ct\output\data\Bengin cases\Basic_Color_Map\Bengin case (101)_1.jpg
# Processed and saved Bengin case (101).jpg with method 'Adaptive_Histogram_Equalization' as F:\MLpractrice\ct\output\data\Bengin cases\Adaptive_Histogram_Equalization\Bengin case (101)_2.jpg
# Processed and saved Bengin case (101).jpg with method 'Contrast_Stretching' as F:\MLpractrice\ct\output\data\Bengin cases\Contrast_Stretching\Bengin case (101)_3.jpg
# Processed and saved Bengin case (101).jpg with method 'Gaussian_Blur' as F:\MLpractrice\ct\output\data\Bengin cases\Gaussian_Blur\Bengin case (101)_4.jpg
# Processed and saved Bengin case (101).jpg with method 'Edge_Detection' as F:\MLpractrice\ct\output\data\Bengin cases\Edge_Detection\Bengin case (101)_5.jpg
# Processed and saved Bengin case (101).jpg with method 'Random_Color_Palette' as F:\MLpractrice\ct\output\data\Bengin cases\Random_Color_Palette\Bengin case (101)_6.jpg
# Processed and saved Bengin case (101).jpg with method 'Gamma_Correction' as F:\MLpractrice\ct\output\data\Bengin cases\Gamma_Correction\Bengin case (101)_7.jpg
# Processed and saved Bengin case (101).jpg with method 'LUT_Color_Map' as F:\MLpractrice\ct\output\data\Bengin cases\LUT_Color_Map\Bengin case (101)_8.jpg
# Processed and saved Bengin case (101).jpg with method 'Alpha_Blending' as F:\MLpractrice\ct\output\data\Bengin cases\Alpha_Blending\Bengin case (101)_9.jpg
# Processed and saved Bengin case (101).jpg with method '3D_Rendering' as F:\MLpractrice\ct\output\data\Bengin cases\3D_Rendering\Bengin case (101)_10.jpg
# Processed and saved Bengin case (101).jpg with method 'Heatmap_Visualization' as F:\MLpractrice\ct\output\data\Bengin cases\Heatmap_Visualization\Bengin case (101)_11.jpg
# Processed and saved Bengin case (101).jpg with method '3D_Volume_Rendering' as F:\MLpractrice\ct\output\data\Bengin cases\3D_Volume_Rendering\Bengin case (101)_12.jpg
# Processed and saved Bengin case (101).jpg with method 'Interactive_Segmentation' as F:\MLpractrice\ct\output\data\Bengin cases\Interactive_Segmentation\Bengin case (101)_13.jpg
# Processed and saved Bengin case (102).jpg with method 'Basic_Color_Map' as F:\MLpractrice\ct\output\data\Bengin cases\Basic_Color_Map\Bengin case (102)_1.jpg
# Processed and saved Bengin case (102).jpg with method 'Adaptive_Histogram_Equalization' as F:\MLpractrice\ct\output\data\Bengin cases\Adaptive_Histogram_Equalization\Bengin case (102)_2.jpg
# Processed and saved Bengin case (102).jpg with method 'Contrast_Stretching' as F:\MLpractrice\ct\output\data\Bengin cases\Contrast_Stretching\Bengin case (102)_3.jpg
# Processed and saved Bengin case (102).jpg with method 'Gaussian_Blur' as F:\MLpractrice\ct\output\data\Bengin cases\Gaussian_Blur\Bengin case (102)_4.jpg
# Processed and saved Bengin case (102).jpg with method 'Edge_Detection' as F:\MLpractrice\ct\output\data\Bengin cases\Edge_Detection\Bengin case (102)_5.jpg
# Processed and saved Bengin case (102).jpg with method 'Random_Color_Palette' as F:\MLpractrice\ct\output\data\Bengin cases\Random_Color_Palette\Bengin case (102)_6.jpg
# Processed and saved Bengin case (102).jpg with method 'Gamma_Correction' as F:\MLpractrice\ct\output\data\Bengin cases\Gamma_Correction\Bengin case (102)_7.jpg
# Processed and saved Bengin case (102).jpg with method 'LUT_Color_Map' as F:\MLpractrice\ct\output\data\Bengin cases\LUT_Color_Map\Bengin case (102)_8.jpg
# Processed and saved Bengin case (102).jpg with method 'Alpha_Blending' as F:\MLpractrice\ct\output\data\Bengin cases\Alpha_Blending\Bengin case (102)_9.jpg
# Processed and saved Bengin case (102).jpg with method '3D_Rendering' as F:\MLpractrice\ct\output\data\Bengin cases\3D_Rendering\Bengin case (102)_10.jpg
# Processed and saved Bengin case (102).jpg with method 'Heatmap_Visualization' as F:\MLpractrice\ct\output\data\Bengin cases\Heatmap_Visualization\Bengin case (102)_11.jpg
# Processed and saved Bengin case (102).jpg with method '3D_Volume_Rendering' as F:\MLpractrice\ct\output\data\Bengin cases\3D_Volume_Rendering\Bengin case (102)_12.jpg
# Processed and saved Bengin case (102).jpg with method 'Interactive_Segmentation' as F:\MLpractrice\ct\output\data\Bengin cases\Interactive_Segmentation\Bengin case (102)_13.jpg
# Processed and saved Bengin case (103).jpg with method 'Basic_Color_Map' as F:\MLpractrice\ct\output\data\Bengin cases\Basic_Color_Map\Bengin case (103)_1.jpg
# Processed and saved Bengin case (103).jpg with method 'Adaptive_Histogram_Equalization' as F:\MLpractrice\ct\output\data\Bengin cases\Adaptive_Histogram_Equalization\Bengin case (103)_2.jpg
# Processed and saved Bengin case (103).jpg with method 'Contrast_Stretching' as F:\MLpractrice\ct\output\data\Bengin cases\Contrast_Stretching\Bengin case (103)_3.jpg
# Processed and saved Bengin case (103).jpg with method 'Gaussian_Blur' as F:\MLpractrice\ct\output\data\Bengin cases\Gaussian_Blur\Bengin case (103)_4.jpg
# Processed and saved Bengin case (103).jpg with method 'Edge_Detection' as F:\MLpractrice\ct\output\data\Bengin cases\Edge_Detection\Bengin case (103)_5.jpg
# Processed and saved Bengin case (103).jpg with method 'Random_Color_Palette' as F:\MLpractrice\ct\output\data\Bengin cases\Random_Color_Palette\Bengin case (103)_6.jpg
# Processed and saved Bengin case (103).jpg with method 'Gamma_Correction' as F:\MLpractrice\ct\output\data\Bengin cases\Gamma_Correction\Bengin case (103)_7.jpg
# Processed and saved Bengin case (103).jpg with method 'LUT_Color_Map' as F:\MLpractrice\ct\output\data\Bengin cases\LUT_Color_Map\Bengin case (103)_8.jpg
# Processed and saved Bengin case (103).jpg with method 'Alpha_Blending' as F:\MLpractrice\ct\output\data\Bengin cases\Alpha_Blending\Bengin case (103)_9.jpg
# Processed and saved Bengin case (103).jpg with method '3D_Rendering' as F:\MLpractrice\ct\output\data\Bengin cases\3D_Rendering\Bengin case (103)_10.jpg
# Processed and saved Bengin case (103).jpg with method 'Heatmap_Visualization' as F:\MLpractrice\ct\output\data\Bengin cases\Heatmap_Visualization\Bengin case (103)_11.jpg
# Processed and saved Bengin case (103).jpg with method '3D_Volume_Rendering' as F:\MLpractrice\ct\output\data\Bengin cases\3D_Volume_Rendering\Bengin case (103)_12.jpg
# Processed and saved Bengin case (103).jpg with method 'Interactive_Segmentation' as F:\MLpractrice\ct\output\data\Bengin cases\Interactive_Segmentation\Bengin case (103)_13.jpg
# Processed and saved Bengin case (104).jpg with method 'Basic_Color_Map' as F:\MLpractrice\ct\output\data\Bengin cases\Basic_Color_Map\Bengin case (104)_1.jpg
# Processed and saved Bengin case (104).jpg with method 'Adaptive_Histogram_Equalization' as F:\MLpractrice\ct\output\data\Bengin cases\Adaptive_Histogram_Equalization\Bengin case (104)_2.jpg
# Processed and saved Bengin case (104).jpg with method 'Contrast_Stretching' as F:\MLpractrice\ct\output\data\Bengin cases\Contrast_Stretching\Bengin case (104)_3.jpg
# Processed and saved Bengin case (104).jpg with method 'Gaussian_Blur' as F:\MLpractrice\ct\output\data\Bengin cases\Gaussian_Blur\Bengin case (104)_4.jpg
# Processed and saved Bengin case (104).jpg with method 'Edge_Detection' as F:\MLpractrice\ct\output\data\Bengin cases\Edge_Detection\Bengin case (104)_5.jpg
# Processed and saved Bengin case (104).jpg with method 'Random_Color_Palette' as F:\MLpractrice\ct\output\data\Bengin cases\Random_Color_Palette\Bengin case (104)_6.jpg
# Processed and saved Bengin case (104).jpg with method 'Gamma_Correction' as F:\MLpractrice\ct\output\data\Bengin cases\Gamma_Correction\Bengin case (104)_7.jpg
# Processed and saved Bengin case (104).jpg with method 'LUT_Color_Map' as F:\MLpractrice\ct\output\data\Bengin cases\LUT_Color_Map\Bengin case (104)_8.jpg
# Processed and saved Bengin case (104).jpg with method 'Alpha_Blending' as F:\MLpractrice\ct\output\data\Bengin cases\Alpha_Blending\Bengin case (104)_9.jpg
# Processed and saved Bengin case (104).jpg with method '3D_Rendering' as F:\MLpractrice\ct\output\data\Bengin cases\3D_Rendering\Bengin case (104)_10.jpg
# Processed and saved Bengin case (104).jpg with method 'Heatmap_Visualization' as F:\MLpractrice\ct\output\data\Bengin cases\Heatmap_Visualization\Bengin case (104)_11.jpg
# Processed and saved Bengin case (104).jpg with method '3D_Volume_Rendering' as F:\MLpractrice\ct\output\data\Bengin cases\3D_Volume_Rendering\Bengin case (104)_12.jpg
# Processed and saved Bengin case (104).jpg with method 'Interactive_Segmentation' as F:\MLpractrice\ct\output\data\Bengin cases\Interactive_Segmentation\Bengin case (104)_13.jpg
# Processed and saved Bengin case (105).jpg with method 'Basic_Color_Map' as F:\MLpractrice\ct\output\data\Bengin cases\Basic_Color_Map\Bengin case (105)_1.jpg
# Processed and saved Bengin case (105).jpg with method 'Adaptive_Histogram_Equalization' as F:\MLpractrice\ct\output\data\Bengin cases\Adaptive_Histogram_Equalization\Bengin case (105)_2.jpg
# Processed and saved Bengin case (105).jpg with method 'Contrast_Stretching' as F:\MLpractrice\ct\output\data\Bengin cases\Contrast_Stretching\Bengin case (105)_3.jpg
# Processed and saved Bengin case (105).jpg with method 'Gaussian_Blur' as F:\MLpractrice\ct\output\data\Bengin cases\Gaussian_Blur\Bengin case (105)_4.jpg
# Processed and saved Bengin case (105).jpg with method 'Edge_Detection' as F:\MLpractrice\ct\output\data\Bengin cases\Edge_Detection\Bengin case (105)_5.jpg
# Processed and saved Bengin case (105).jpg with method 'Random_Color_Palette' as F:\MLpractrice\ct\output\data\Bengin cases\Random_Color_Palette\Bengin case (105)_6.jpg
# Processed and saved Bengin case (105).jpg with method 'Gamma_Correction' as F:\MLpractrice\ct\output\data\Bengin cases\Gamma_Correction\Bengin case (105)_7.jpg
# Processed and saved Bengin case (105).jpg with method 'LUT_Color_Map' as F:\MLpractrice\ct\output\data\Bengin cases\LUT_Color_Map\Bengin case (105)_8.jpg
# Processed and saved Bengin case (105).jpg with method 'Alpha_Blending' as F:\MLpractrice\ct\output\data\Bengin cases\Alpha_Blending\Bengin case (105)_9.jpg
# Processed and saved Bengin case (105).jpg with method '3D_Rendering' as F:\MLpractrice\ct\output\data\Bengin cases\3D_Rendering\Bengin case (105)_10.jpg
# Processed and saved Bengin case (105).jpg with method 'Heatmap_Visualization' as F:\MLpractrice\ct\output\data\Bengin cases\Heatmap_Visualization\Bengin case (105)_11.jpg
# Processed and saved Bengin case (105).jpg with method '3D_Volume_Rendering' as F:\MLpractrice\ct\output\data\Bengin cases\3D_Volume_Rendering\Bengin case (105)_12.jpg
# Processed and saved Bengin case (105).jpg with method 'Interactive_Segmentation' as F:\MLpractrice\ct\output\data\Bengin cases\Interactive_Segmentation\Bengin case (105)_13.jpg
# Processed and saved Bengin case (106).jpg with method 'Basic_Color_Map' as F:\MLpractrice\ct\output\data\Bengin cases\Basic_Color_Map\Bengin case (106)_1.jpg
# Processed and saved Bengin case (106).jpg with method 'Adaptive_Histogram_Equalization' as F:\MLpractrice\ct\output\data\Bengin cases\Adaptive_Histogram_Equalization\Bengin case (106)_2.jpg
# Processed and saved Bengin case (106).jpg with method 'Contrast_Stretching' as F:\MLpractrice\ct\output\data\Bengin cases\Contrast_Stretching\Bengin case (106)_3.jpg
# Processed and saved Bengin case (106).jpg with method 'Gaussian_Blur' as F:\MLpractrice\ct\output\data\Bengin cases\Gaussian_Blur\Bengin case (106)_4.jpg
# Processed and saved Bengin case (106).jpg with method 'Edge_Detection' as F:\MLpractrice\ct\output\data\Bengin cases\Edge_Detection\Bengin case (106)_5.jpg
# Processed and saved Bengin case (106).jpg with method 'Random_Color_Palette' as F:\MLpractrice\ct\output\data\Bengin cases\Random_Color_Palette\Bengin case (106)_6.jpg
# Processed and saved Bengin case (106).jpg with method 'Gamma_Correction' as F:\MLpractrice\ct\output\data\Bengin cases\Gamma_Correction\Bengin case (106)_7.jpg
# Processed and saved Bengin case (106).jpg with method 'LUT_Color_Map' as F:\MLpractrice\ct\output\data\Bengin cases\LUT_Color_Map\Bengin case (106)_8.jpg
# Processed and saved Bengin case (106).jpg with method 'Alpha_Blending' as F:\MLpractrice\ct\output\data\Bengin cases\Alpha_Blending\Bengin case (106)_9.jpg
# Processed and saved Bengin case (106).jpg with method '3D_Rendering' as F:\MLpractrice\ct\output\data\Bengin cases\3D_Rendering\Bengin case (106)_10.jpg
# Processed and saved Bengin case (106).jpg with method 'Heatmap_Visualization' as F:\MLpractrice\ct\output\data\Bengin cases\Heatmap_Visualization\Bengin case (106)_11.jpg
# Processed and saved Bengin case (106).jpg with method '3D_Volume_Rendering' as F:\MLpractrice\ct\output\data\Bengin cases\3D_Volume_Rendering\Bengin case (106)_12.jpg
# Processed and saved Bengin case (106).jpg with method 'Interactive_Segmentation' as F:\MLpractrice\ct\output\data\Bengin cases\Interactive_Segmentation\Bengin case (106)_13.jpg
# Processed and saved Bengin case (107).jpg with method 'Basic_Color_Map' as F:\MLpractrice\ct\output\data\Bengin cases\Basic_Color_Map\Bengin case (107)_1.jpg
# Processed and saved Bengin case (107).jpg with method 'Adaptive_Histogram_Equalization' as F:\MLpractrice\ct\output\data\Bengin cases\Adaptive_Histogram_Equalization\Bengin case (107)_2.jpg
# Processed and saved Bengin case (107).jpg with method 'Contrast_Stretching' as F:\MLpractrice\ct\output\data\Bengin cases\Contrast_Stretching\Bengin case (107)_3.jpg
# Processed and saved Bengin case (107).jpg with method 'Gaussian_Blur' as F:\MLpractrice\ct\output\data\Bengin cases\Gaussian_Blur\Bengin case (107)_4.jpg
# Processed and saved Bengin case (107).jpg with method 'Edge_Detection' as F:\MLpractrice\ct\output\data\Bengin cases\Edge_Detection\Bengin case (107)_5.jpg
# Processed and saved Bengin case (107).jpg with method 'Random_Color_Palette' as F:\MLpractrice\ct\output\data\Bengin cases\Random_Color_Palette\Bengin case (107)_6.jpg
# Processed and saved Bengin case (107).jpg with method 'Gamma_Correction' as F:\MLpractrice\ct\output\data\Bengin cases\Gamma_Correction\Bengin case (107)_7.jpg
# Processed and saved Bengin case (107).jpg with method 'LUT_Color_Map' as F:\MLpractrice\ct\output\data\Bengin cases\LUT_Color_Map\Bengin case (107)_8.jpg
# Processed and saved Bengin case (107).jpg with method 'Alpha_Blending' as F:\MLpractrice\ct\output\data\Bengin cases\Alpha_Blending\Bengin case (107)_9.jpg
# Processed and saved Bengin case (107).jpg with method '3D_Rendering' as F:\MLpractrice\ct\output\data\Bengin cases\3D_Rendering\Bengin case (107)_10.jpg
# Processed and saved Bengin case (107).jpg with method 'Heatmap_Visualization' as F:\MLpractrice\ct\output\data\Bengin cases\Heatmap_Visualization\Bengin case (107)_11.jpg
# Processed and saved Bengin case (107).jpg with method '3D_Volume_Rendering' as F:\MLpractrice\ct\output\data\Bengin cases\3D_Volume_Rendering\Bengin case (107)_12.jpg
# Processed and saved Bengin case (107).jpg with method 'Interactive_Segmentation' as F:\MLpractrice\ct\output\data\Bengin cases\Interactive_Segmentation\Bengin case (107)_13.jpg
# Processed and saved Bengin case (108).jpg with method 'Basic_Color_Map' as F:\MLpractrice\ct\output\data\Bengin cases\Basic_Color_Map\Bengin case (108)_1.jpg
# Processed and saved Bengin case (108).jpg with method 'Adaptive_Histogram_Equalization' as F:\MLpractrice\ct\output\data\Bengin cases\Adaptive_Histogram_Equalization\Bengin case (108)_2.jpg
# Processed and saved Bengin case (108).jpg with method 'Contrast_Stretching' as F:\MLpractrice\ct\output\data\Bengin cases\Contrast_Stretching\Bengin case (108)_3.jpg
# Processed and saved Bengin case (108).jpg with method 'Gaussian_Blur' as F:\MLpractrice\ct\output\data\Bengin cases\Gaussian_Blur\Bengin case (108)_4.jpg
# Processed and saved Bengin case (108).jpg with method 'Edge_Detection' as F:\MLpractrice\ct\output\data\Bengin cases\Edge_Detection\Bengin case (108)_5.jpg
# Processed and saved Bengin case (108).jpg with method 'Random_Color_Palette' as F:\MLpractrice\ct\output\data\Bengin cases\Random_Color_Palette\Bengin case (108)_6.jpg
# Processed and saved Bengin case (108).jpg with method 'Gamma_Correction' as F:\MLpractrice\ct\output\data\Bengin cases\Gamma_Correction\Bengin case (108)_7.jpg
# Processed and saved Bengin case (108).jpg with method 'LUT_Color_Map' as F:\MLpractrice\ct\output\data\Bengin cases\LUT_Color_Map\Bengin case (108)_8.jpg
# Processed and saved Bengin case (108).jpg with method 'Alpha_Blending' as F:\MLpractrice\ct\output\data\Bengin cases\Alpha_Blending\Bengin case (108)_9.jpg
# Processed and saved Bengin case (108).jpg with method '3D_Rendering' as F:\MLpractrice\ct\output\data\Bengin cases\3D_Rendering\Bengin case (108)_10.jpg
# Processed and saved Bengin case (108).jpg with method 'Heatmap_Visualization' as F:\MLpractrice\ct\output\data\Bengin cases\Heatmap_Visualization\Bengin case (108)_11.jpg
# Processed and saved Bengin case (108).jpg with method '3D_Volume_Rendering' as F:\MLpractrice\ct\output\data\Bengin cases\3D_Volume_Rendering\Bengin case (108)_12.jpg
# Processed and saved Bengin case (108).jpg with method 'Interactive_Segmentation' as F:\MLpractrice\ct\output\data\Bengin cases\Interactive_Segmentation\Bengin case (108)_13.jpg
# Processed and saved Bengin case (109).jpg with method 'Basic_Color_Map' as F:\MLpractrice\ct\output\data\Bengin cases\Basic_Color_Map\Bengin case (109)_1.jpg
# Processed and saved Bengin case (109).jpg with method 'Adaptive_Histogram_Equalization' as F:\MLpractrice\ct\output\data\Bengin cases\Adaptive_Histogram_Equalization\Bengin case (109)_2.jpg
# Processed and saved Bengin case (109).jpg with method 'Contrast_Stretching' as F:\MLpractrice\ct\output\data\Bengin cases\Contrast_Stretching\Bengin case (109)_3.jpg
# Processed and saved Bengin case (109).jpg with method 'Gaussian_Blur' as F:\MLpractrice\ct\output\data\Bengin cases\Gaussian_Blur\Bengin case (109)_4.jpg
# Processed and saved Bengin case (109).jpg with method 'Edge_Detection' as F:\MLpractrice\ct\output\data\Bengin cases\Edge_Detection\Bengin case (109)_5.jpg
# Processed and saved Bengin case (109).jpg with method 'Random_Color_Palette' as F:\MLpractrice\ct\output\data\Bengin cases\Random_Color_Palette\Bengin case (109)_6.jpg
# Processed and saved Bengin case (109).jpg with method 'Gamma_Correction' as F:\MLpractrice\ct\output\data\Bengin cases\Gamma_Correction\Bengin case (109)_7.jpg
# Processed and saved Bengin case (109).jpg with method 'LUT_Color_Map' as F:\MLpractrice\ct\output\data\Bengin cases\LUT_Color_Map\Bengin case (109)_8.jpg
# Processed and saved Bengin case (109).jpg with method 'Alpha_Blending' as F:\MLpractrice\ct\output\data\Bengin cases\Alpha_Blending\Bengin case (109)_9.jpg
# Processed and saved Bengin case (109).jpg with method '3D_Rendering' as F:\MLpractrice\ct\output\data\Bengin cases\3D_Rendering\Bengin case (109)_10.jpg
# Processed and saved Bengin case (109).jpg with method 'Heatmap_Visualization' as F:\MLpractrice\ct\output\data\Bengin cases\Heatmap_Visualization\Bengin case (109)_11.jpg
# Processed and saved Bengin case (109).jpg with method '3D_Volume_Rendering' as F:\MLpractrice\ct\output\data\Bengin cases\3D_Volume_Rendering\Bengin case (109)_12.jpg
# Processed and saved Bengin case (109).jpg with method 'Interactive_Segmentation' as F:\MLpractrice\ct\output\data\Bengin cases\Interactive_Segmentation\Bengin case (109)_13.jpg
# Processed and saved Bengin case (11).jpg with method 'Basic_Color_Map' as F:\MLpractrice\ct\output\data\Bengin cases\Basic_Color_Map\Bengin case (11)_1.jpg
# Processed and saved Bengin case (11).jpg with method 'Adaptive_Histogram_Equalization' as F:\MLpractrice\ct\output\data\Bengin cases\Adaptive_Histogram_Equalization\Bengin case (11)_2.jpg
# Processed and saved Bengin case (11).jpg with method 'Contrast_Stretching' as F:\MLpractrice\ct\output\data\Bengin cases\Contrast_Stretching\Bengin case (11)_3.jpg
# Processed and saved Bengin case (11).jpg with method 'Gaussian_Blur' as F:\MLpractrice\ct\output\data\Bengin cases\Gaussian_Blur\Bengin case (11)_4.jpg
# Processed and saved Bengin case (11).jpg with method 'Edge_Detection' as F:\MLpractrice\ct\output\data\Bengin cases\Edge_Detection\Bengin case (11)_5.jpg
# Processed and saved Bengin case (11).jpg with method 'Random_Color_Palette' as F:\MLpractrice\ct\output\data\Bengin cases\Random_Color_Palette\Bengin case (11)_6.jpg
# Processed and saved Bengin case (11).jpg with method 'Gamma_Correction' as F:\MLpractrice\ct\output\data\Bengin cases\Gamma_Correction\Bengin case (11)_7.jpg
# Processed and saved Bengin case (11).jpg with method 'LUT_Color_Map' as F:\MLpractrice\ct\output\data\Bengin cases\LUT_Color_Map\Bengin case (11)_8.jpg
# Processed and saved Bengin case (11).jpg with method 'Alpha_Blending' as F:\MLpractrice\ct\output\data\Bengin cases\Alpha_Blending\Bengin case (11)_9.jpg
# Processed and saved Bengin case (11).jpg with method '3D_Rendering' as F:\MLpractrice\ct\output\data\Bengin cases\3D_Rendering\Bengin case (11)_10.jpg
# Processed and saved Bengin case (11).jpg with method 'Heatmap_Visualization' as F:\MLpractrice\ct\output\data\Bengin cases\Heatmap_Visualization\Bengin case (11)_11.jpg
# Processed and saved Bengin case (11).jpg with method '3D_Volume_Rendering' as F:\MLpractrice\ct\output\data\Bengin cases\3D_Volume_Rendering\Bengin case (11)_12.jpg
# Processed and saved Bengin case (11).jpg with method 'Interactive_Segmentation' as F:\MLpractrice\ct\output\data\Bengin cases\Interactive_Segmentation\Bengin case (11)_13.jpg
# Processed and saved Bengin case (110).jpg with method 'Basic_Color_Map' as F:\MLpractrice\ct\output\data\Bengin cases\Basic_Color_Map\Bengin case (110)_1.jpg
# Processed and saved Bengin case (110).jpg with method 'Adaptive_Histogram_Equalization' as F:\MLpractrice\ct\output\data\Bengin cases\Adaptive_Histogram_Equalization\Bengin case (110)_2.jpg
# Processed and saved Bengin case (110).jpg with method 'Contrast_Stretching' as F:\MLpractrice\ct\output\data\Bengin cases\Contrast_Stretching\Bengin case (110)_3.jpg
# Processed and saved Bengin case (110).jpg with method 'Gaussian_Blur' as F:\MLpractrice\ct\output\data\Bengin cases\Gaussian_Blur\Bengin case (110)_4.jpg
# Processed and saved Bengin case (110).jpg with method 'Edge_Detection' as F:\MLpractrice\ct\output\data\Bengin cases\Edge_Detection\Bengin case (110)_5.jpg
# Processed and saved Bengin case (110).jpg with method 'Random_Color_Palette' as F:\MLpractrice\ct\output\data\Bengin cases\Random_Color_Palette\Bengin case (110)_6.jpg
# Processed and saved Bengin case (110).jpg with method 'Gamma_Correction' as F:\MLpractrice\ct\output\data\Bengin cases\Gamma_Correction\Bengin case (110)_7.jpg
# Processed and saved Bengin case (110).jpg with method 'LUT_Color_Map' as F:\MLpractrice\ct\output\data\Bengin cases\LUT_Color_Map\Bengin case (110)_8.jpg
# Processed and saved Bengin case (110).jpg with method 'Alpha_Blending' as F:\MLpractrice\ct\output\data\Bengin cases\Alpha_Blending\Bengin case (110)_9.jpg
# Processed and saved Bengin case (110).jpg with method '3D_Rendering' as F:\MLpractrice\ct\output\data\Bengin cases\3D_Rendering\Bengin case (110)_10.jpg
# Processed and saved Bengin case (110).jpg with method 'Heatmap_Visualization' as F:\MLpractrice\ct\output\data\Bengin cases\Heatmap_Visualization\Bengin case (110)_11.jpg
# Processed and saved Bengin case (110).jpg with method '3D_Volume_Rendering' as F:\MLpractrice\ct\output\data\Bengin cases\3D_Volume_Rendering\Bengin case (110)_12.jpg
# Processed and saved Bengin case (110).jpg with method 'Interactive_Segmentation' as F:\MLpractrice\ct\output\data\Bengin cases\Interactive_Segmentation\Bengin case (110)_13.jpg
# Processed and saved Bengin case (111).jpg with method 'Basic_Color_Map' as F:\MLpractrice\ct\output\data\Bengin cases\Basic_Color_Map\Bengin case (111)_1.jpg
# Processed and saved Bengin case (111).jpg with method 'Adaptive_Histogram_Equalization' as F:\MLpractrice\ct\output\data\Bengin cases\Adaptive_Histogram_Equalization\Bengin case (111)_2.jpg
# Processed and saved Bengin case (111).jpg with method 'Contrast_Stretching' as F:\MLpractrice\ct\output\data\Bengin cases\Contrast_Stretching\Bengin case (111)_3.jpg
# Processed and saved Bengin case (111).jpg with method 'Gaussian_Blur' as F:\MLpractrice\ct\output\data\Bengin cases\Gaussian_Blur\Bengin case (111)_4.jpg
# Processed and saved Bengin case (111).jpg with method 'Edge_Detection' as F:\MLpractrice\ct\output\data\Bengin cases\Edge_Detection\Bengin case (111)_5.jpg
# Processed and saved Bengin case (111).jpg with method 'Random_Color_Palette' as F:\MLpractrice\ct\output\data\Bengin cases\Random_Color_Palette\Bengin case (111)_6.jpg
# Processed and saved Bengin case (111).jpg with method 'Gamma_Correction' as F:\MLpractrice\ct\output\data\Bengin cases\Gamma_Correction\Bengin case (111)_7.jpg
# Processed and saved Bengin case (111).jpg with method 'LUT_Color_Map' as F:\MLpractrice\ct\output\data\Bengin cases\LUT_Color_Map\Bengin case (111)_8.jpg
# Processed and saved Bengin case (111).jpg with method 'Alpha_Blending' as F:\MLpractrice\ct\output\data\Bengin cases\Alpha_Blending\Bengin case (111)_9.jpg
# Processed and saved Bengin case (111).jpg with method '3D_Rendering' as F:\MLpractrice\ct\output\data\Bengin cases\3D_Rendering\Bengin case (111)_10.jpg
# Processed and saved Bengin case (111).jpg with method 'Heatmap_Visualization' as F:\MLpractrice\ct\output\data\Bengin cases\Heatmap_Visualization\Bengin case (111)_11.jpg
# Processed and saved Bengin case (111).jpg with method '3D_Volume_Rendering' as F:\MLpractrice\ct\output\data\Bengin cases\3D_Volume_Rendering\Bengin case (111)_12.jpg
# Processed and saved Bengin case (111).jpg with method 'Interactive_Segmentation' as F:\MLpractrice\ct\output\data\Bengin cases\Interactive_Segmentation\Bengin case (111)_13.jpg
# Processed and saved Bengin case (112).jpg with method 'Basic_Color_Map' as F:\MLpractrice\ct\output\data\Bengin cases\Basic_Color_Map\Bengin case (112)_1.jpg
# Processed and saved Bengin case (112).jpg with method 'Adaptive_Histogram_Equalization' as F:\MLpractrice\ct\output\data\Bengin cases\Adaptive_Histogram_Equalization\Bengin case (112)_2.jpg
# Processed and saved Bengin case (112).jpg with method 'Contrast_Stretching' as F:\MLpractrice\ct\output\data\Bengin cases\Contrast_Stretching\Bengin case (112)_3.jpg
# Processed and saved Bengin case (112).jpg with method 'Gaussian_Blur' as F:\MLpractrice\ct\output\data\Bengin cases\Gaussian_Blur\Bengin case (112)_4.jpg
# Processed and saved Bengin case (112).jpg with method 'Edge_Detection' as F:\MLpractrice\ct\output\data\Bengin cases\Edge_Detection\Bengin case (112)_5.jpg
# Processed and saved Bengin case (112).jpg with method 'Random_Color_Palette' as F:\MLpractrice\ct\output\data\Bengin cases\Random_Color_Palette\Bengin case (112)_6.jpg
# Processed and saved Bengin case (112).jpg with method 'Gamma_Correction' as F:\MLpractrice\ct\output\data\Bengin cases\Gamma_Correction\Bengin case (112)_7.jpg
# Processed and saved Bengin case (112).jpg with method 'LUT_Color_Map' as F:\MLpractrice\ct\output\data\Bengin cases\LUT_Color_Map\Bengin case (112)_8.jpg
# Processed and saved Bengin case (112).jpg with method 'Alpha_Blending' as F:\MLpractrice\ct\output\data\Bengin cases\Alpha_Blending\Bengin case (112)_9.jpg
# Processed and saved Bengin case (112).jpg with method '3D_Rendering' as F:\MLpractrice\ct\output\data\Bengin cases\3D_Rendering\Bengin case (112)_10.jpg
# Processed and saved Bengin case (112).jpg with method 'Heatmap_Visualization' as F:\MLpractrice\ct\output\data\Bengin cases\Heatmap_Visualization\Bengin case (112)_11.jpg
# Processed and saved Bengin case (112).jpg with method '3D_Volume_Rendering' as F:\MLpractrice\ct\output\data\Bengin cases\3D_Volume_Rendering\Bengin case (112)_12.jpg
# Processed and saved Bengin case (112).jpg with method 'Interactive_Segmentation' as F:\MLpractrice\ct\output\data\Bengin cases\Interactive_Segmentation\Bengin case (112)_13.jpg
# Processed and saved Bengin case (113).jpg with method 'Basic_Color_Map' as F:\MLpractrice\ct\output\data\Bengin cases\Basic_Color_Map\Bengin case (113)_1.jpg
# Processed and saved Bengin case (113).jpg with method 'Adaptive_Histogram_Equalization' as F:\MLpractrice\ct\output\data\Bengin cases\Adaptive_Histogram_Equalization\Bengin case (113)_2.jpg
# Processed and saved Bengin case (113).jpg with method 'Contrast_Stretching' as F:\MLpractrice\ct\output\data\Bengin cases\Contrast_Stretching\Bengin case (113)_3.jpg
# Processed and saved Bengin case (113).jpg with method 'Gaussian_Blur' as F:\MLpractrice\ct\output\data\Bengin cases\Gaussian_Blur\Bengin case (113)_4.jpg
# Processed and saved Bengin case (113).jpg with method 'Edge_Detection' as F:\MLpractrice\ct\output\data\Bengin cases\Edge_Detection\Bengin case (113)_5.jpg
# Processed and saved Bengin case (113).jpg with method 'Random_Color_Palette' as F:\MLpractrice\ct\output\data\Bengin cases\Random_Color_Palette\Bengin case (113)_6.jpg
# Processed and saved Bengin case (113).jpg with method 'Gamma_Correction' as F:\MLpractrice\ct\output\data\Bengin cases\Gamma_Correction\Bengin case (113)_7.jpg
# Processed and saved Bengin case (113).jpg with method 'LUT_Color_Map' as F:\MLpractrice\ct\output\data\Bengin cases\LUT_Color_Map\Bengin case (113)_8.jpg
# Processed and saved Bengin case (113).jpg with method 'Alpha_Blending' as F:\MLpractrice\ct\output\data\Bengin cases\Alpha_Blending\Bengin case (113)_9.jpg
# Processed and saved Bengin case (113).jpg with method '3D_Rendering' as F:\MLpractrice\ct\output\data\Bengin cases\3D_Rendering\Bengin case (113)_10.jpg
# Processed and saved Bengin case (113).jpg with method 'Heatmap_Visualization' as F:\MLpractrice\ct\output\data\Bengin cases\Heatmap_Visualization\Bengin case (113)_11.jpg
# Processed and saved Bengin case (113).jpg with method '3D_Volume_Rendering' as F:\MLpractrice\ct\output\data\Bengin cases\3D_Volume_Rendering\Bengin case (113)_12.jpg
# Processed and saved Bengin case (113).jpg with method 'Interactive_Segmentation' as F:\MLpractrice\ct\output\data\Bengin cases\Interactive_Segmentation\Bengin case (113)_13.jpg
# Processed and saved Bengin case (114).jpg with method 'Basic_Color_Map' as F:\MLpractrice\ct\output\data\Bengin cases\Basic_Color_Map\Bengin case (114)_1.jpg
# Processed and saved Bengin case (114).jpg with method 'Adaptive_Histogram_Equalization' as F:\MLpractrice\ct\output\data\Bengin cases\Adaptive_Histogram_Equalization\Bengin case (114)_2.jpg
# Processed and saved Bengin case (114).jpg with method 'Contrast_Stretching' as F:\MLpractrice\ct\output\data\Bengin cases\Contrast_Stretching\Bengin case (114)_3.jpg
# Processed and saved Bengin case (114).jpg with method 'Gaussian_Blur' as F:\MLpractrice\ct\output\data\Bengin cases\Gaussian_Blur\Bengin case (114)_4.jpg
# Processed and saved Bengin case (114).jpg with method 'Edge_Detection' as F:\MLpractrice\ct\output\data\Bengin cases\Edge_Detection\Bengin case (114)_5.jpg
# Processed and saved Bengin case (114).jpg with method 'Random_Color_Palette' as F:\MLpractrice\ct\output\data\Bengin cases\Random_Color_Palette\Bengin case (114)_6.jpg
# Processed and saved Bengin case (114).jpg with method 'Gamma_Correction' as F:\MLpractrice\ct\output\data\Bengin cases\Gamma_Correction\Bengin case (114)_7.jpg
# Processed and saved Bengin case (114).jpg with method 'LUT_Color_Map' as F:\MLpractrice\ct\output\data\Bengin cases\LUT_Color_Map\Bengin case (114)_8.jpg
# Processed and saved Bengin case (114).jpg with method 'Alpha_Blending' as F:\MLpractrice\ct\output\data\Bengin cases\Alpha_Blending\Bengin case (114)_9.jpg
# Processed and saved Bengin case (114).jpg with method '3D_Rendering' as F:\MLpractrice\ct\output\data\Bengin cases\3D_Rendering\Bengin case (114)_10.jpg
# Processed and saved Bengin case (114).jpg with method 'Heatmap_Visualization' as F:\MLpractrice\ct\output\data\Bengin cases\Heatmap_Visualization\Bengin case (114)_11.jpg
# Processed and saved Bengin case (114).jpg with method '3D_Volume_Rendering' as F:\MLpractrice\ct\output\data\Bengin cases\3D_Volume_Rendering\Bengin case (114)_12.jpg
# Processed and saved Bengin case (114).jpg with method 'Interactive_Segmentation' as F:\MLpractrice\ct\output\data\Bengin cases\Interactive_Segmentation\Bengin case (114)_13.jpg
# Processed and saved Bengin case (115).jpg with method 'Basic_Color_Map' as F:\MLpractrice\ct\output\data\Bengin cases\Basic_Color_Map\Bengin case (115)_1.jpg
# Processed and saved Bengin case (115).jpg with method 'Adaptive_Histogram_Equalization' as F:\MLpractrice\ct\output\data\Bengin cases\Adaptive_Histogram_Equalization\Bengin case (115)_2.jpg
# Processed and saved Bengin case (115).jpg with method 'Contrast_Stretching' as F:\MLpractrice\ct\output\data\Bengin cases\Contrast_Stretching\Bengin case (115)_3.jpg
# Processed and saved Bengin case (115).jpg with method 'Gaussian_Blur' as F:\MLpractrice\ct\output\data\Bengin cases\Gaussian_Blur\Bengin case (115)_4.jpg
# Processed and saved Bengin case (115).jpg with method 'Edge_Detection' as F:\MLpractrice\ct\output\data\Bengin cases\Edge_Detection\Bengin case (115)_5.jpg
# Processed and saved Bengin case (115).jpg with method 'Random_Color_Palette' as F:\MLpractrice\ct\output\data\Bengin cases\Random_Color_Palette\Bengin case (115)_6.jpg
# Processed and saved Bengin case (115).jpg with method 'Gamma_Correction' as F:\MLpractrice\ct\output\data\Bengin cases\Gamma_Correction\Bengin case (115)_7.jpg
# Processed and saved Bengin case (115).jpg with method 'LUT_Color_Map' as F:\MLpractrice\ct\output\data\Bengin cases\LUT_Color_Map\Bengin case (115)_8.jpg
# Processed and saved Bengin case (115).jpg with method 'Alpha_Blending' as F:\MLpractrice\ct\output\data\Bengin cases\Alpha_Blending\Bengin case (115)_9.jpg
# Processed and saved Bengin case (115).jpg with method '3D_Rendering' as F:\MLpractrice\ct\output\data\Bengin cases\3D_Rendering\Bengin case (115)_10.jpg
# Processed and saved Bengin case (115).jpg with method 'Heatmap_Visualization' as F:\MLpractrice\ct\output\data\Bengin cases\Heatmap_Visualization\Bengin case (115)_11.jpg
# Processed and saved Bengin case (115).jpg with method '3D_Volume_Rendering' as F:\MLpractrice\ct\output\data\Bengin cases\3D_Volume_Rendering\Bengin case (115)_12.jpg
# Processed and saved Bengin case (115).jpg with method 'Interactive_Segmentation' as F:\MLpractrice\ct\output\data\Bengin cases\Interactive_Segmentation\Bengin case (115)_13.jpg
# Processed and saved Bengin case (116).jpg with method 'Basic_Color_Map' as F:\MLpractrice\ct\output\data\Bengin cases\Basic_Color_Map\Bengin case (116)_1.jpg
# Processed and saved Bengin case (116).jpg with method 'Adaptive_Histogram_Equalization' as F:\MLpractrice\ct\output\data\Bengin cases\Adaptive_Histogram_Equalization\Bengin case (116)_2.jpg
# Processed and saved Bengin case (116).jpg with method 'Contrast_Stretching' as F:\MLpractrice\ct\output\data\Bengin cases\Contrast_Stretching\Bengin case (116)_3.jpg
# Processed and saved Bengin case (116).jpg with method 'Gaussian_Blur' as F:\MLpractrice\ct\output\data\Bengin cases\Gaussian_Blur\Bengin case (116)_4.jpg
# Processed and saved Bengin case (116).jpg with method 'Edge_Detection' as F:\MLpractrice\ct\output\data\Bengin cases\Edge_Detection\Bengin case (116)_5.jpg
# Processed and saved Bengin case (116).jpg with method 'Random_Color_Palette' as F:\MLpractrice\ct\output\data\Bengin cases\Random_Color_Palette\Bengin case (116)_6.jpg
# Processed and saved Bengin case (116).jpg with method 'Gamma_Correction' as F:\MLpractrice\ct\output\data\Bengin cases\Gamma_Correction\Bengin case (116)_7.jpg
# Processed and saved Bengin case (116).jpg with method 'LUT_Color_Map' as F:\MLpractrice\ct\output\data\Bengin cases\LUT_Color_Map\Bengin case (116)_8.jpg
# Processed and saved Bengin case (116).jpg with method 'Alpha_Blending' as F:\MLpractrice\ct\output\data\Bengin cases\Alpha_Blending\Bengin case (116)_9.jpg
# Processed and saved Bengin case (116).jpg with method '3D_Rendering' as F:\MLpractrice\ct\output\data\Bengin cases\3D_Rendering\Bengin case (116)_10.jpg
# Processed and saved Bengin case (116).jpg with method 'Heatmap_Visualization' as F:\MLpractrice\ct\output\data\Bengin cases\Heatmap_Visualization\Bengin case (116)_11.jpg
# Processed and saved Bengin case (116).jpg with method '3D_Volume_Rendering' as F:\MLpractrice\ct\output\data\Bengin cases\3D_Volume_Rendering\Bengin case (116)_12.jpg
# Processed and saved Bengin case (116).jpg with method 'Interactive_Segmentation' as F:\MLpractrice\ct\output\data\Bengin cases\Interactive_Segmentation\Bengin case (116)_13.jpg
# Processed and saved Bengin case (117).jpg with method 'Basic_Color_Map' as F:\MLpractrice\ct\output\data\Bengin cases\Basic_Color_Map\Bengin case (117)_1.jpg
# Processed and saved Bengin case (117).jpg with method 'Adaptive_Histogram_Equalization' as F:\MLpractrice\ct\output\data\Bengin cases\Adaptive_Histogram_Equalization\Bengin case (117)_2.jpg
# Processed and saved Bengin case (117).jpg with method 'Contrast_Stretching' as F:\MLpractrice\ct\output\data\Bengin cases\Contrast_Stretching\Bengin case (117)_3.jpg
# Processed and saved Bengin case (117).jpg with method 'Gaussian_Blur' as F:\MLpractrice\ct\output\data\Bengin cases\Gaussian_Blur\Bengin case (117)_4.jpg
# Processed and saved Bengin case (117).jpg with method 'Edge_Detection' as F:\MLpractrice\ct\output\data\Bengin cases\Edge_Detection\Bengin case (117)_5.jpg
# Processed and saved Bengin case (117).jpg with method 'Random_Color_Palette' as F:\MLpractrice\ct\output\data\Bengin cases\Random_Color_Palette\Bengin case (117)_6.jpg
# Processed and saved Bengin case (117).jpg with method 'Gamma_Correction' as F:\MLpractrice\ct\output\data\Bengin cases\Gamma_Correction\Bengin case (117)_7.jpg
# Processed and saved Bengin case (117).jpg with method 'LUT_Color_Map' as F:\MLpractrice\ct\output\data\Bengin cases\LUT_Color_Map\Bengin case (117)_8.jpg
# Processed and saved Bengin case (117).jpg with method 'Alpha_Blending' as F:\MLpractrice\ct\output\data\Bengin cases\Alpha_Blending\Bengin case (117)_9.jpg
# Processed and saved Bengin case (117).jpg with method '3D_Rendering' as F:\MLpractrice\ct\output\data\Bengin cases\3D_Rendering\Bengin case (117)_10.jpg
# Processed and saved Bengin case (117).jpg with method 'Heatmap_Visualization' as F:\MLpractrice\ct\output\data\Bengin cases\Heatmap_Visualization\Bengin case (117)_11.jpg
# Processed and saved Bengin case (117).jpg with method '3D_Volume_Rendering' as F:\MLpractrice\ct\output\data\Bengin cases\3D_Volume_Rendering\Bengin case (117)_12.jpg
# Processed and saved Bengin case (117).jpg with method 'Interactive_Segmentation' as F:\MLpractrice\ct\output\data\Bengin cases\Interactive_Segmentation\Bengin case (117)_13.jpg
# Processed and saved Bengin case (118).jpg with method 'Basic_Color_Map' as F:\MLpractrice\ct\output\data\Bengin cases\Basic_Color_Map\Bengin case (118)_1.jpg
# Processed and saved Bengin case (118).jpg with method 'Adaptive_Histogram_Equalization' as F:\MLpractrice\ct\output\data\Bengin cases\Adaptive_Histogram_Equalization\Bengin case (118)_2.jpg
# Processed and saved Bengin case (118).jpg with method 'Contrast_Stretching' as F:\MLpractrice\ct\output\data\Bengin cases\Contrast_Stretching\Bengin case (118)_3.jpg
# Processed and saved Bengin case (118).jpg with method 'Gaussian_Blur' as F:\MLpractrice\ct\output\data\Bengin cases\Gaussian_Blur\Bengin case (118)_4.jpg
# Processed and saved Bengin case (118).jpg with method 'Edge_Detection' as F:\MLpractrice\ct\output\data\Bengin cases\Edge_Detection\Bengin case (118)_5.jpg
# Processed and saved Bengin case (118).jpg with method 'Random_Color_Palette' as F:\MLpractrice\ct\output\data\Bengin cases\Random_Color_Palette\Bengin case (118)_6.jpg
# Processed and saved Bengin case (118).jpg with method 'Gamma_Correction' as F:\MLpractrice\ct\output\data\Bengin cases\Gamma_Correction\Bengin case (118)_7.jpg
# Processed and saved Bengin case (118).jpg with method 'LUT_Color_Map' as F:\MLpractrice\ct\output\data\Bengin cases\LUT_Color_Map\Bengin case (118)_8.jpg
# Processed and saved Bengin case (118).jpg with method 'Alpha_Blending' as F:\MLpractrice\ct\output\data\Bengin cases\Alpha_Blending\Bengin case (118)_9.jpg
# Processed and saved Bengin case (118).jpg with method '3D_Rendering' as F:\MLpractrice\ct\output\data\Bengin cases\3D_Rendering\Bengin case (118)_10.jpg
# Processed and saved Bengin case (118).jpg with method 'Heatmap_Visualization' as F:\MLpractrice\ct\output\data\Bengin cases\Heatmap_Visualization\Bengin case (118)_11.jpg
# Processed and saved Bengin case (118).jpg with method '3D_Volume_Rendering' as F:\MLpractrice\ct\output\data\Bengin cases\3D_Volume_Rendering\Bengin case (118)_12.jpg
# Processed and saved Bengin case (118).jpg with method 'Interactive_Segmentation' as F:\MLpractrice\ct\output\data\Bengin cases\Interactive_Segmentation\Bengin case (118)_13.jpg
# Processed and saved Bengin case (119).jpg with method 'Basic_Color_Map' as F:\MLpractrice\ct\output\data\Bengin cases\Basic_Color_Map\Bengin case (119)_1.jpg
# Processed and saved Bengin case (119).jpg with method 'Adaptive_Histogram_Equalization' as F:\MLpractrice\ct\output\data\Bengin cases\Adaptive_Histogram_Equalization\Bengin case (119)_2.jpg
# Processed and saved Bengin case (119).jpg with method 'Contrast_Stretching' as F:\MLpractrice\ct\output\data\Bengin cases\Contrast_Stretching\Bengin case (119)_3.jpg
# Processed and saved Bengin case (119).jpg with method 'Gaussian_Blur' as F:\MLpractrice\ct\output\data\Bengin cases\Gaussian_Blur\Bengin case (119)_4.jpg
# Processed and saved Bengin case (119).jpg with method 'Edge_Detection' as F:\MLpractrice\ct\output\data\Bengin cases\Edge_Detection\Bengin case (119)_5.jpg
# ...
# Processed and saved Normal case (221).jpg with method 'Adaptive_Histogram_Equalization' as F:\MLpractrice\ct\output\data\Normal cases\Adaptive_Histogram_Equalization\Normal case (221)_2.jpg
# Processed and saved Normal case (221).jpg with method 'Contrast_Stretching' as F:\MLpractrice\ct\output\data\Normal cases\Contrast_Stretching\Normal case (221)_3.jpg
# Processed and saved Normal case (221).jpg with method 'Gaussian_Blur' as F:\MLpractrice\ct\output\data\Normal cases\Gaussian_Blur\Normal case (221)_4.jpg
# Processed and saved Normal case (221).jpg with method 'Edge_Detection' as F:\MLpractrice\ct\output\data\Normal cases\Edge_Detection\Normal case (221)_5.jpg
# Processed and saved Normal case (221).jpg with method 'Random_Color_Palette' as F:\MLpractrice\ct\output\data\Normal cases\Random_Color_Palette\Normal case (221)_6.jpg
# Processed and saved Normal case (221).jpg with method 'Gamma_Correction' as F:\MLpractrice\ct\output\data\Normal cases\Gamma_Correction\Normal case (221)_7.jpg
# Processed and saved Normal case (221).jpg with method 'LUT_Color_Map' as F:\MLpractrice\ct\output\data\Normal cases\LUT_Color_Map\Normal case (221)_8.jpg
# Processed and saved Normal case (221).jpg with method 'Alpha_Blending' as F:\MLpractrice\ct\output\data\Normal cases\Alpha_Blending\Normal case (221)_9.jpg
# Processed and saved Normal case (221).jpg with method '3D_Rendering' as F:\MLpractrice\ct\output\data\Normal cases\3D_Rendering\Normal case (221)_10.jpg
# Processed and saved Normal case (221).jpg with method 'Heatmap_Visualization' as F:\MLpractrice\ct\output\data\Normal cases\Heatmap_Visualization\Normal case (221)_11.jpg
# Processed and saved Normal case (221).jpg with method '3D_Volume_Rendering' as F:\MLpractrice\ct\output\data\Normal cases\3D_Volume_Rendering\Normal case (221)_12.jpg
# Processed and saved Normal case (221).jpg with method 'Interactive_Segmentation' as F:\MLpractrice\ct\output\data\Normal cases\Interactive_Segmentation\Normal case (221)_13.jpg
# Processed and saved Normal case (222).jpg with method 'Basic_Color_Map' as F:\MLpractrice\ct\output\data\Normal cases\Basic_Color_Map\Normal case (222)_1.jpg
# Processed and saved Normal case (222).jpg with method 'Adaptive_Histogram_Equalization' as F:\MLpractrice\ct\output\data\Normal cases\Adaptive_Histogram_Equalization\Normal case (222)_2.jpg
# Processed and saved Normal case (222).jpg with method 'Contrast_Stretching' as F:\MLpractrice\ct\output\data\Normal cases\Contrast_Stretching\Normal case (222)_3.jpg
# Processed and saved Normal case (222).jpg with method 'Gaussian_Blur' as F:\MLpractrice\ct\output\data\Normal cases\Gaussian_Blur\Normal case (222)_4.jpg
# Processed and saved Normal case (222).jpg with method 'Edge_Detection' as F:\MLpractrice\ct\output\data\Normal cases\Edge_Detection\Normal case (222)_5.jpg
# Processed and saved Normal case (222).jpg with method 'Random_Color_Palette' as F:\MLpractrice\ct\output\data\Normal cases\Random_Color_Palette\Normal case (222)_6.jpg
# Processed and saved Normal case (222).jpg with method 'Gamma_Correction' as F:\MLpractrice\ct\output\data\Normal cases\Gamma_Correction\Normal case (222)_7.jpg
# Processed and saved Normal case (222).jpg with method 'LUT_Color_Map' as F:\MLpractrice\ct\output\data\Normal cases\LUT_Color_Map\Normal case (222)_8.jpg
# Processed and saved Normal case (222).jpg with method 'Alpha_Blending' as F:\MLpractrice\ct\output\data\Normal cases\Alpha_Blending\Normal case (222)_9.jpg
# Processed and saved Normal case (222).jpg with method '3D_Rendering' as F:\MLpractrice\ct\output\data\Normal cases\3D_Rendering\Normal case (222)_10.jpg
# Processed and saved Normal case (222).jpg with method 'Heatmap_Visualization' as F:\MLpractrice\ct\output\data\Normal cases\Heatmap_Visualization\Normal case (222)_11.jpg
# Processed and saved Normal case (222).jpg with method '3D_Volume_Rendering' as F:\MLpractrice\ct\output\data\Normal cases\3D_Volume_Rendering\Normal case (222)_12.jpg
# Processed and saved Normal case (222).jpg with method 'Interactive_Segmentation' as F:\MLpractrice\ct\output\data\Normal cases\Interactive_Segmentation\Normal case (222)_13.jpg
# Processed and saved Normal case (223).jpg with method 'Basic_Color_Map' as F:\MLpractrice\ct\output\data\Normal cases\Basic_Color_Map\Normal case (223)_1.jpg
# Processed and saved Normal case (223).jpg with method 'Adaptive_Histogram_Equalization' as F:\MLpractrice\ct\output\data\Normal cases\Adaptive_Histogram_Equalization\Normal case (223)_2.jpg
# Processed and saved Normal case (223).jpg with method 'Contrast_Stretching' as F:\MLpractrice\ct\output\data\Normal cases\Contrast_Stretching\Normal case (223)_3.jpg
# Processed and saved Normal case (223).jpg with method 'Gaussian_Blur' as F:\MLpractrice\ct\output\data\Normal cases\Gaussian_Blur\Normal case (223)_4.jpg
# Processed and saved Normal case (223).jpg with method 'Edge_Detection' as F:\MLpractrice\ct\output\data\Normal cases\Edge_Detection\Normal case (223)_5.jpg
# Processed and saved Normal case (223).jpg with method 'Random_Color_Palette' as F:\MLpractrice\ct\output\data\Normal cases\Random_Color_Palette\Normal case (223)_6.jpg
# Processed and saved Normal case (223).jpg with method 'Gamma_Correction' as F:\MLpractrice\ct\output\data\Normal cases\Gamma_Correction\Normal case (223)_7.jpg
# Processed and saved Normal case (223).jpg with method 'LUT_Color_Map' as F:\MLpractrice\ct\output\data\Normal cases\LUT_Color_Map\Normal case (223)_8.jpg
# Processed and saved Normal case (223).jpg with method 'Alpha_Blending' as F:\MLpractrice\ct\output\data\Normal cases\Alpha_Blending\Normal case (223)_9.jpg
# Processed and saved Normal case (223).jpg with method '3D_Rendering' as F:\MLpractrice\ct\output\data\Normal cases\3D_Rendering\Normal case (223)_10.jpg
# Processed and saved Normal case (223).jpg with method 'Heatmap_Visualization' as F:\MLpractrice\ct\output\data\Normal cases\Heatmap_Visualization\Normal case (223)_11.jpg
# Processed and saved Normal case (223).jpg with method '3D_Volume_Rendering' as F:\MLpractrice\ct\output\data\Normal cases\3D_Volume_Rendering\Normal case (223)_12.jpg
# Processed and saved Normal case (223).jpg with method 'Interactive_Segmentation' as F:\MLpractrice\ct\output\data\Normal cases\Interactive_Segmentation\Normal case (223)_13.jpg
# Processed and saved Normal case (224).jpg with method 'Basic_Color_Map' as F:\MLpractrice\ct\output\data\Normal cases\Basic_Color_Map\Normal case (224)_1.jpg
# Processed and saved Normal case (224).jpg with method 'Adaptive_Histogram_Equalization' as F:\MLpractrice\ct\output\data\Normal cases\Adaptive_Histogram_Equalization\Normal case (224)_2.jpg
# Processed and saved Normal case (224).jpg with method 'Contrast_Stretching' as F:\MLpractrice\ct\output\data\Normal cases\Contrast_Stretching\Normal case (224)_3.jpg
# Processed and saved Normal case (224).jpg with method 'Gaussian_Blur' as F:\MLpractrice\ct\output\data\Normal cases\Gaussian_Blur\Normal case (224)_4.jpg
# Processed and saved Normal case (224).jpg with method 'Edge_Detection' as F:\MLpractrice\ct\output\data\Normal cases\Edge_Detection\Normal case (224)_5.jpg
# Processed and saved Normal case (224).jpg with method 'Random_Color_Palette' as F:\MLpractrice\ct\output\data\Normal cases\Random_Color_Palette\Normal case (224)_6.jpg
# Processed and saved Normal case (224).jpg with method 'Gamma_Correction' as F:\MLpractrice\ct\output\data\Normal cases\Gamma_Correction\Normal case (224)_7.jpg
# Processed and saved Normal case (224).jpg with method 'LUT_Color_Map' as F:\MLpractrice\ct\output\data\Normal cases\LUT_Color_Map\Normal case (224)_8.jpg
# Processed and saved Normal case (224).jpg with method 'Alpha_Blending' as F:\MLpractrice\ct\output\data\Normal cases\Alpha_Blending\Normal case (224)_9.jpg
# Processed and saved Normal case (224).jpg with method '3D_Rendering' as F:\MLpractrice\ct\output\data\Normal cases\3D_Rendering\Normal case (224)_10.jpg
# Processed and saved Normal case (224).jpg with method 'Heatmap_Visualization' as F:\MLpractrice\ct\output\data\Normal cases\Heatmap_Visualization\Normal case (224)_11.jpg
# Processed and saved Normal case (224).jpg with method '3D_Volume_Rendering' as F:\MLpractrice\ct\output\data\Normal cases\3D_Volume_Rendering\Normal case (224)_12.jpg
# Processed and saved Normal case (224).jpg with method 'Interactive_Segmentation' as F:\MLpractrice\ct\output\data\Normal cases\Interactive_Segmentation\Normal case (224)_13.jpg
# Processed and saved Normal case (225).jpg with method 'Basic_Color_Map' as F:\MLpractrice\ct\output\data\Normal cases\Basic_Color_Map\Normal case (225)_1.jpg
# Processed and saved Normal case (225).jpg with method 'Adaptive_Histogram_Equalization' as F:\MLpractrice\ct\output\data\Normal cases\Adaptive_Histogram_Equalization\Normal case (225)_2.jpg
# Processed and saved Normal case (225).jpg with method 'Contrast_Stretching' as F:\MLpractrice\ct\output\data\Normal cases\Contrast_Stretching\Normal case (225)_3.jpg
# Processed and saved Normal case (225).jpg with method 'Gaussian_Blur' as F:\MLpractrice\ct\output\data\Normal cases\Gaussian_Blur\Normal case (225)_4.jpg
# Processed and saved Normal case (225).jpg with method 'Edge_Detection' as F:\MLpractrice\ct\output\data\Normal cases\Edge_Detection\Normal case (225)_5.jpg
# Processed and saved Normal case (225).jpg with method 'Random_Color_Palette' as F:\MLpractrice\ct\output\data\Normal cases\Random_Color_Palette\Normal case (225)_6.jpg
# Processed and saved Normal case (225).jpg with method 'Gamma_Correction' as F:\MLpractrice\ct\output\data\Normal cases\Gamma_Correction\Normal case (225)_7.jpg
# Processed and saved Normal case (225).jpg with method 'LUT_Color_Map' as F:\MLpractrice\ct\output\data\Normal cases\LUT_Color_Map\Normal case (225)_8.jpg
# Processed and saved Normal case (225).jpg with method 'Alpha_Blending' as F:\MLpractrice\ct\output\data\Normal cases\Alpha_Blending\Normal case (225)_9.jpg
# Processed and saved Normal case (225).jpg with method '3D_Rendering' as F:\MLpractrice\ct\output\data\Normal cases\3D_Rendering\Normal case (225)_10.jpg
# Processed and saved Normal case (225).jpg with method 'Heatmap_Visualization' as F:\MLpractrice\ct\output\data\Normal cases\Heatmap_Visualization\Normal case (225)_11.jpg
# Processed and saved Normal case (225).jpg with method '3D_Volume_Rendering' as F:\MLpractrice\ct\output\data\Normal cases\3D_Volume_Rendering\Normal case (225)_12.jpg
# Processed and saved Normal case (225).jpg with method 'Interactive_Segmentation' as F:\MLpractrice\ct\output\data\Normal cases\Interactive_Segmentation\Normal case (225)_13.jpg
# Processed and saved Normal case (226).jpg with method 'Basic_Color_Map' as F:\MLpractrice\ct\output\data\Normal cases\Basic_Color_Map\Normal case (226)_1.jpg
# Processed and saved Normal case (226).jpg with method 'Adaptive_Histogram_Equalization' as F:\MLpractrice\ct\output\data\Normal cases\Adaptive_Histogram_Equalization\Normal case (226)_2.jpg
# Processed and saved Normal case (226).jpg with method 'Contrast_Stretching' as F:\MLpractrice\ct\output\data\Normal cases\Contrast_Stretching\Normal case (226)_3.jpg
# Processed and saved Normal case (226).jpg with method 'Gaussian_Blur' as F:\MLpractrice\ct\output\data\Normal cases\Gaussian_Blur\Normal case (226)_4.jpg
# Processed and saved Normal case (226).jpg with method 'Edge_Detection' as F:\MLpractrice\ct\output\data\Normal cases\Edge_Detection\Normal case (226)_5.jpg
# Processed and saved Normal case (226).jpg with method 'Random_Color_Palette' as F:\MLpractrice\ct\output\data\Normal cases\Random_Color_Palette\Normal case (226)_6.jpg
# Processed and saved Normal case (226).jpg with method 'Gamma_Correction' as F:\MLpractrice\ct\output\data\Normal cases\Gamma_Correction\Normal case (226)_7.jpg
# Processed and saved Normal case (226).jpg with method 'LUT_Color_Map' as F:\MLpractrice\ct\output\data\Normal cases\LUT_Color_Map\Normal case (226)_8.jpg
# Processed and saved Normal case (226).jpg with method 'Alpha_Blending' as F:\MLpractrice\ct\output\data\Normal cases\Alpha_Blending\Normal case (226)_9.jpg
# Processed and saved Normal case (226).jpg with method '3D_Rendering' as F:\MLpractrice\ct\output\data\Normal cases\3D_Rendering\Normal case (226)_10.jpg
# Processed and saved Normal case (226).jpg with method 'Heatmap_Visualization' as F:\MLpractrice\ct\output\data\Normal cases\Heatmap_Visualization\Normal case (226)_11.jpg
# Processed and saved Normal case (226).jpg with method '3D_Volume_Rendering' as F:\MLpractrice\ct\output\data\Normal cases\3D_Volume_Rendering\Normal case (226)_12.jpg
# Processed and saved Normal case (226).jpg with method 'Interactive_Segmentation' as F:\MLpractrice\ct\output\data\Normal cases\Interactive_Segmentation\Normal case (226)_13.jpg
# Processed and saved Normal case (227).jpg with method 'Basic_Color_Map' as F:\MLpractrice\ct\output\data\Normal cases\Basic_Color_Map\Normal case (227)_1.jpg
# Processed and saved Normal case (227).jpg with method 'Adaptive_Histogram_Equalization' as F:\MLpractrice\ct\output\data\Normal cases\Adaptive_Histogram_Equalization\Normal case (227)_2.jpg
# Processed and saved Normal case (227).jpg with method 'Contrast_Stretching' as F:\MLpractrice\ct\output\data\Normal cases\Contrast_Stretching\Normal case (227)_3.jpg
# Processed and saved Normal case (227).jpg with method 'Gaussian_Blur' as F:\MLpractrice\ct\output\data\Normal cases\Gaussian_Blur\Normal case (227)_4.jpg
# Processed and saved Normal case (227).jpg with method 'Edge_Detection' as F:\MLpractrice\ct\output\data\Normal cases\Edge_Detection\Normal case (227)_5.jpg
# Processed and saved Normal case (227).jpg with method 'Random_Color_Palette' as F:\MLpractrice\ct\output\data\Normal cases\Random_Color_Palette\Normal case (227)_6.jpg
# Processed and saved Normal case (227).jpg with method 'Gamma_Correction' as F:\MLpractrice\ct\output\data\Normal cases\Gamma_Correction\Normal case (227)_7.jpg
# Processed and saved Normal case (227).jpg with method 'LUT_Color_Map' as F:\MLpractrice\ct\output\data\Normal cases\LUT_Color_Map\Normal case (227)_8.jpg
# Processed and saved Normal case (227).jpg with method 'Alpha_Blending' as F:\MLpractrice\ct\output\data\Normal cases\Alpha_Blending\Normal case (227)_9.jpg
# Processed and saved Normal case (227).jpg with method '3D_Rendering' as F:\MLpractrice\ct\output\data\Normal cases\3D_Rendering\Normal case (227)_10.jpg
# Processed and saved Normal case (227).jpg with method 'Heatmap_Visualization' as F:\MLpractrice\ct\output\data\Normal cases\Heatmap_Visualization\Normal case (227)_11.jpg
# Processed and saved Normal case (227).jpg with method '3D_Volume_Rendering' as F:\MLpractrice\ct\output\data\Normal cases\3D_Volume_Rendering\Normal case (227)_12.jpg
# Processed and saved Normal case (227).jpg with method 'Interactive_Segmentation' as F:\MLpractrice\ct\output\data\Normal cases\Interactive_Segmentation\Normal case (227)_13.jpg
# Processed and saved Normal case (228).jpg with method 'Basic_Color_Map' as F:\MLpractrice\ct\output\data\Normal cases\Basic_Color_Map\Normal case (228)_1.jpg
# Processed and saved Normal case (228).jpg with method 'Adaptive_Histogram_Equalization' as F:\MLpractrice\ct\output\data\Normal cases\Adaptive_Histogram_Equalization\Normal case (228)_2.jpg
# Processed and saved Normal case (228).jpg with method 'Contrast_Stretching' as F:\MLpractrice\ct\output\data\Normal cases\Contrast_Stretching\Normal case (228)_3.jpg
# Processed and saved Normal case (228).jpg with method 'Gaussian_Blur' as F:\MLpractrice\ct\output\data\Normal cases\Gaussian_Blur\Normal case (228)_4.jpg
# Processed and saved Normal case (228).jpg with method 'Edge_Detection' as F:\MLpractrice\ct\output\data\Normal cases\Edge_Detection\Normal case (228)_5.jpg
# Processed and saved Normal case (228).jpg with method 'Random_Color_Palette' as F:\MLpractrice\ct\output\data\Normal cases\Random_Color_Palette\Normal case (228)_6.jpg
# Processed and saved Normal case (228).jpg with method 'Gamma_Correction' as F:\MLpractrice\ct\output\data\Normal cases\Gamma_Correction\Normal case (228)_7.jpg

# %%
4000+4

# %%
4000+4
